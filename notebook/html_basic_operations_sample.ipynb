# %% [markdown]
# <a href="https://colab.research.google.com/github/girijeshcse/car_finder/blob/ambika/notebook/html_basic_operations_sample.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pwd
# !ls /content
# Out:
# /content
# drive  h.jpeg  sample_data  static  template

# %%
# !pip install flask_ngrok

# %%
#!pip install streamlit


# !pip install pyngrok
from pyngrok import ngrok

# %%
# !mkdir  /content/template
# !mkdir /content/static
# Out:
# mkdir: cannot create directory ‘/content/template’: File exists
# mkdir: cannot create directory ‘/content/static’: File exists

# %%
# !ngrok authtoken 22tbMPPQcCEfC5ezJ9rDuHyV5Hg_3oAwcW81SxhFhXYinoWyK
# Out:
# Authtoken saved to configuration file: /root/.ngrok2/ngrok.yml

# %%
# !cp -r /content/drive/MyDrive/MachineLearning/CapstoneProject/template /content

# %%
def test1():
  return "This is good"

# %%
ls "/content/drive/MyDrive/MachineLearning/CapstoneProject/Dataset/Car Images/Train Images/AM General Hummer SUV 2000/00163.jpg"
# Out:
# '/content/drive/MyDrive/MachineLearning/CapstoneProject/Dataset/Car Images/Train Images/AM General Hummer SUV 2000/00163.jpg'

# %%
import random
import os 
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
  
from PIL import Image
import numpy as np

import tensorflow as tf
import os
import pandas as pd

def ploting_image():
  f = plt.figure()
  axarr = f.add_subplot(1, 1, 1)
  filename="/content/drive/MyDrive/MachineLearning/CapstoneProject/Dataset/Car Images/Train Images/AM General Hummer SUV 2000/00163.jpg"
  # Create figure and axes
  #fig,ax = plt.subplots(1)
  im = Image.open(filename, mode='r')
  #im = im.resize(128, 128, 3)
  pix_val = np.array(list(im.getdata()))
  plt.imshow(im)
  print(pix_val)
  plt.savefig('/content/static/image1.jpeg')
    #.reshape(size_dim,size_dim,3))
  return f
  #plt.show()

# %%
def plot_another():
    f = plt.figure()
    # Get x values of the sine wave
    time        = np.arange(0, 100, 1);

    # Amplitude of the sine wave is sine of a variable like time
    amplitude   = np.sin(time)

    # plt a sine wave using time and amplitude obtained for the sine wave
    plt.plot(time, amplitude)

    # Give a title for the sine wave plt
    plt.title('Sine wave')


    # Give x axis label for the sine wave plt
    plt.xlabel('Time')
    # Give y axis label for the sine wave plt
    plt.ylabel('Amplitude = sin(time)')


    #plt.grid(True, which='both')
    #plt.axhline(y=0, color='k')

    
    plt.savefig('/content/static/image2.jpeg')
    return f

# %%
import numpy as np
def plot_form():
  axarr = f.add_subplot(1, 1, 1)
  arr=np.array([[1,0]*4,[0,1]*4]*4)
  # use the 'gray' argument in cmap argument to make the image black and white
  plt.imshow(arr,cmap="gray")
  plt.savefig('h.jpeg')
  return f

# %%
ls /content
# Out:
# drive/  h.jpeg  sample_data/  static/  template/

# %%
fig_size=(8,8)
f = plt.figure(figsize=fig_size)
f = plot_form()

# %%
fig_size=(8,8)
f = plt.figure(figsize=fig_size)
f = plot_form()

# %%
ploting_image()
# Out:
# [[255 255 255]
#  [255 255 255]
#  [255 255 255]
#  ...
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]]

# %%
 plot_another()

# %%
# %%writefile /content/template/index.html
# <!doctype html>
# <html>
# <head>
#   <link rel="shortcut icon" href="#" />
#   <title>Capstone Project - JAN 21 B batch</title>
#
# </head>
# <body>
#   <h1>CV2 - Car Finder Project</h1>
#   <h2>Data Gathering</h2>
#   <form>
#     <input name="traindata" id="Training-data">
#     <button type="button" id="home" onclick=trainData() value="checkvalue"></button>
#     {{ form }}
#   </form>
#   <img id="picture 1" src="data:image/jpeg;base64,{{ img_data1 }}">
#
#   <img id="picture 2" src="data:image/jpeg;base64,{{ img_data2 }}">
#
#
#   <template>
#     <div id="datagather">
#         <p>CV2 - Car Finder Project</p>
#         <p id="test1">hello word2</p>
#         <p>hello word3</p>
#         <p>hello word4</p>
#     </div>
#   </template>
#   <script>
#     function trainData() {
#       butA = document.createElement("button");
#       butA.innerHTML = "Training Images";
#       document.body.appendChild(butA);
#     }
#   </script>
# </body>
# </html>
# Out:
# Overwriting /content/template/index.html

# %%
from flask import Flask
from flask import render_template
from flask_ngrok import run_with_ngrok
import io
import os
import uuid

import base64
app = Flask(__name__,template_folder='template')


run_with_ngrok(app)   


def data_converter(filename):
  im = Image.open(filename)
  data = io.BytesIO()
  im.save(data, "JPEG")
  return data


@app.route('/')
def index():

    data1 = data_converter("/content/static/image1.jpeg")
    encoded_img_data1 = base64.b64encode(data1.getvalue())
    f= test1()
    data2 = data_converter("/content/static/image2.jpeg")
    encoded_img_data2 = base64.b64encode(data2.getvalue())
    return render_template("index.html", form=f,img_data1=encoded_img_data1.decode('utf-8'),img_data2=encoded_img_data2.decode('utf-8'))

if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
#  * Running on http://2cd5-35-203-143-9.ngrok.io
#  * Traffic stats available on http://127.0.0.1:4040
# 127.0.0.1 - - [07/Jan/2022 16:33:05] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Jan/2022 16:33:06] "GET / HTTP/1.1" 200 -

# %%
from flask import Flask
from flask import render_template
from flask_ngrok import run_with_ngrok
import io
import os
import uuid
import base64


app = Flask(__name__,template_folder='template')


run_with_ngrok(app)   



@app.route('/')
def index():
   
    f = plt.figure()
    f = ploting()
    
    full_filename = "/content/drive/MyDrive/MachineLearning/CapstoneProject/Dataset/Car Images/Train Images/AM General Hummer SUV 2000/00163.jpg"
    #return render_template('user_popup.html', user=user, form=form)
    return render_template('index.html', form=f, user_image=full_filename)

if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
