# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cd /content/drive/MyDrive/MachineLearning/CapstoneProject

# %%
# !ls '/content/drive/MyDrive/MachineLearning/CapstoneProject/Dataset_1/Dataset/Car Images/Train Images'
# Out:
# 'Acura Integra Type R 2001'
# 'Acura RL Sedan 2012'
# 'Acura TL Sedan 2012'
# 'Acura TL Type-S 2008'
# 'Acura TSX Sedan 2012'
# 'Acura ZDX Hatchback 2012'
# 'AM General Hummer SUV 2000'
# 'Aston Martin V8 Vantage Convertible 2012'
# 'Aston Martin V8 Vantage Coupe 2012'
# 'Aston Martin Virage Convertible 2012'
# 'Aston Martin Virage Coupe 2012'
# 'Audi 100 Sedan 1994'
# 'Audi 100 Wagon 1994'
# 'Audi A5 Coupe 2012'
# 'Audi R8 Coupe 2012'
# 'Audi RS 4 Convertible 2008'
# 'Audi S4 Sedan 2007'
# 'Audi S4 Sedan 2012'
# 'Audi S5 Convertible 2012'
# 'Audi S5 Coupe 2012'
# 'Audi S6 Sedan 2011'
# 'Audi TT Hatchback 2011'
# 'Audi TT RS Coupe 2012'
# 'Audi TTS Coupe 2012'
# 'Audi V8 Sedan 1994'
# 'Bentley Arnage Sedan 2009'
# 'Bentley Continental Flying Spur Sedan 2007'
# 'Bentley Continental GT Coupe 2007'
# 'Bentley Continental GT Coupe 2012'
# 'Bentley Continental Supersports Conv. Convertible 2012'
# 'Bentley Mulsanne Sedan 2011'
# 'BMW 1 Series Convertible 2012'
# 'BMW 1 Series Coupe 2012'
# 'BMW 3 Series Sedan 2012'
# 'BMW 3 Series Wagon 2012'
# 'BMW 6 Series Convertible 2007'
# 'BMW ActiveHybrid 5 Sedan 2012'
# 'BMW M3 Coupe 2012'
# 'BMW M5 Sedan 2010'
# 'BMW M6 Convertible 2010'
# 'BMW X3 SUV 2012'
# 'BMW X5 SUV 2007'
# 'BMW X6 SUV 2012'
# 'BMW Z4 Convertible 2012'
# 'Bugatti Veyron 16.4 Convertible 2009'
# 'Bugatti Veyron 16.4 Coupe 2009'
# 'Buick Enclave SUV 2012'
# 'Buick Rainier SUV 2007'
# 'Buick Regal GS 2012'
# 'Buick Verano Sedan 2012'
# 'Cadillac CTS-V Sedan 2012'
# 'Cadillac Escalade EXT Crew Cab 2007'
# 'Cadillac SRX SUV 2012'
# 'Chevrolet Avalanche Crew Cab 2012'
# 'Chevrolet Camaro Convertible 2012'
# 'Chevrolet Cobalt SS 2010'
# 'Chevrolet Corvette Convertible 2012'
# 'Chevrolet Corvette Ron Fellows Edition Z06 2007'
# 'Chevrolet Corvette ZR1 2012'
# 'Chevrolet Express Cargo Van 2007'
# 'Chevrolet Express Van 2007'
# 'Chevrolet HHR SS 2010'
# 'Chevrolet Impala Sedan 2007'
# 'Chevrolet Malibu Hybrid Sedan 2010'
# 'Chevrolet Malibu Sedan 2007'
# 'Chevrolet Monte Carlo Coupe 2007'
# 'Chevrolet Silverado 1500 Classic Extended Cab 2007'
# 'Chevrolet Silverado 1500 Extended Cab 2012'
# 'Chevrolet Silverado 1500 Hybrid Crew Cab 2012'
# 'Chevrolet Silverado 1500 Regular Cab 2012'
# 'Chevrolet Silverado 2500HD Regular Cab 2012'
# 'Chevrolet Sonic Sedan 2012'
# 'Chevrolet Tahoe Hybrid SUV 2012'
# 'Chevrolet TrailBlazer SS 2009'
# 'Chevrolet Traverse SUV 2012'
# 'Chrysler 300 SRT-8 2010'
# 'Chrysler Aspen SUV 2009'
# 'Chrysler Crossfire Convertible 2008'
# 'Chrysler PT Cruiser Convertible 2008'
# 'Chrysler Sebring Convertible 2010'
# 'Chrysler Town and Country Minivan 2012'
# 'Daewoo Nubira Wagon 2002'
# 'Dodge Caliber Wagon 2007'
# 'Dodge Caliber Wagon 2012'
# 'Dodge Caravan Minivan 1997'
# 'Dodge Challenger SRT8 2011'
# 'Dodge Charger Sedan 2012'
# 'Dodge Charger SRT-8 2009'
# 'Dodge Dakota Club Cab 2007'
# 'Dodge Dakota Crew Cab 2010'
# 'Dodge Durango SUV 2007'
# 'Dodge Durango SUV 2012'
# 'Dodge Journey SUV 2012'
# 'Dodge Magnum Wagon 2008'
# 'Dodge Ram Pickup 3500 Crew Cab 2010'
# 'Dodge Ram Pickup 3500 Quad Cab 2009'
# 'Dodge Sprinter Cargo Van 2009'
# 'Eagle Talon Hatchback 1998'
# 'Ferrari 458 Italia Convertible 2012'
# 'Ferrari 458 Italia Coupe 2012'
# 'Ferrari California Convertible 2012'
# 'Ferrari FF Coupe 2012'
# 'FIAT 500 Abarth 2012'
# 'FIAT 500 Convertible 2012'
# 'Fisker Karma Sedan 2012'
# 'Ford Edge SUV 2012'
# 'Ford E-Series Wagon Van 2012'
# 'Ford Expedition EL SUV 2009'
# 'Ford F-150 Regular Cab 2007'
# 'Ford F-150 Regular Cab 2012'
# 'Ford F-450 Super Duty Crew Cab 2012'
# 'Ford Fiesta Sedan 2012'
# 'Ford Focus Sedan 2007'
# 'Ford Freestar Minivan 2007'
# 'Ford GT Coupe 2006'
# 'Ford Mustang Convertible 2007'
# 'Ford Ranger SuperCab 2011'
# 'Geo Metro Convertible 1993'
# 'GMC Acadia SUV 2012'
# 'GMC Canyon Extended Cab 2012'
# 'GMC Savana Van 2012'
# 'GMC Terrain SUV 2012'
# 'GMC Yukon Hybrid SUV 2012'
# 'Honda Accord Coupe 2012'
# 'Honda Accord Sedan 2012'
# 'Honda Odyssey Minivan 2007'
# 'Honda Odyssey Minivan 2012'
# 'HUMMER H2 SUT Crew Cab 2009'
# 'HUMMER H3T Crew Cab 2010'
# 'Hyundai Accent Sedan 2012'
# 'Hyundai Azera Sedan 2012'
# 'Hyundai Elantra Sedan 2007'
# 'Hyundai Elantra Touring Hatchback 2012'
# 'Hyundai Genesis Sedan 2012'
# 'Hyundai Santa Fe SUV 2012'
# 'Hyundai Sonata Hybrid Sedan 2012'
# 'Hyundai Sonata Sedan 2012'
# 'Hyundai Tucson SUV 2012'
# 'Hyundai Veloster Hatchback 2012'
# 'Hyundai Veracruz SUV 2012'
# 'Infiniti G Coupe IPL 2012'
# 'Infiniti QX56 SUV 2011'
# 'Isuzu Ascender SUV 2008'
# 'Jaguar XK XKR 2012'
# 'Jeep Compass SUV 2012'
# 'Jeep Grand Cherokee SUV 2012'
# 'Jeep Liberty SUV 2012'
# 'Jeep Patriot SUV 2012'
# 'Jeep Wrangler SUV 2012'
# 'Lamborghini Aventador Coupe 2012'
# 'Lamborghini Diablo Coupe 2001'
# 'Lamborghini Gallardo LP 570-4 Superleggera 2012'
# 'Lamborghini Reventon Coupe 2008'
# 'Land Rover LR2 SUV 2012'
# 'Land Rover Range Rover SUV 2012'
# 'Lincoln Town Car Sedan 2011'
# 'Maybach Landaulet Convertible 2012'
# 'Mazda Tribute SUV 2011'
# 'McLaren MP4-12C Coupe 2012'
# 'Mercedes-Benz 300-Class Convertible 1993'
# 'Mercedes-Benz C-Class Sedan 2012'
# 'Mercedes-Benz E-Class Sedan 2012'
# 'Mercedes-Benz S-Class Sedan 2012'
# 'Mercedes-Benz SL-Class Coupe 2009'
# 'Mercedes-Benz Sprinter Van 2012'
# 'MINI Cooper Roadster Convertible 2012'
# 'Mitsubishi Lancer Sedan 2012'
# 'Nissan 240SX Coupe 1998'
# 'Nissan Juke Hatchback 2012'
# 'Nissan Leaf Hatchback 2012'
# 'Nissan NV Passenger Van 2012'
# 'Plymouth Neon Coupe 1999'
# 'Porsche Panamera Sedan 2012'
# 'Ram C-V Cargo Van Minivan 2012'
# 'Rolls-Royce Ghost Sedan 2012'
# 'Rolls-Royce Phantom Drophead Coupe Convertible 2012'
# 'Rolls-Royce Phantom Sedan 2012'
# 'Scion xD Hatchback 2012'
# 'smart fortwo Convertible 2012'
# 'Spyker C8 Convertible 2009'
# 'Spyker C8 Coupe 2009'
# 'Suzuki Aerio Sedan 2007'
# 'Suzuki Kizashi Sedan 2012'
# 'Suzuki SX4 Hatchback 2012'
# 'Suzuki SX4 Sedan 2012'
# 'Tesla Model S Sedan 2012'
# 'Toyota 4Runner SUV 2012'
# 'Toyota Camry Sedan 2012'
# 'Toyota Corolla Sedan 2012'
# 'Toyota Sequoia SUV 2012'
# 'Volkswagen Beetle Hatchback 2012'
# 'Volkswagen Golf Hatchback 1991'
# 'Volkswagen Golf Hatchback 2012'
# 'Volvo 240 Sedan 1993'
# 'Volvo C30 Hatchback 2012'
# 'Volvo XC90 SUV 2007'

# %%
# !ls '/content/drive/MyDrive/MachineLearning/CapstoneProject/Dataset_1/Dataset/Car Images//Train Images/Jeep Liberty SUV 2012' | head -3
# Out:
# 00119.jpg
# 00299.jpg
# 00343.jpg

# %%
import pandas as pd
annotations_df = pd.read_csv("/content/drive/MyDrive/MachineLearning/CapstoneProject/Dataset/Annotations/Train Annotations.csv")
annotations_df.rename(columns = {'Bounding Box coordinates':'xmin'}, inplace = True)
annotations_df.rename(columns = {'Unnamed: 2':'ymin'}, inplace = True)
annotations_df.rename(columns = {'Unnamed: 3':'xmax'}, inplace = True)
annotations_df.rename(columns = {'Unnamed: 4':'ymax'}, inplace = True)
annotations_df.rename(columns = {'Image class':'Image_class'}, inplace = True)
annotations_df.rename(columns = {'Image Name':'Image_Name'}, inplace = True)
annotations_df
# Out:
#      Image_Name  xmin  ymin  xmax  ymax  Image_class
# 0     00001.jpg    39   116   569   375           14
# 1     00002.jpg    36   116   868   587            3
# 2     00003.jpg    85   109   601   381           91
# 3     00004.jpg   621   393  1484  1096          134
# 4     00005.jpg    14    36   133    99          106
# ...         ...   ...   ...   ...   ...          ...
# 8139  08140.jpg     3    44   423   336           78
# 8140  08141.jpg   138   150   706   523          196
# 8141  08142.jpg    26   246   660   449          163
# 8142  08143.jpg    78   526  1489   908          112
# 8143  08144.jpg    20   240   862   677           17
#
# [8144 rows x 6 columns]

# %%
import pandas as pd
import os
import glob

#/content/drive/MyDrive/MachineLearning/CapstoneProject/Dataset_1/Dataset/Car Images/Samples/Jeep Liberty SUV 2012/00271.jpg
mypath="/content/drive/MyDrive/MachineLearning/CapstoneProject/Dataset_1/Dataset/"
#reading png files in the path
ll = glob.glob(mypath + "Car Images//Train Images/*/*")
print(ll)

ll1 = []
for fileandFolder in ll:
  ll2 = fileandFolder.split("/")[-2:]
  ll1.append(ll2)
# Out:
# ['/content/drive/MyDrive/MachineLearning/CapstoneProject/Dataset_1/Dataset/Car Images//Train Images/Volvo 240 Sedan 1993/02344.jpg', '/content/drive/MyDrive/MachineLearning/CapstoneProject/Dataset_1/Dataset/Car Images//Train Images/Volvo 240 Sedan 1993/01431.jpg', '/content/drive/MyDrive/MachineLearning/CapstoneProject/Dataset_1/Dataset/Car Images//Train Images/Volvo 240 Sedan 1993/07067.jpg', '/content/drive/MyDrive/MachineLearning/CapstoneProject/Dataset_1/Dataset/Car Images//Train Images/Volvo 240 Sedan 1993/01853.jpg', '/content/drive/MyDrive/MachineLearning/CapstoneProject/Dataset_1/Dataset/Car Images//Train Images/Volvo 240 Sedan 1993/05376.jpg', '/content/drive/MyDrive/MachineLearning/CapstoneProject/Dataset_1/Dataset/Car Images//Train Images/Volvo 240 Sedan 1993/03613.jpg', '/content/drive/MyDrive/MachineLearning/CapstoneProject/Dataset_1/Dataset/Car Images//Train Images/Volvo 240 Sedan 1993/04538.jpg', '/content/drive/MyDrive/MachineLearning/CapstoneProject/Dataset_1/Dataset/Car Images//Train Images/Volvo 240 Sedan 1993/07900.jpg', '/content/drive/MyDrive/MachineLearning/CapstoneProject/Dataset_1/Dataset/Car Images//Train Images/Volvo 240 Sedan 1993/06260.jpg', '/content/drive/MyDrive/MachineLearning/CapstoneProject/Dataset_1/Dataset/Car Images//Train Images/Volvo 240 Sedan 1993/03345.jpg', '/content/drive/MyDrive/MachineLearning/CapstoneProject/Dataset_1/Dataset/Car Images//Train Images/Volvo 240 Sedan 1993/01015.jpg', '/content/drive/MyDrive/MachineLearning/CapstoneProject/Dataset_1/Dataset/Car Images//Train Images/Volvo 240 Sedan 1993/07702.jpg', '/content/drive/MyDrive/MachineLearning/CapstoneProject/Dataset_1/Dataset/Car Images//Train Images/Volvo 240 Sedan 1993/06127.jpg', '/content/drive/MyDrive/MachineLearning/CapstoneProject/Dataset_1/Dataset/Car Images//Train Images/Volvo 240 Sedan 1993/05292.jpg', '/content/drive/MyDrive/MachineLearning/CapstoneProject/Dataset_1/Dataset/Car Images//Train Images/Volvo 240 Sedan 1993/01992.jpg', '/content/drive/MyDrive/MachineLearning/CapstoneProject/Dataset_1/Dataset/Car Images//Train Images/Volvo 240 Sedan 1993/01814.jpg', '/content/drive/MyDrive/MachineLearning/CapstoneProject/Dataset_1/Dataset/Car Images//Train Images/Volvo 240 Sedan 1993/00455.jpg', '/content/drive/MyDrive/MachineLearning/CapstoneProject/Dataset_1/Dataset/Car Images//Train Images/Volvo 240 Sedan 1993/02051.jpg', '/content/drive/MyDrive/MachineLearning/CapstoneProject/Dataset_1/Dataset/Car Images//Train Images/Volvo 240 Sedan 1993/00047.jpg', '/content/drive/MyDrive/MachineLearning/CapstoneProject/Dataset_1/Dataset/Car Images//Train Images/Volvo 240 Sedan 1993/04215.jpg', '/content/drive/MyDrive/MachineLearning/CapstoneProject/Dataset_1/Dataset/Car Images//Train Images/Volvo 240 Sedan 1993/05625.jpg', '/content/drive/MyDrive/MachineLearning/CapstoneProject/Dataset_1/Dataset/Car Images//Train Images/Volvo 240 Sedan 1993/01908.jpg', '/content/drive/MyDrive/MachineLearning/CapstoneProject/Dataset_1/Dataset/Car Images//Train Images/Volvo 240 Sedan 1993/00285.jpg', '/content/drive/MyDrive/MachineLearning/CapstoneProject/Dataset_1/Dataset/Car Images//Train Images/Volvo 240 Sedan 1993/02067.jpg', '/content/drive/MyDrive/MachineLearning/CapstoneProject/Dataset_1/Dataset/Car Images//Train Images/Volvo 240 Sedan 1993/07633.jpg', '/content/drive/MyDrive/MachineLearning/CapstoneProject/Dataset_1/Dataset/Car Images//Train Images/Volvo 240 Sedan 1993/00025.jpg', '/content/drive/MyDrive/MachineLearning/CapstoneProject/Dataset_1/Dataset/Car Images//Train Images/Volvo 240 Sedan 1993/07858.jpg', '/content/drive/MyDrive/MachineLearning/CapstoneProject/Dataset_1/Dataset/Car Images//Train Images/Volvo 240 Sedan 1993/00426.jpg', '/content/drive/MyDrive/MachineLearning/CapstoneProject/Dataset_1/Dataset/Car Images//Train Images/Volvo 240 Sedan 1993/01844.jpg', '/content/drive/MyDrive/MachineLearning/CapstoneProject/Dataset_1/Dataset/Car Images//Train Images/Volvo 240 Sedan 1993/03785.jpg', '/content/drive/MyDrive/MachineLearning ...

# %%
df = pd.DataFrame(ll1, columns = ['carName','imageName'])
df['carModel'] = df['carName'].str[-4:]
df['carModel_1'] = df['carName'].str[:-4]
df[['carName','carModel','carModel_1','imageName']]
# Out:
#                        carName carModel            carModel_1  imageName
# 0         Volvo 240 Sedan 1993     1993      Volvo 240 Sedan   02344.jpg
# 1         Volvo 240 Sedan 1993     1993      Volvo 240 Sedan   01431.jpg
# 2         Volvo 240 Sedan 1993     1993      Volvo 240 Sedan   07067.jpg
# 3         Volvo 240 Sedan 1993     1993      Volvo 240 Sedan   01853.jpg
# 4         Volvo 240 Sedan 1993     1993      Volvo 240 Sedan   05376.jpg
# ...                        ...      ...                   ...        ...
# 8139  Volvo C30 Hatchback 2012     2012  Volvo C30 Hatchback   06111.jpg
# 8140  Volvo C30 Hatchback 2012     2012  Volvo C30 Hatchback   07373.jpg
# 8141  Volvo C30 Hatchback 2012     2012  Volvo C30 Hatchback   07454.jpg
# 8142  Volvo C30 Hatchback 2012     2012  Volvo C30 Hatchback   06442.jpg
# 8143  Volvo C30 Hatchback 2012     2012  Volvo C30 Hatchback   05438.jpg
#
# [8144 rows x 4 columns]

# %%
dfMerged = df.merge(annotations_df, how='inner', left_on='imageName', right_on='Image_Name')
dfMerged = dfMerged.assign(image_path='/content/drive/MyDrive/MachineLearning/CapstoneProject/Dataset_1/Dataset/Car Images//Train Images/')

# %%
dfMerged['carName_11'] = dfMerged['carName'].str.replace(' ', '')

# %%
dfMerged
# Out:
#                        carName  ...             carName_11
# 0         Volvo 240 Sedan 1993  ...      Volvo240Sedan1993
# 1         Volvo 240 Sedan 1993  ...      Volvo240Sedan1993
# 2         Volvo 240 Sedan 1993  ...      Volvo240Sedan1993
# 3         Volvo 240 Sedan 1993  ...      Volvo240Sedan1993
# 4         Volvo 240 Sedan 1993  ...      Volvo240Sedan1993
# ...                        ...  ...                    ...
# 8139  Volvo C30 Hatchback 2012  ...  VolvoC30Hatchback2012
# 8140  Volvo C30 Hatchback 2012  ...  VolvoC30Hatchback2012
# 8141  Volvo C30 Hatchback 2012  ...  VolvoC30Hatchback2012
# 8142  Volvo C30 Hatchback 2012  ...  VolvoC30Hatchback2012
# 8143  Volvo C30 Hatchback 2012  ...  VolvoC30Hatchback2012
#
# [8144 rows x 12 columns]

# %%
len(dfMerged['Image_class'].unique())
# Out:
# 196

# %%
from sklearn import preprocessing
 
# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()
 
# Encode labels in column 'species'.
# df['le_carName']= label_encoder.fit_transform(df[
dfMerged['le_carName']= label_encoder.fit_transform(dfMerged['carName'])

# %%
train_df = dfMerged
#dfMerged.to_csv

# %%
from matplotlib import pyplot as plt
import cv2
import numpy as np
import pandas as pd


#Pickup a random image number
img_num = np.random.randint(0, train_df.shape[0])
# print(train_df.columns)
print(train_df.loc[img_num])
img_path = os.path.join(train_df.loc[img_num,'image_path'],train_df.loc[img_num,'carName'], train_df.loc[img_num,'imageName'])
#Read the image and draw a rectangle as per bounding box information
img = cv2.imread(img_path)
cv2.rectangle(img, 
             (train_df.loc[img_num, 'xmin'],train_df.loc[img_num, 'ymin']),
             (train_df.loc[img_num, 'xmax'],train_df.loc[img_num, 'ymax']), 
             (0,255,0),
             6)
#Convert BGR format (used by opencv to RGB format used by matplotlib)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

#Draw image using matplotlib
plt.suptitle(train_df.loc[img_num, 'carModel_1'])
plt.imshow(img)
plt.show()
# Out:
# carName                                    Ford Focus Sedan 2007
# imageName                                              00974.jpg
# carModel                                                    2007
# carModel_1                                     Ford Focus Sedan
# Image_Name                                             00974.jpg
# xmin                                                          26
# ymin                                                         118
# xmax                                                         445
# ymax                                                         306
# Image_class                                                  115
# image_path     /content/drive/MyDrive/MachineLearning/Capston...
# carName_11                                    FordFocusSedan2007
# le_carName                                                   112
# Name: 4493, dtype: object

# %%
train_df
# Out:
#                        carName  imageName  ...             carName_11 le_carName
# 0         Volvo 240 Sedan 1993  02344.jpg  ...      Volvo240Sedan1993        192
# 1         Volvo 240 Sedan 1993  01431.jpg  ...      Volvo240Sedan1993        192
# 2         Volvo 240 Sedan 1993  07067.jpg  ...      Volvo240Sedan1993        192
# 3         Volvo 240 Sedan 1993  01853.jpg  ...      Volvo240Sedan1993        192
# 4         Volvo 240 Sedan 1993  05376.jpg  ...      Volvo240Sedan1993        192
# ...                        ...        ...  ...                    ...        ...
# 8139  Volvo C30 Hatchback 2012  06111.jpg  ...  VolvoC30Hatchback2012        193
# 8140  Volvo C30 Hatchback 2012  07373.jpg  ...  VolvoC30Hatchback2012        193
# 8141  Volvo C30 Hatchback 2012  07454.jpg  ...  VolvoC30Hatchback2012        193
# 8142  Volvo C30 Hatchback 2012  06442.jpg  ...  VolvoC30Hatchback2012        193
# 8143  Volvo C30 Hatchback 2012  05438.jpg  ...  VolvoC30Hatchback2012        193
#
# [8144 rows x 13 columns]

# %%
train_df["image_file"] = train_df["image_path"] + "/" +  train_df["carName"] + "/" + train_df["imageName"]

# %%
train_df.rename(columns = {'le_carName':'class'}, inplace = True)
train_df
# Out:
#                        carName  ...                                         image_file
# 0         Volvo 240 Sedan 1993  ...  /content/drive/MyDrive/MachineLearning/Capston...
# 1         Volvo 240 Sedan 1993  ...  /content/drive/MyDrive/MachineLearning/Capston...
# 2         Volvo 240 Sedan 1993  ...  /content/drive/MyDrive/MachineLearning/Capston...
# 3         Volvo 240 Sedan 1993  ...  /content/drive/MyDrive/MachineLearning/Capston...
# 4         Volvo 240 Sedan 1993  ...  /content/drive/MyDrive/MachineLearning/Capston...
# ...                        ...  ...                                                ...
# 8139  Volvo C30 Hatchback 2012  ...  /content/drive/MyDrive/MachineLearning/Capston...
# 8140  Volvo C30 Hatchback 2012  ...  /content/drive/MyDrive/MachineLearning/Capston...
# 8141  Volvo C30 Hatchback 2012  ...  /content/drive/MyDrive/MachineLearning/Capston...
# 8142  Volvo C30 Hatchback 2012  ...  /content/drive/MyDrive/MachineLearning/Capston...
# 8143  Volvo C30 Hatchback 2012  ...  /content/drive/MyDrive/MachineLearning/Capston...
#
# [8144 rows x 14 columns]

# %%
#We will build a pandas dataset
# import pandas as pd
df = train_df#pd.DataFrame(columns=['class','image_file'])

# %% [markdown]
# Create Training & Test Dataset

# %%
from sklearn.model_selection import train_test_split
train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)

# %%
train_df.to_csv('/content/drive/MyDrive/MachineLearning/CapstoneProject/tempCSV/train.csv',index=False)
test_df.to_csv('/content/drive/MyDrive/MachineLearning/CapstoneProject/tempCSV/test.csv', index=False)

# %% [markdown]
# ### Read training and test data

# %%
#Read training and test Dataframe
train_df = pd.read_csv('/content/drive/MyDrive/MachineLearning/CapstoneProject/tempCSV/train.csv')
test_df = pd.read_csv('/content/drive/MyDrive/MachineLearning/CapstoneProject/tempCSV/test.csv')

# %%
#Check contents
train_df.sample(n=5)
# Out:
#                               carName  ...                                         image_file
# 4058       Dodge Dakota Club Cab 2007  ...  /content/drive/MyDrive/MachineLearning/Capston...
# 5879       Honda Odyssey Minivan 2007  ...  /content/drive/MyDrive/MachineLearning/Capston...
# 404           BMW Z4 Convertible 2012  ...  /content/drive/MyDrive/MachineLearning/Capston...
# 3775  Chevrolet Tahoe Hybrid SUV 2012  ...  /content/drive/MyDrive/MachineLearning/Capston...
# 3993             Volvo 240 Sedan 1993  ...  /content/drive/MyDrive/MachineLearning/Capston...
#
# [5 rows x 14 columns]

# %%
#Get class names
class_names = train_df['class'].unique().tolist()
print('Car classes: ', class_names)
print('Car classes length : ', len(class_names))
# Out:
# Car classes:  [134, 155, 91, 162, 141, 190, 71, 41, 77, 131, 117, 159, 186, 149, 187, 12, 118, 23, 136, 168, 156, 69, 144, 130, 120, 116, 6, 66, 153, 52, 138, 150, 132, 56, 108, 121, 81, 49, 24, 15, 37, 31, 157, 143, 161, 48, 125, 122, 133, 96, 167, 54, 13, 5, 139, 152, 87, 164, 62, 119, 0, 163, 11, 64, 40, 172, 33, 32, 86, 107, 174, 191, 53, 181, 114, 50, 30, 145, 113, 80, 28, 4, 192, 83, 169, 165, 22, 94, 58, 51, 67, 39, 82, 102, 59, 147, 43, 16, 27, 95, 151, 45, 171, 21, 177, 89, 3, 99, 7, 193, 195, 61, 60, 182, 123, 38, 185, 20, 63, 57, 90, 175, 65, 188, 46, 34, 72, 29, 135, 126, 101, 93, 184, 85, 88, 44, 75, 128, 160, 115, 166, 106, 10, 124, 142, 158, 19, 154, 105, 8, 98, 173, 18, 146, 25, 112, 129, 110, 176, 109, 179, 97, 17, 111, 180, 79, 137, 47, 127, 55, 183, 1, 92, 35, 78, 100, 9, 14, 68, 76, 70, 194, 36, 140, 104, 148, 26, 103, 189, 84, 42, 74, 2, 170, 73, 178]
# Car classes length :  196

# %% [markdown]
# ### Build Batch generator (using ImageDataGenerator)

# %%
import tensorflow as tf
import numpy as np

# %%
#Define some parameters
img_size = 224
img_depth = 3

# %% [markdown]
# Function to normalize image according to Model being used

# %%
def normalize_data(img):
    
    #Normalize for ResNet50
    return tf.keras.applications.resnet50.preprocess_input(img)

# %% [markdown]
# Defime ImageDataGenerator for both Training and Test Separately

# %%
#Define Training Data Generator with augmentations
train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rotation_range=20,
                                                                width_shift_range=0.2,
                                                                height_shift_range=0.2,
                                                                horizontal_flip=True,
                                                                preprocessing_function=normalize_data) #Normalize the data accordingly

#Define Test Data Generator with NO augmentations
test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(preprocessing_function=normalize_data) #Normalize the data accordingly

# %% [markdown]
# Create Data Generators objects for Training and Test

# %%
train_df.head()
# Out:
#                             carName  ...                                         image_file
# 0         Hyundai Santa Fe SUV 2012  ...  /content/drive/MyDrive/MachineLearning/Capston...
# 1       Lincoln Town Car Sedan 2011  ...  /content/drive/MyDrive/MachineLearning/Capston...
# 2            Dodge Durango SUV 2012  ...  /content/drive/MyDrive/MachineLearning/Capston...
# 3  Mercedes-Benz E-Class Sedan 2012  ...  /content/drive/MyDrive/MachineLearning/Capston...
# 4            Infiniti QX56 SUV 2011  ...  /content/drive/MyDrive/MachineLearning/Capston...
#
# [5 rows x 14 columns]

# %%
#Training (from dataframe)
train_generator = train_datagen.flow_from_dataframe(train_df, 
                                                    x_col='image_file', #File path for image
                                                    y_col='carName',           #Class for the image
                                                    target_size=(img_size, img_size), #Image resize dimensions
                                                    batch_size=64)
# Out:
# Found 6515 validated image filenames belonging to 196 classes.

# %%
#Test (from dataframe)
test_generator = test_datagen.flow_from_dataframe(test_df,
                                                  x_col='image_file', #File path for image
                                                  y_col='carName',           #Class for the image
                                                  target_size=(img_size, img_size), #Image resize dimensions
                                                  batch_size=64)
# Out:
# Found 1629 validated image filenames belonging to 196 classes.

# %% [markdown]
# ImageDataGenerator has lot of useful features. Learn more about ImageDataGenerator at https://keras.io/preprocessing/image/

# %% [markdown]
# ### Load pre-trained model

# %%
tf.keras.backend.clear_session()
model = tf.keras.applications.efficientnet.EfficientNetB5(include_top=False, #Do not include classification layer for imagenet
                                       input_shape=(500,500,3),
                                       weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb5_notop.h5
# 115269632/115263384 [==============================] - 1s 0us/step
# 115277824/115263384 [==============================] - 1s 0us/step

# %%
model.summary()
# Out:
# Model: "efficientnetb5"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 500, 500, 3  0           []
#                                 )]
#
#  rescaling (Rescaling)          (None, 500, 500, 3)  0           ['input_1[0][0]']
#
#  normalization (Normalization)  (None, 500, 500, 3)  7           ['rescaling[0][0]']
#
#  stem_conv_pad (ZeroPadding2D)  (None, 501, 501, 3)  0           ['normalization[0][0]']
#
#  stem_conv (Conv2D)             (None, 250, 250, 48  1296        ['stem_conv_pad[0][0]']
#                                 )
#
#  stem_bn (BatchNormalization)   (None, 250, 250, 48  192         ['stem_conv[0][0]']
#                                 )
#
#  stem_activation (Activation)   (None, 250, 250, 48  0           ['stem_bn[0][0]']
#                                 )
#
#  block1a_dwconv (DepthwiseConv2  (None, 250, 250, 48  432        ['stem_activation[0][0]']
#  D)                             )
#
#  block1a_bn (BatchNormalization  (None, 250, 250, 48  192        ['block1a_dwconv[0][0]']
#  )                              )
#
#  block1a_activation (Activation  (None, 250, 250, 48  0          ['block1a_bn[0][0]']
#  )                              )
#
#  block1a_se_squeeze (GlobalAver  (None, 48)          0           ['block1a_activation[0][0]']
#  agePooling2D)
#
#  block1a_se_reshape (Reshape)   (None, 1, 1, 48)     0           ['block1a_se_squeeze[0][0]']
#
#  block1a_se_reduce (Conv2D)     (None, 1, 1, 12)     588         ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)     (None, 1, 1, 48)     624         ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multiply)   (None, 250, 250, 48  0           ['block1a_activation[0][0]',
#                                 )                                 'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv2D)  (None, 250, 250, 24  1152        ['block1a_se_excite[0][0]']
#                                 )
#
#  block1a_project_bn (BatchNorma  (None, 250, 250, 24  96         ['block1a_project_conv[0][0]']
#  lization)                      )
#
#  block1b_dwconv (DepthwiseConv2  (None, 250, 250, 24  216        ['block1a_project_bn[0][0]']
#  D)                             )
#
#  block1b_bn (BatchNormalization  (None, 250, 250, 24  96         ['block1b_dwconv[0][0]']
#  )                              )
#
#  block1b_activation (Activation  (None, 250, 250, 24  0          ['block1b_bn[0][0]']
#  )                              )
#
#  block1b_se_squeeze (GlobalAver  (None, 24)          0           ['block1b_activation[0][0]']
#  agePooling2D)
#
#  block1b_se_reshape (Reshape)   (None, 1, 1, 24)     0           ['block1b_se_squeeze[0][0]']
#
#  block1b_se_reduce (Conv2D)     (None, 1, 1, 6)      150         ['block1b_se_reshape[0][0]']
#
#  block1b_se_expand (Conv2D)     (None, 1, 1, 24)     168         ['block1b_se_reduce[0][0]']
#
#  block1b_se_excite (Multiply)   (None, 250, 250, 24  0           ['block1b_activation[0][0]',
#                                 )                                 'block1b_se_expand[0][0]']
#
#  block1b_project_conv (Conv2D)  (None, 250, 250, 24  576         ['block1b_se_excite[0][0]']
#                                 )
#
#  block1b_project_bn (BatchNorma  (None, 250, 250, 24  96         ['block1b_project_conv[0][0]']
#  lization)                      )
#
#  block1b_drop (Dropout)         (None, 250, 250, 24  0           ['block1b_project_bn[0][0]']
#                                 )
#
#  block1b_add (Add)              (None, 250, 250, 24  0           ['block1b_drop[0][0]',
#                                 )                                 'block1a_project_bn[0][0]']
#
#  block1c_dwconv (DepthwiseConv2  (None, 250, 250, 24  216        ['block1b_add[0][0]']
#  D)                             )
#
#  block1c_bn (BatchNormalization  (None, 250, 250, 24  96         ['block1c_dwconv[0][0]']
#  )                              )
#
#  block1c_activation (Activation  (None, 250, 250, 24  0          ['block1c_bn[0][0]']
#  )                              )
#
#  block1c_se_squeeze (GlobalAver  (None, 24)          0           ['block1c_activation[0][0]']
#  agePooling2D)
#
#  block1c_se_reshape (Reshape)   (None, 1, 1, 24)     0           ['block1c_se_squeeze[0][0]']
#
#  block1c_se_reduce (Conv2D)     (None, 1, 1, 6)      150         ['block1c_se_reshape[0][0]']
#
#  block1c_se_expand (Conv2D)     (None, 1, 1, 24)     168         ['block1c_se_reduce[0][0]']
#
#  block1c_se_excite (Multiply)   (None, 250, 250, 24  0           ['block1c_activation[0][0]',
#                                 )                                 'block1c_se_expand[0][0]']
#
#  block1c_project_conv (Conv2D)  (None, 250, 250, 24  576         ['block1c_se_excite[0][0]']
#                                 )
#
#  block1c_project_bn (BatchNorma  (None, 250, 250, 24  96         ['block1c_project_conv[0][0]']
#  lization)                      )
#
#  block1c_drop (Dropout)         (None, 250, 250, 24  0           ['block1c_project_bn[0][0]']
#                                 )
#
#  block1c_add (Add)              (None, 250, 250, 24  0           ['block1c_drop[0][0]',
#                                 )                                 'block1b_add[0][0]']
#
#  block2a_expand_conv (Conv2D)   (None, 250, 250, 14  3456        ['block1c_add[0][0]']
#                                 4)
#
#  block2a_expand_bn (BatchNormal  (None, 250, 250, 14  576        ['block2a_expand_conv[0][0]']
#  ization)                       4)
#
#  block2a_expand_activation (Act  (None, 250, 250, 14  0          ['block2a_expand_bn[0][0]']
#  ivation)                       4)
#
#  block2a_dwconv_pad (ZeroPaddin  (None, 251, 251, 14  0          ['block2a_expand_activation[0][0]
#  g2D)                           4)                               ']
#
#  block2a_dwconv (DepthwiseConv2  (None, 125, 125, 14  1296       ['block2a_dwconv_pad[0][0]']
#  D)                             4)
#
#  block2a_bn (BatchNormalization  (None, 125, 125, 14  576        ['block2a_dwconv[0][0]']
#  )                              4)
#
#  block2a_activation (Activation  (None, 125, 125, 14  0          ['block2a_bn[0][0]']
#  )                              4)
#
#  block2a_se_squeeze (GlobalAver  (None, 144)         0           ['block2a_activation[0][0]']
#  agePooling2D)
#
#  block2a_se_reshape (Reshape)   (None, 1, 1, 144)    0           ['block2a_se_squeeze[0][0]']
#
#  block2a_se_reduce (Conv2D)     (None, 1, 1, 6)      870         ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)     (None, 1, 1, 144)    1008        ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multiply)   (None, 125, 125, 14  0           ['block2a_activation[0][0]',
#                                 4)                                'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv2D)  (None, 125, 125, 40  5760        ['block2a_se_excite[0][0]']
#                                 )
#
#  block2a_project_bn (BatchNorma  (None, 125, 125, 40  160        ['block2a_project_conv[0][0]']
#  lization)                      )
#
#  block2b_expand_conv (Conv2D)   (None, 125, 125, 24  9600        ['block2a_project_bn[0][0]']
#                                 0)
#
#  block2b_expand_bn (BatchNormal  (None, 125, 125, 24  960        ['block2b_expand_conv[0][0]']
#  ization)                       0)
#
#  block2b_expand_activation (Act  (None, 125, 125, 24  0          ['block2b_expand_bn[0][0]']
#  ivation)                       0)
#
#  block2b_dwconv (DepthwiseConv2  (None, 125, 125, 24  2160       ['block2b_expand_activation[0][0]
#  D)                             0)                               ']
#
#  block2b_bn (BatchNormalization  (None, 125, 125, 24  960        ['block2b_dwconv[0][0]']
#  )                              0)
#
#  block2b_activation (Activation  (None, 125, 125, 24  0          ['block2b_bn[0][0]']
#  )                              0)
#
#  block2b_se_squeeze (GlobalAver  (None, 240)         0           ['block2b_activation[0][0]']
#  agePooling2D)
#
#  block2b_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block2b_se_squeeze[0][0]']
#
#  block2b_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multiply)   (None, 125, 125, 24  0           ['block2b_activation[0][0]',
#                                 0)                                'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv2D)  (None, 125, 125, 40  9600        ['block2b_se_excite[0][0]']
#                                 )
#
#  block2b_project_bn (BatchNorma  (None, 125, 125, 40  160        ['block2b_project_conv[0][0]']
#  lization)                      )
#
#  block2b_drop (Dropout)         (None, 125, 125, 40  0           ['block2b_project_bn[0][0]']
#                                 )
#
#  block2b_add (Add)              (None, 125, 125, 40  0           ['block2b_drop[0][0]',
#                                 )                                 'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2D)   (None, 125, 125, 24  9600        ['block2b_add[0][0]']
#                                 0)
#
#  block2c_expand_bn (BatchNormal  (None, 125, 125, 24  960        ['block2c_expand_conv[0][0]']
#  ization)                       0)
#
#  block2c_expand_activation (Act  (None, 125, 125, 24  0          ['block2c_expand_bn[0][0]']
#  ivation)                       0)
#
#  block2c_dwconv (DepthwiseConv2  (None, 125, 125, 24  2160       ['block2c_expand_activation[0][0]
#  D)                             0)                               ']
#
#  block2c_bn (BatchNormalization  (None, 125, 125, 24  960        ['block2c_dwconv[0][0]']
#  )                              0)
#
#  block2c_activation (Activation  (None, 125, 125, 24  0          ['block2c_bn[0][0]']
#  )                              0)
#
#  block2c_se_squeeze (GlobalAver  (None, 240)         0           ['block2c_activation[0][0]']
#  agePooling2D)
#
#  block2c_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block2c_se_squeeze[0][0]']
#
#  block2c_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block2c_se_reshape[0][0]']
#
#  block2c_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block2c_se_reduce[0][0]']
#
#  block2c_se_excite (Multiply)   (None, 125, 125, 24  0           ['block2c_activation[0][0]',
#                                 0)                                'block2c_se_expand[0][0]']
#
#  block2c_project_conv (Conv2D)  (None, 125, 125, 40  9600        ['block2c_se_excite[0][0]']
#                                 )
#
#  block2c_project_bn (BatchNorma  (None, 125, 125, 40  160        ['block2c_project_conv[0][0]']
#  lization)                      )
#
#  block2c_drop (Dropout)         (None, 125, 125, 40  0           ['block2c_project_bn[0][0]']
#                                 )
#
#  block2c_add (Add)              (None, 125, 125, 40  0           ['block2c_drop[0][0]',
#                                 )                                 'block2b_add[0][0]']
#
#  block2d_expand_conv (Conv2D)   (None, 125, 125, 24  9600        ['block2c_add[0][0]']
#                                 0)
#
#  block2d_expand_bn (BatchNormal  (None, 125, 125, 24  960        ['block2d_expand_conv[0][0]']
#  ization)                       0)
#
#  block2d_expand_activation (Act  (None, 125, 125, 24  0          ['block2d_expand_bn[0][0]']
#  ivation)                       0)
#
#  block2d_dwconv (DepthwiseConv2  (None, 125, 125, 24  2160       ['block2d_expand_activation[0][0]
#  D)                             0)                               ']
#
#  block2d_bn (BatchNormalization  (None, 125, 125, 24  960        ['block2d_dwconv[0][0]']
#  )                              0)
#
#  block2d_activation (Activation  (None, 125, 125, 24  0          ['block2d_bn[0][0]']
#  )                              0)
#
#  block2d_se_squeeze (GlobalAver  (None, 240)         0           ['block2d_activation[0][0]']
#  agePooling2D)
#
#  block2d_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block2d_se_squeeze[0][0]']
#
#  block2d_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block2d_se_reshape[0][0]']
#
#  block2d_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block2d_se_reduce[0][0]']
#
#  block2d_se_excite (Multiply)   (None, 125, 125, 24  0           ['block2d_activation[0][0]',
#                                 0)                                'block2d_se_expand[0][0]']
#
#  block2d_project_conv (Conv2D)  (None, 125, 125, 40  9600        ['block2d_se_excite[0][0]']
#                                 )
#
#  block2d_project_bn (BatchNorma  (None, 125, 125, 40  160        ['block2d_project_conv[0][0]']
#  lization)                      )
#
#  block2d_drop (Dropout)         (None, 125, 125, 40  0           ['block2d_project_bn[0][0]']
#                                 )
#
#  block2d_add (Add)              (None, 125, 125, 40  0           ['block2d_drop[0][0]',
#                                 )                                 'block2c_add[0][0]']
#
#  block2e_expand_conv (Conv2D)   (None, 125, 125, 24  9600        ['block2d_add[0][0]']
#                                 0)
#
#  block2e_expand_bn (BatchNormal  (None, 125, 125, 24  960        ['block2e_expand_conv[0][0]']
#  ization)                       0)
#
#  block2e_expand_activation (Act  (None, 125, 125, 24  0          ['block2e_expand_bn[0][0]']
#  ivation)                       0)
#
#  block2e_dwconv (DepthwiseConv2  (None, 125, 125, 24  2160       ['block2e_expand_activation[0][0]
#  D)                             0)                               ']
#
#  block2e_bn (BatchNormalization  (None, 125, 125, 24  960        ['block2e_dwconv[0][0]']
#  )                              0)
#
#  block2e_activation (Activation  (None, 125, 125, 24  0          ['block2e_bn[0][0]']
#  )                              0)
#
#  block2e_se_squeeze (GlobalAver  (None, 240)         0           ['block2e_activation[0][0]']
#  agePooling2D)
#
#  block2e_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block2e_se_squeeze[0][0]']
#
#  block2e_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block2e_se_reshape[0][0]']
#
#  block2e_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block2e_se_reduce[0][0]']
#
#  block2e_se_excite (Multiply)   (None, 125, 125, 24  0           ['block2e_activation[0][0]',
#                                 0)                                'block2e_se_expand[0][0]']
#
#  block2e_project_conv (Conv2D)  (None, 125, 125, 40  9600        ['block2e_se_excite[0][0]']
#                                 )
#
#  block2e_project_bn (BatchNorma  (None, 125, 125, 40  160        ['block2e_project_conv[0][0]']
#  lization)                      )
#
#  block2e_drop (Dropout)         (None, 125, 125, 40  0           ['block2e_project_bn[0][0]']
#                                 )
#
#  block2e_add (Add)              (None, 125, 125, 40  0           ['block2e_drop[0][0]',
#                                 )                                 'block2d_add[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, 125, 125, 24  9600        ['block2e_add[0][0]']
#                                 0)
#
#  block3a_expand_bn (BatchNormal  (None, 125, 125, 24  960        ['block3a_expand_conv[0][0]']
#  ization)                       0)
#
#  block3a_expand_activation (Act  (None, 125, 125, 24  0          ['block3a_expand_bn[0][0]']
#  ivation)                       0)
#
#  block3a_dwconv_pad (ZeroPaddin  (None, 129, 129, 24  0          ['block3a_expand_activation[0][0]
#  g2D)                           0)                               ']
#
#  block3a_dwconv (DepthwiseConv2  (None, 63, 63, 240)  6000       ['block3a_dwconv_pad[0][0]']
#  D)
#
#  block3a_bn (BatchNormalization  (None, 63, 63, 240)  960        ['block3a_dwconv[0][0]']
#  )
#
#  block3a_activation (Activation  (None, 63, 63, 240)  0          ['block3a_bn[0][0]']
#  )
#
#  block3a_se_squeeze (GlobalAver  (None, 240)         0           ['block3a_activation[0][0]']
#  agePooling2D)
#
#  block3a_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block3a_se_squeeze[0][0]']
#
#  block3a_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multiply)   (None, 63, 63, 240)  0           ['block3a_activation[0][0]',
#                                                                   'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv2D)  (None, 63, 63, 64)   15360       ['block3a_se_excite[0][0]']
#
#  block3a_project_bn (BatchNorma  (None, 63, 63, 64)  256         ['block3a_project_conv[0][0]']
#  lization)
#
#  block3b_expand_conv (Conv2D)   (None, 63, 63, 384)  24576       ['block3a_project_bn[0][0]']
#
#  block3b_expand_bn (BatchNormal  (None, 63, 63, 384)  1536       ['block3b_expand_conv[0][0]']
#  ization)
#
#  block3b_expand_activation (Act  (None, 63, 63, 384)  0          ['block3b_expand_bn[0][0]']
#  ivation)
#
#  block3b_dwconv (DepthwiseConv2  (None, 63, 63, 384)  9600       ['block3b_expand_activation[0][0]
#  D)                                                              ']
#
#  block3b_bn (BatchNormalization  (None, 63, 63, 384)  1536       ['block3b_dwconv[0][0]']
#  )
#
#  block3b_activation (Activation  (None, 63, 63, 384)  0          ['block3b_bn[0][0]']
#  )
#
#  block3b_se_squeeze (GlobalAver  (None, 384)         0           ['block3b_activation[0][0]']
#  agePooling2D)
#
#  block3b_se_reshape (Reshape)   (None, 1, 1, 384)    0           ['block3b_se_squeeze[0][0]']
#
#  block3b_se_reduce (Conv2D)     (None, 1, 1, 16)     6160        ['block3b_se_reshape[0][0]']
#
#  block3b_se_expand (Conv2D)     (None, 1, 1, 384)    6528        ['block3b_se_reduce[0][0]']
#
#  block3b_se_excite (Multiply)   (None, 63, 63, 384)  0           ['block3b_activation[0][0]',
#                                                                   'block3b_se_expand[0][0]']
#
#  block3b_project_conv (Conv2D)  (None, 63, 63, 64)   24576       ['block3b_se_excite[0][0]']
#
#  block3b_project_bn (BatchNorma  (None, 63, 63, 64)  256         ['block3b_project_conv[0][0]']
#  lization)
#
#  block3b_drop (Dropout)         (None, 63, 63, 64)   0           ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)              (None, 63, 63, 64)   0           ['block3b_drop[0][0]',
#                                                                   'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2D)   (None, 63, 63, 384)  24576       ['block3b_add[0][0]']
#
#  block3c_expand_bn (BatchNormal  (None, 63, 63, 384)  1536       ['block3c_expand_conv[0][0]']
#  ization)
#
#  block3c_expand_activation (Act  (None, 63, 63, 384)  0          ['block3c_expand_bn[0][0]']
#  ivation)
#
#  block3c_dwconv (DepthwiseConv2  (None, 63, 63, 384)  9600       ['block3c_expand_activation[0][0]
#  D)                                                              ']
#
#  block3c_bn (BatchNormalization  (None, 63, 63, 384)  1536       ['block3c_dwconv[0][0]']
#  )
#
#  block3c_activation (Activation  (None, 63, 63, 384)  0          ['block3c_bn[0][0]']
#  )
#
#  block3c_se_squeeze (GlobalAver  (None, 384)         0           ['block3c_activation[0][0]']
#  agePooling2D)
#
#  block3c_se_reshape (Reshape)   (None, 1, 1, 384)    0           ['block3c_se_squeeze[0][0]']
#
#  block3c_se_reduce (Conv2D)     (None, 1, 1, 16)     6160        ['block3c_se_reshape[0][0]']
#
#  block3c_se_expand (Conv2D)     (None, 1, 1, 384)    6528        ['block3c_se_reduce[0][0]']
#
#  block3c_se_excite (Multiply)   (None, 63, 63, 384)  0           ['block3c_activation[0][0]',
#                                                                   'block3c_se_expand[0][0]']
#
#  block3c_project_conv (Conv2D)  (None, 63, 63, 64)   24576       ['block3c_se_excite[0][0]']
#
#  block3c_project_bn (BatchNorma  (None, 63, 63, 64)  256         ['block3c_project_conv[0][0]']
#  lization)
#
#  block3c_drop (Dropout)         (None, 63, 63, 64)   0           ['block3c_project_bn[0][0]']
#
#  block3c_add (Add)              (None, 63, 63, 64)   0           ['block3c_drop[0][0]',
#                                                                   'block3b_add[0][0]']
#
#  block3d_expand_conv (Conv2D)   (None, 63, 63, 384)  24576       ['block3c_add[0][0]']
#
#  block3d_expand_bn (BatchNormal  (None, 63, 63, 384)  1536       ['block3d_expand_conv[0][0]']
#  ization)
#
#  block3d_expand_activation (Act  (None, 63, 63, 384)  0          ['block3d_expand_bn[0][0]']
#  ivation)
#
#  block3d_dwconv (DepthwiseConv2  (None, 63, 63, 384)  9600       ['block3d_expand_activation[0][0]
#  D)                                                              ']
#
#  block3d_bn (BatchNormalization  (None, 63, 63, 384)  1536       ['block3d_dwconv[0][0]']
#  )
#
#  block3d_activation (Activation  (None, 63, 63, 384)  0          ['block3d_bn[0][0]']
#  )
#
#  block3d_se_squeeze (GlobalAver  (None, 384)         0           ['block3d_activation[0][0]']
#  agePooling2D)
#
#  block3d_se_reshape (Reshape)   (None, 1, 1, 384)    0           ['block3d_se_squeeze[0][0]']
#
#  block3d_se_reduce (Conv2D)     (None, 1, 1, 16)     6160        ['block3d_se_reshape[0][0]']
#
#  block3d_se_expand (Conv2D)     (None, 1, 1, 384)    6528        ['block3d_se_reduce[0][0]']
#
#  block3d_se_excite (Multiply)   (None, 63, 63, 384)  0           ['block3d_activation[0][0]',
#                                                                   'block3d_se_expand[0][0]']
#
#  block3d_project_conv (Conv2D)  (None, 63, 63, 64)   24576       ['block3d_se_excite[0][0]']
#
#  block3d_project_bn (BatchNorma  (None, 63, 63, 64)  256         ['block3d_project_conv[0][0]']
#  lization)
#
#  block3d_drop (Dropout)         (None, 63, 63, 64)   0           ['block3d_project_bn[0][0]']
#
#  block3d_add (Add)              (None, 63, 63, 64)   0           ['block3d_drop[0][0]',
#                                                                   'block3c_add[0][0]']
#
#  block3e_expand_conv (Conv2D)   (None, 63, 63, 384)  24576       ['block3d_add[0][0]']
#
#  block3e_expand_bn (BatchNormal  (None, 63, 63, 384)  1536       ['block3e_expand_conv[0][0]']
#  ization)
#
#  block3e_expand_activation (Act  (None, 63, 63, 384)  0          ['block3e_expand_bn[0][0]']
#  ivation)
#
# ...
#  block6i_expand_activation (Act  (None, 16, 16, 1824  0          ['block6i_expand_bn[0][0]']
#  ivation)                       )
#
#  block6i_dwconv (DepthwiseConv2  (None, 16, 16, 1824  45600      ['block6i_expand_activation[0][0]
#  D)                             )                                ']
#
#  block6i_bn (BatchNormalization  (None, 16, 16, 1824  7296       ['block6i_dwconv[0][0]']
#  )                              )
#
#  block6i_activation (Activation  (None, 16, 16, 1824  0          ['block6i_bn[0][0]']
#  )                              )
#
#  block6i_se_squeeze (GlobalAver  (None, 1824)        0           ['block6i_activation[0][0]']
#  agePooling2D)
#
#  block6i_se_reshape (Reshape)   (None, 1, 1, 1824)   0           ['block6i_se_squeeze[0][0]']
#
#  block6i_se_reduce (Conv2D)     (None, 1, 1, 76)     138700      ['block6i_se_reshape[0][0]']
#
#  block6i_se_expand (Conv2D)     (None, 1, 1, 1824)   140448      ['block6i_se_reduce[0][0]']
#
#  block6i_se_excite (Multiply)   (None, 16, 16, 1824  0           ['block6i_activation[0][0]',
#                                 )                                 'block6i_se_expand[0][0]']
#
#  block6i_project_conv (Conv2D)  (None, 16, 16, 304)  554496      ['block6i_se_excite[0][0]']
#
#  block6i_project_bn (BatchNorma  (None, 16, 16, 304)  1216       ['block6i_project_conv[0][0]']
#  lization)
#
#  block6i_drop (Dropout)         (None, 16, 16, 304)  0           ['block6i_project_bn[0][0]']
#
#  block6i_add (Add)              (None, 16, 16, 304)  0           ['block6i_drop[0][0]',
#                                                                   'block6h_add[0][0]']
#
#  block7a_expand_conv (Conv2D)   (None, 16, 16, 1824  554496      ['block6i_add[0][0]']
#                                 )
#
#  block7a_expand_bn (BatchNormal  (None, 16, 16, 1824  7296       ['block7a_expand_conv[0][0]']
#  ization)                       )
#
#  block7a_expand_activation (Act  (None, 16, 16, 1824  0          ['block7a_expand_bn[0][0]']
#  ivation)                       )
#
#  block7a_dwconv (DepthwiseConv2  (None, 16, 16, 1824  16416      ['block7a_expand_activation[0][0]
#  D)                             )                                ']
#
#  block7a_bn (BatchNormalization  (None, 16, 16, 1824  7296       ['block7a_dwconv[0][0]']
#  )                              )
#
#  block7a_activation (Activation  (None, 16, 16, 1824  0          ['block7a_bn[0][0]']
#  )                              )
#
#  block7a_se_squeeze (GlobalAver  (None, 1824)        0           ['block7a_activation[0][0]']
#  agePooling2D)
#
#  block7a_se_reshape (Reshape)   (None, 1, 1, 1824)   0           ['block7a_se_squeeze[0][0]']
#
#  block7a_se_reduce (Conv2D)     (None, 1, 1, 76)     138700      ['block7a_se_reshape[0][0]']
#
#  block7a_se_expand (Conv2D)     (None, 1, 1, 1824)   140448      ['block7a_se_reduce[0][0]']
#
#  block7a_se_excite (Multiply)   (None, 16, 16, 1824  0           ['block7a_activation[0][0]',
#                                 )                                 'block7a_se_expand[0][0]']
#
#  block7a_project_conv (Conv2D)  (None, 16, 16, 512)  933888      ['block7a_se_excite[0][0]']
#
#  block7a_project_bn (BatchNorma  (None, 16, 16, 512)  2048       ['block7a_project_conv[0][0]']
#  lization)
#
#  block7b_expand_conv (Conv2D)   (None, 16, 16, 3072  1572864     ['block7a_project_bn[0][0]']
#                                 )
#
#  block7b_expand_bn (BatchNormal  (None, 16, 16, 3072  12288      ['block7b_expand_conv[0][0]']
#  ization)                       )
#
#  block7b_expand_activation (Act  (None, 16, 16, 3072  0          ['block7b_expand_bn[0][0]']
#  ivation)                       )
#
#  block7b_dwconv (DepthwiseConv2  (None, 16, 16, 3072  27648      ['block7b_expand_activation[0][0]
#  D)                             )                                ']
#
#  block7b_bn (BatchNormalization  (None, 16, 16, 3072  12288      ['block7b_dwconv[0][0]']
#  )                              )
#
#  block7b_activation (Activation  (None, 16, 16, 3072  0          ['block7b_bn[0][0]']
#  )                              )
#
#  block7b_se_squeeze (GlobalAver  (None, 3072)        0           ['block7b_activation[0][0]']
#  agePooling2D)
#
#  block7b_se_reshape (Reshape)   (None, 1, 1, 3072)   0           ['block7b_se_squeeze[0][0]']
#
#  block7b_se_reduce (Conv2D)     (None, 1, 1, 128)    393344      ['block7b_se_reshape[0][0]']
#
#  block7b_se_expand (Conv2D)     (None, 1, 1, 3072)   396288      ['block7b_se_reduce[0][0]']
#
#  block7b_se_excite (Multiply)   (None, 16, 16, 3072  0           ['block7b_activation[0][0]',
#                                 )                                 'block7b_se_expand[0][0]']
#
#  block7b_project_conv (Conv2D)  (None, 16, 16, 512)  1572864     ['block7b_se_excite[0][0]']
#
#  block7b_project_bn (BatchNorma  (None, 16, 16, 512)  2048       ['block7b_project_conv[0][0]']
#  lization)
#
#  block7b_drop (Dropout)         (None, 16, 16, 512)  0           ['block7b_project_bn[0][0]']
#
#  block7b_add (Add)              (None, 16, 16, 512)  0           ['block7b_drop[0][0]',
#                                                                   'block7a_project_bn[0][0]']
#
#  block7c_expand_conv (Conv2D)   (None, 16, 16, 3072  1572864     ['block7b_add[0][0]']
#                                 )
#
#  block7c_expand_bn (BatchNormal  (None, 16, 16, 3072  12288      ['block7c_expand_conv[0][0]']
#  ization)                       )
#
#  block7c_expand_activation (Act  (None, 16, 16, 3072  0          ['block7c_expand_bn[0][0]']
#  ivation)                       )
#
#  block7c_dwconv (DepthwiseConv2  (None, 16, 16, 3072  27648      ['block7c_expand_activation[0][0]
#  D)                             )                                ']
#
#  block7c_bn (BatchNormalization  (None, 16, 16, 3072  12288      ['block7c_dwconv[0][0]']
#  )                              )
#
#  block7c_activation (Activation  (None, 16, 16, 3072  0          ['block7c_bn[0][0]']
#  )                              )
#
#  block7c_se_squeeze (GlobalAver  (None, 3072)        0           ['block7c_activation[0][0]']
#  agePooling2D)
#
#  block7c_se_reshape (Reshape)   (None, 1, 1, 3072)   0           ['block7c_se_squeeze[0][0]']
#
#  block7c_se_reduce (Conv2D)     (None, 1, 1, 128)    393344      ['block7c_se_reshape[0][0]']
#
#  block7c_se_expand (Conv2D)     (None, 1, 1, 3072)   396288      ['block7c_se_reduce[0][0]']
#
#  block7c_se_excite (Multiply)   (None, 16, 16, 3072  0           ['block7c_activation[0][0]',
#                                 )                                 'block7c_se_expand[0][0]']
#
#  block7c_project_conv (Conv2D)  (None, 16, 16, 512)  1572864     ['block7c_se_excite[0][0]']
#
#  block7c_project_bn (BatchNorma  (None, 16, 16, 512)  2048       ['block7c_project_conv[0][0]']
#  lization)
#
#  block7c_drop (Dropout)         (None, 16, 16, 512)  0           ['block7c_project_bn[0][0]']
#
#  block7c_add (Add)              (None, 16, 16, 512)  0           ['block7c_drop[0][0]',
#                                                                   'block7b_add[0][0]']
#
#  top_conv (Conv2D)              (None, 16, 16, 2048  1048576     ['block7c_add[0][0]']
#                                 )
#
#  top_bn (BatchNormalization)    (None, 16, 16, 2048  8192        ['top_conv[0][0]']
#                                 )
#
#  top_activation (Activation)    (None, 16, 16, 2048  0           ['top_bn[0][0]']
#                                 )
#
# ==================================================================================================
# Total params: 28,513,527
# Trainable params: 28,340,784
# Non-trainable params: 172,743
# __________________________________________________________________________________________________

# %%
model.output
# Out:
# <KerasTensor: shape=(None, 16, 16, 2048) dtype=float32 (created by layer 'top_activation')>

# %% [markdown]
# Freeze the layers in Pre-trained model

# %%
model.layers
# Out:
# [<keras.engine.input_layer.InputLayer at 0x7f9bb6c27590>,
#  <keras.layers.preprocessing.image_preprocessing.Rescaling at 0x7f9bb5b87810>,
#  <keras.layers.preprocessing.normalization.Normalization at 0x7f9bb5b87e10>,
#  <keras.layers.convolutional.ZeroPadding2D at 0x7f9bb5b02950>,
#  <keras.layers.convolutional.Conv2D at 0x7f9bb5b11dd0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9bb5ac0890>,
#  <keras.layers.core.activation.Activation at 0x7f9bb5ac0950>,
#  <keras.layers.convolutional.DepthwiseConv2D at 0x7f9ba0427f90>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9ba0427c10>,
#  <keras.layers.core.activation.Activation at 0x7f9bb5b87ad0>,
#  <keras.layers.pooling.GlobalAveragePooling2D at 0x7f9bb63b6250>,
#  <keras.layers.core.reshape.Reshape at 0x7f9ba0397d50>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba0402410>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba03a4450>,
#  <keras.layers.merge.Multiply at 0x7f9ba03aee90>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba039f510>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9ba03b2250>,
#  <keras.layers.convolutional.DepthwiseConv2D at 0x7f9ba03bfa10>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9ba03b40d0>,
#  <keras.layers.core.activation.Activation at 0x7f9ba03c9ed0>,
#  <keras.layers.pooling.GlobalAveragePooling2D at 0x7f9bb5b110d0>,
#  <keras.layers.core.reshape.Reshape at 0x7f9ba03c94d0>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba03d0ad0>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba039fb10>,
#  <keras.layers.merge.Multiply at 0x7f9ba03631d0>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba0427b10>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9ba0370c90>,
#  <keras.layers.core.dropout.Dropout at 0x7f9ba03797d0>,
#  <keras.layers.merge.Add at 0x7f9ba0374210>,
#  <keras.layers.convolutional.DepthwiseConv2D at 0x7f9ba03794d0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9ba038ea50>,
#  <keras.layers.core.activation.Activation at 0x7f9ba0374c10>,
#  <keras.layers.pooling.GlobalAveragePooling2D at 0x7f9ba037df10>,
#  <keras.layers.core.reshape.Reshape at 0x7f9ba040f810>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba03df9d0>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba03796d0>,
#  <keras.layers.merge.Multiply at 0x7f9bb63e1150>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba031d310>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9ba0314d90>,
#  <keras.layers.core.dropout.Dropout at 0x7f9ba0321150>,
#  <keras.layers.merge.Add at 0x7f9ba0328750>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba032ecd0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9ba0328150>,
#  <keras.layers.core.activation.Activation at 0x7f9ba033c050>,
#  <keras.layers.convolutional.ZeroPadding2D at 0x7f9ba0341210>,
#  <keras.layers.convolutional.DepthwiseConv2D at 0x7f9ba0341f90>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9ba0345690>,
#  <keras.layers.core.activation.Activation at 0x7f9ba02d35d0>,
#  <keras.layers.pooling.GlobalAveragePooling2D at 0x7f9ba02d3dd0>,
#  <keras.layers.core.reshape.Reshape at 0x7f9ba034cbd0>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba03369d0>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba02e9310>,
#  <keras.layers.merge.Multiply at 0x7f9ba02df9d0>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba02ed290>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9ba02f7c10>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba02f7ad0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9ba0345cd0>,
#  <keras.layers.core.activation.Activation at 0x7f9ba02ee2d0>,
#  <keras.layers.convolutional.DepthwiseConv2D at 0x7f9ba0308d50>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9ba0296810>,
#  <keras.layers.core.activation.Activation at 0x7f9ba02a6090>,
#  <keras.layers.pooling.GlobalAveragePooling2D at 0x7f9ba02a6810>,
#  <keras.layers.core.reshape.Reshape at 0x7f9ba02ab4d0>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba02ae250>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba02bb6d0>,
#  <keras.layers.merge.Multiply at 0x7f9ba02bbd90>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba02bf990>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9ba02d04d0>,
#  <keras.layers.core.dropout.Dropout at 0x7f9ba02cb1d0>,
#  <keras.layers.merge.Add at 0x7f9ba02c4150>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba0253690>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9ba025c5d0>,
#  <keras.layers.core.activation.Activation at 0x7f9ba02cbb50>,
#  <keras.layers.convolutional.DepthwiseConv2D at 0x7f9ba0256490>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9ba0308610>,
#  <keras.layers.core.activation.Activation at 0x7f9ba0296a10>,
#  <keras.layers.pooling.GlobalAveragePooling2D at 0x7f9ba02532d0>,
#  <keras.layers.core.reshape.Reshape at 0x7f9ba02df090>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba037d950>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba02d9ad0>,
#  <keras.layers.merge.Multiply at 0x7f9ba026dc10>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba0271310>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9ba0271890>,
#  <keras.layers.core.dropout.Dropout at 0x7f9ba027a410>,
#  <keras.layers.merge.Add at 0x7f9ba027e1d0>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba0284d90>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9ba027ed90>,
#  <keras.layers.core.activation.Activation at 0x7f9ba037d910>,
#  <keras.layers.convolutional.DepthwiseConv2D at 0x7f9ba0217b10>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9ba02170d0>,
#  <keras.layers.core.activation.Activation at 0x7f9ba021eb50>,
#  <keras.layers.pooling.GlobalAveragePooling2D at 0x7f9bb5b87cd0>,
#  <keras.layers.core.reshape.Reshape at 0x7f9ba022b650>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba021ebd0>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba0230590>,
#  <keras.layers.merge.Multiply at 0x7f9ba0239e90>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba0289f50>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9ba02467d0>,
#  <keras.layers.core.dropout.Dropout at 0x7f9ba024d590>,
#  <keras.layers.merge.Add at 0x7f9ba024d0d0>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba01d2610>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9ba01d8290>,
#  <keras.layers.core.activation.Activation at 0x7f9ba01e1050>,
#  <keras.layers.convolutional.DepthwiseConv2D at 0x7f9ba01dc6d0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9ba01dffd0>,
#  <keras.layers.core.activation.Activation at 0x7f9ba01f8050>,
#  <keras.layers.pooling.GlobalAveragePooling2D at 0x7f9ba01f8550>,
#  <keras.layers.core.reshape.Reshape at 0x7f9ba01f5d90>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba0205b50>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba020ef90>,
#  <keras.layers.merge.Multiply at 0x7f9ba0193910>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba0196310>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9ba01a3450>,
#  <keras.layers.core.dropout.Dropout at 0x7f9ba019f4d0>,
#  <keras.layers.merge.Add at 0x7f9ba019a790>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba01fda90>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9ba02489d0>,
#  <keras.layers.core.activation.Activation at 0x7f9ba01dfed0>,
#  <keras.layers.convolutional.ZeroPadding2D at 0x7f9ba01f5bd0>,
#  <keras.layers.convolutional.DepthwiseConv2D at 0x7f9ba0271d10>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9ba029c350>,
#  <keras.layers.core.activation.Activation at 0x7f9ba0241690>,
#  <keras.layers.pooling.GlobalAveragePooling2D at 0x7f9ba0304310>,
#  <keras.layers.core.reshape.Reshape at 0x7f9ba01b4690>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba01b8410>,
#  <keras.layers.convolutional.Conv2D at 0x7f9bb5ad5450>,
#  <keras.layers.merge.Multiply at 0x7f9ba01d0b50>,
#  <keras.layers.convolutional.Conv2D at 0x7f9bb5ad52d0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9bb5ad5550>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba015d6d0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9ba0158f90>,
#  <keras.layers.core.activation.Activation at 0x7f9ba0165190>,
#  <keras.layers.convolutional.DepthwiseConv2D at 0x7f9ba01723d0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9ba0172750>,
#  <keras.layers.core.activation.Activation at 0x7f9ba0176e50>,
#  <keras.layers.pooling.GlobalAveragePooling2D at 0x7f9ba0186710>,
#  <keras.layers.core.reshape.Reshape at 0x7f9ba0186d10>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba01860d0>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba0190190>,
#  <keras.layers.merge.Multiply at 0x7f9ba0119710>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba0119fd0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9ba011eed0>,
#  <keras.layers.core.dropout.Dropout at 0x7f9ba012bd10>,
#  <keras.layers.merge.Add at 0x7f9ba012ba90>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba0125a50>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9ba0135b90>,
#  <keras.layers.core.activation.Activation at 0x7f9ba013d810>,
#  <keras.layers.convolutional.DepthwiseConv2D at 0x7f9ba012ff90>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9ba014a850>,
#  <keras.layers.core.activation.Activation at 0x7f9ba0151410>,
#  <keras.layers.pooling.GlobalAveragePooling2D at 0x7f9ba0151810>,
#  <keras.layers.core.reshape.Reshape at 0x7f9ba00dd510>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba00e2290>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba00e94d0>,
#  <keras.layers.merge.Multiply at 0x7f9ba014a910>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba0145450>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9ba01774d0>,
#  <keras.layers.core.dropout.Dropout at 0x7f9ba01623d0>,
#  <keras.layers.merge.Add at 0x7f9ba012f5d0>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba0158b90>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9ba0230210>,
#  <keras.layers.core.activation.Activation at 0x7f9ba0151e90>,
#  <keras.layers.convolutional.DepthwiseConv2D at 0x7f9ba012f090>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9ba00f6990>,
#  <keras.layers.core.activation.Activation at 0x7f9ba024db90>,
#  <keras.layers.pooling.GlobalAveragePooling2D at 0x7f9ba01b40d0>,
#  <keras.layers.core.reshape.Reshape at 0x7f9ba00ff290>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba0106210>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba00fad50>,
#  <keras.layers.merge.Multiply at 0x7f9ba010dd50>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba0095850>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9ba00923d0>,
#  <keras.layers.core.dropout.Dropout at 0x7f9ba00a2790>,
#  <keras.layers.merge.Add at 0x7f9ba00a2f90>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba00ace10>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9ba00a2c90>,
#  <keras.layers.core.activation.Activation at 0x7f9ba00b17d0>,
#  <keras.layers.convolutional.DepthwiseConv2D at 0x7f9ba00be410>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9ba00b8690>,
#  <keras.layers.core.activation.Activation at 0x7f9ba00c4d10>,
#  <keras.layers.pooling.GlobalAveragePooling2D at 0x7f9ba00d1c50>,
#  <keras.layers.core.reshape.Reshape at 0x7f9ba00d1690>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba00cb810>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba0057750>,
#  <keras.layers.merge.Multiply at 0x7f9ba00b1750>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba00c49d0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9ba006d9d0>,
#  <keras.layers.core.dropout.Dropout at 0x7f9ba006ef10>,
#  <keras.layers.merge.Add at 0x7f9ba0075c50>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba0079d90>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9ba007b490>,
#  <keras.layers.core.activation.Activation at 0x7f9ba008d1d0>,
#  <keras.layers.convolutional.ZeroPadding2D at 0x7f9ba00751d0>,
#  <keras.layers.convolutional.DepthwiseConv2D at 0x7f9ba0012e90>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9ba0019390>,
#  <keras.layers.core.activation.Activation at 0x7f9ba00193d0>,
#  <keras.layers.pooling.GlobalAveragePooling2D at 0x7f9ba001e690>,
#  <keras.layers.core.reshape.Reshape at 0x7f9ba0079610>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba006ebd0>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba0095e50>,
#  <keras.layers.merge.Multiply at 0x7f9ba00faed0>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba0106c90>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9ba0119ed0>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba0177890>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9ba0028110>,
#  <keras.layers.core.activation.Activation at 0x7f9ba0289050>,
#  <keras.layers.convolutional.DepthwiseConv2D at 0x7f9ba0030dd0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9ba003a510>,
#  <keras.layers.core.activation.Activation at 0x7f9ba0027f10>,
#  <keras.layers.pooling.GlobalAveragePooling2D at 0x7f9ba0043bd0>,
#  <keras.layers.core.reshape.Reshape at 0x7f9ba004e210>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b386d4290>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba0027c90>,
#  <keras.layers.merge.Multiply at 0x7f9ba004ec90>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b386e4710>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b386f0210>,
#  <keras.layers.core.dropout.Dropout at 0x7f9b386e8710>,
#  <keras.layers.merge.Add at 0x7f9b386e7b10>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b386f6c90>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b386e8050>,
#  <keras.layers.core.activation.Activation at 0x7f9b387069d0>,
#  <keras.layers.convolutional.DepthwiseConv2D at 0x7f9b386fa8d0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b38696750>,
#  <keras.layers.core.activation.Activation at 0x7f9b3870bc90>,
#  <keras.layers.pooling.GlobalAveragePooling2D at 0x7f9b386fa650>,
#  <keras.layers.core.reshape.Reshape at 0x7f9b3869b350>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b386a8dd0>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b386f68d0>,
#  <keras.layers.merge.Multiply at 0x7f9b386b8b10>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b386bf150>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b386b40d0>,
#  <keras.layers.core.dropout.Dropout at 0x7f9b386e4d10>,
#  <keras.layers.merge.Add at 0x7f9b386c6550>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b386b9490>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b386bf8d0>,
#  <keras.layers.core.activation.Activation at 0x7f9b38655ed0>,
#  <keras.layers.convolutional.DepthwiseConv2D at 0x7f9b38665cd0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b386656d0>,
#  <keras.layers.core.activation.Activation at 0x7f9b38665f10>,
#  <keras.layers.pooling.GlobalAveragePooling2D at 0x7f9b38665ed0>,
#  <keras.layers.core.reshape.Reshape at 0x7f9bb63f8d10>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba0427850>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba0358350>,
#  <keras.layers.merge.Multiply at 0x7f9ba03a41d0>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba04020d0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9ba03c6a10>,
#  <keras.layers.core.dropout.Dropout at 0x7f9ba02ab090>,
#  <keras.layers.merge.Add at 0x7f9ba0217fd0>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba032e850>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9ba026e690>,
#  <keras.layers.core.activation.Activation at 0x7f9ba0328a10>,
#  <keras.layers.convolutional.DepthwiseConv2D at 0x7f9ba0196fd0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9ba00e9990>,
#  <keras.layers.core.activation.Activation at 0x7f9ba01220d0>,
#  <keras.layers.pooling.GlobalAveragePooling2D at 0x7f9ba00e9150>,
#  <keras.layers.core.reshape.Reshape at 0x7f9ba0068210>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba02248d0>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba00953d0>,
#  <keras.layers.merge.Multiply at 0x7f9ba0075590>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b3870e7d0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b38706790>,
#  <keras.layers.core.dropout.Dropout at 0x7f9b3865fbd0>,
#  <keras.layers.merge.Add at 0x7f9ba007bad0>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba0012050>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9ba0087d10>,
#  <keras.layers.core.activation.Activation at 0x7f9ba01a3ad0>,
#  <keras.layers.convolutional.DepthwiseConv2D at 0x7f9ba0312810>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9ba0380190>,
#  <keras.layers.core.activation.Activation at 0x7f9ba003a710>,
#  <keras.layers.pooling.GlobalAveragePooling2D at 0x7f9ba0043290>,
#  <keras.layers.core.reshape.Reshape at 0x7f9ba00284d0>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba002b310>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba02414d0>,
#  <keras.layers.merge.Multiply at 0x7f9b3866b950>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba0256810>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9ba0241a10>,
#  <keras.layers.core.dropout.Dropout at 0x7f9b385e9f10>,
#  <keras.layers.merge.Add at 0x7f9b386e7590>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b385ed490>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b385f1110>,
#  <keras.layers.core.activation.Activation at 0x7f9b385fd6d0>,
#  <keras.layers.convolutional.DepthwiseConv2D at 0x7f9b385e9ad0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9ba01ac250>,
#  <keras.layers.core.activation.Activation at 0x7f9b3870e910>,
#  <keras.layers.pooling.GlobalAveragePooling2D at 0x7f9ba02d3110>,
#  <keras.layers.core.reshape.Reshape at 0x7f9b386e8890>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba031de10>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba032ef10>,
#  <keras.layers.merge.Multiply at 0x7f9b386070d0>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b38607cd0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b3860e5d0>,
#  <keras.layers.core.dropout.Dropout at 0x7f9b3860b390>,
#  <keras.layers.merge.Add at 0x7f9b38608250>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b38593f90>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b385a3c10>,
#  <keras.layers.core.activation.Activation at 0x7f9b38593e10>,
#  <keras.layers.convolutional.DepthwiseConv2D at 0x7f9b38598c10>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b385aca90>,
#  <keras.layers.core.activation.Activation at 0x7f9b38598250>,
#  <keras.layers.pooling.GlobalAveragePooling2D at 0x7f9b385bed50>,
#  <keras.layers.core.reshape.Reshape at 0x7f9b385c53d0>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b385bacd0>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b385cbf10>,
#  <keras.layers.merge.Multiply at 0x7f9b38556e50>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b3855dbd0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b385620d0>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b38566590>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b3856e250>,
#  <keras.layers.core.activation.Activation at 0x7f9b3856e8d0>,
#  <keras.layers.convolutional.DepthwiseConv2D at 0x7f9b38566ad0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b38589710>,
#  <keras.layers.core.activation.Activation at 0x7f9b385822d0>,
#  <keras.layers.pooling.GlobalAveragePooling2D at 0x7f9b3857bcd0>,
#  <keras.layers.core.reshape.Reshape at 0x7f9b385921d0>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b3851db10>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b385824d0>,
#  <keras.layers.merge.Multiply at 0x7f9b3852a850>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b38534ad0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b3852dfd0>,
#  <keras.layers.core.dropout.Dropout at 0x7f9b3852d750>,
#  <keras.layers.merge.Add at 0x7f9b385336d0>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b385428d0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b38548350>,
#  <keras.layers.core.activation.Activation at 0x7f9b3853a410>,
#  <keras.layers.convolutional.DepthwiseConv2D at 0x7f9b3856e1d0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b3858dc10>,
#  <keras.layers.core.activation.Activation at 0x7f9b385bee10>,
#  <keras.layers.pooling.GlobalAveragePooling2D at 0x7f9b385b77d0>,
#  <keras.layers.core.reshape.Reshape at 0x7f9ba00acd10>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b3860e310>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b38698050>,
#  <keras.layers.merge.Multiply at 0x7f9b384d5850>,
#  <keras.layers.convolutional.Conv2D at 0x7f9ba0224410>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b384d9950>,
#  <keras.layers.core.dropout.Dropout at 0x7f9b384dce50>,
#  <keras.layers.merge.Add at 0x7f9b384e1bd0>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b384e6850>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b384e7410>,
#  <keras.layers.core.activation.Activation at 0x7f9b384fc150>,
#  <keras.layers.convolutional.DepthwiseConv2D at 0x7f9b384fc8d0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b384f4f50>,
#  <keras.layers.core.activation.Activation at 0x7f9b3850b0d0>,
#  <keras.layers.pooling.GlobalAveragePooling2D at 0x7f9b3850b7d0>,
#  <keras.layers.core.reshape.Reshape at 0x7f9b385074d0>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b38498cd0>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b384a49d0>,
#  <keras.layers.merge.Multiply at 0x7f9b384a7bd0>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b384ab4d0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b384b8110>,
#  <keras.layers.core.dropout.Dropout at 0x7f9b384b6490>,
#  <keras.layers.merge.Add at 0x7f9b384b0910>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b384be750>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b384c9810>,
#  <keras.layers.core.activation.Activation at 0x7f9b384cdb10>,
#  <keras.layers.convolutional.DepthwiseConv2D at 0x7f9b384bf0d0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b3845a790>,
#  <keras.layers.core.activation.Activation at 0x7f9b384c4210>,
#  <keras.layers.pooling.GlobalAveragePooling2D at 0x7f9b384bf3d0>,
#  <keras.layers.core.reshape.Reshape at 0x7f9b38465190>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b3846fb50>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b3845fa10>,
#  <keras.layers.merge.Multiply at 0x7f9b3847f890>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b384892d0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b3847ff50>,
#  <keras.layers.core.dropout.Dropout at 0x7f9b384c4c10>,
#  <keras.layers.merge.Add at 0x7f9b38511510>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b384ff090>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b384e6750>,
#  <keras.layers.core.activation.Activation at 0x7f9b384760d0>,
#  <keras.layers.convolutional.DepthwiseConv2D at 0x7f9b384b8390>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b3866f950>,
#  <keras.layers.core.activation.Activation at 0x7f9b3841a550>,
#  <keras.layers.pooling.GlobalAveragePooling2D at 0x7f9b3841ccd0>,
#  <keras.layers.core.reshape.Reshape at 0x7f9b38421610>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b38426390>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b38432450>,
#  <keras.layers.merge.Multiply at 0x7f9b38437250>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b38437d90>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b384466d0>,
#  <keras.layers.core.dropout.Dropout at 0x7f9b384402d0>,
#  <keras.layers.merge.Add at 0x7f9b3843a2d0>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b3844c050>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b383d9d10>,
#  <keras.layers.core.activation.Activation at 0x7f9b38452390>,
#  <keras.layers.convolutional.DepthwiseConv2D at 0x7f9b3844c690>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b383e7b50>,
#  <keras.layers.core.activation.Activation at 0x7f9b3844c890>,
#  <keras.layers.pooling.GlobalAveragePooling2D at 0x7f9b383ec4d0>,
#  <keras.layers.core.reshape.Reshape at 0x7f9b383f94d0>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b38400250>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b383f13d0>,
#  <keras.layers.merge.Multiply at 0x7f9b38407f50>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b38393e10>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b3840ec50>,
#  <keras.layers.core.dropout.Dropout at 0x7f9b3839b7d0>,
#  <keras.layers.merge.Add at 0x7f9b3839c410>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b383a5fd0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b3839bc50>,
#  <keras.layers.core.activation.Activation at 0x7f9b383acd10>,
#  <keras.layers.convolutional.ZeroPadding2D at 0x7f9b383b5990>,
#  <keras.layers.convolutional.DepthwiseConv2D at 0x7f9b383b7490>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b383b70d0>,
#  <keras.layers.core.activation.Activation at 0x7f9b383c71d0>,
#  <keras.layers.pooling.GlobalAveragePooling2D at 0x7f9b383d0310>,
#  <keras.layers.core.reshape.Reshape at 0x7f9b383c7910>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b3839c710>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b383e0b50>,
#  <keras.layers.merge.Multiply at 0x7f9b38393e50>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b383f1f90>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b3860e7d0>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b384b82d0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b38416510>,
#  <keras.layers.core.activation.Activation at 0x7f9b38357310>,
#  <keras.layers.convolutional.DepthwiseConv2D at 0x7f9b383577d0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b38360450>,
#  <keras.layers.core.activation.Activation at 0x7f9b383662d0>,
#  <keras.layers.pooling.GlobalAveragePooling2D at 0x7f9b38366950>,
#  <keras.layers.core.reshape.Reshape at 0x7f9b38371150>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b38371ed0>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b3837b490>,
#  <keras.layers.merge.Multiply at 0x7f9b38371cd0>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b383868d0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b38313150>,
#  <keras.layers.core.dropout.Dropout at 0x7f9b3838f650>,
#  <keras.layers.merge.Add at 0x7f9b38389a90>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b38316bd0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b38323050>,
#  <keras.layers.core.activation.Activation at 0x7f9b3832add0>,
#  <keras.layers.convolutional.DepthwiseConv2D at 0x7f9b3831c950>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b383368d0>,
#  <keras.layers.core.activation.Activation at 0x7f9b3832dbd0>,
#  <keras.layers.pooling.GlobalAveragePooling2D at 0x7f9b3831c550>,
#  <keras.layers.core.reshape.Reshape at 0x7f9b38341350>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b3834bd10>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b3832dd10>,
#  <keras.layers.merge.Multiply at 0x7f9b382dba50>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b382e4cd0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b382d59d0>,
#  <keras.layers.core.dropout.Dropout at 0x7f9b382ed490>,
#  <keras.layers.merge.Add at 0x7f9b382ed8d0>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b382f7b10>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b382ed810>,
#  <keras.layers.core.activation.Activation at 0x7f9b382fc390>,
#  <keras.layers.convolutional.DepthwiseConv2D at 0x7f9b38301550>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b382f7350>,
#  <keras.layers.core.activation.Activation at 0x7f9b38341e50>,
#  <keras.layers.pooling.GlobalAveragePooling2D at 0x7f9b3833a490>,
#  <keras.layers.core.reshape.Reshape at 0x7f9b38313590>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b38323ed0>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b38362790>,
#  <keras.layers.merge.Multiply at 0x7f9b3841cb90>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b383661d0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b38389e10>,
#  <keras.layers.core.dropout.Dropout at 0x7f9b382950d0>,
#  <keras.layers.merge.Add at 0x7f9b38323110>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b38293f50>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b3829cfd0>,
#  <keras.layers.core.activation.Activation at 0x7f9b382a2290>,
#  <keras.layers.convolutional.DepthwiseConv2D at 0x7f9b382a2e90>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b382b0950>,
#  <keras.layers.core.activation.Activation at 0x7f9b382b77d0>,
#  <keras.layers.pooling.GlobalAveragePooling2D at 0x7f9b382b7bd0>,
#  <keras.layers.core.reshape.Reshape at 0x7f9b382c08d0>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b382c9650>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b38254710>,
#  <keras.layers.merge.Multiply at 0x7f9b38257550>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b38254c90>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b38264990>,
#  <keras.layers.core.dropout.Dropout at 0x7f9b3825f450>,
#  <keras.layers.merge.Add at 0x7f9b3825bcd0>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b38272f10>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b38267ed0>,
#  <keras.layers.core.activation.Activation at 0x7f9b38278190>,
#  <keras.layers.convolutional.DepthwiseConv2D at 0x7f9b38278e50>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b38287790>,
#  <keras.layers.core.activation.Activation at 0x7f9b3827f090>,
#  <keras.layers.pooling.GlobalAveragePooling2D at 0x7f9b38287b50>,
#  <keras.layers.core.reshape.Reshape at 0x7f9b3827f710>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b3828df90>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b38267e10>,
#  <keras.layers.merge.Multiply at 0x7f9b38220b10>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b38220990>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b382205d0>,
#  <keras.layers.core.dropout.Dropout at 0x7f9b38235d10>,
#  <keras.layers.merge.Add at 0x7f9b3823a990>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b38249b10>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b38249650>,
#  <keras.layers.core.activation.Activation at 0x7f9b38244590>,
#  <keras.layers.convolutional.DepthwiseConv2D at 0x7f9b3823fc50>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b38220790>,
#  <keras.layers.core.activation.Activation at 0x7f9b3826b910>,
#  <keras.layers.pooling.GlobalAveragePooling2D at 0x7f9b38264bd0>,
#  <keras.layers.core.reshape.Reshape at 0x7f9b3823af90>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b38297b90>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b3823f410>,
#  <keras.layers.merge.Multiply at 0x7f9b38297a50>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b38295750>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b382d5990>,
#  <keras.layers.core.dropout.Dropout at 0x7f9b381d8d90>,
#  <keras.layers.merge.Add at 0x7f9b381df750>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b381effd0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b38294dd0>,
#  <keras.layers.core.activation.Activation at 0x7f9b38490550>,
#  <keras.layers.convolutional.DepthwiseConv2D at 0x7f9b381df8d0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b381fd290>,
#  <keras.layers.core.activation.Activation at 0x7f9b381d47d0>,
#  <keras.layers.pooling.GlobalAveragePooling2D at 0x7f9b381dff10>,
#  <keras.layers.core.reshape.Reshape at 0x7f9b381dfbd0>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b38209710>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b381d8bd0>,
#  <keras.layers.merge.Multiply at 0x7f9b3820fa90>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b38195650>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b38195c10>,
#  <keras.layers.core.dropout.Dropout at 0x7f9b381b0210>,
#  <keras.layers.merge.Add at 0x7f9b381ab890>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b381a6bd0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b381a6550>,
#  <keras.layers.core.activation.Activation at 0x7f9b381bf850>,
#  <keras.layers.convolutional.DepthwiseConv2D at 0x7f9b381bf890>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b38156fd0>,
#  <keras.layers.core.activation.Activation at 0x7f9b381f9150>,
#  <keras.layers.pooling.GlobalAveragePooling2D at 0x7f9b38156e10>,
#  <keras.layers.core.reshape.Reshape at 0x7f9b381f9690>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b38165610>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b381b5590>,
#  <keras.layers.merge.Multiply at 0x7f9b38177410>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b38177f10>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b38165590>,
#  <keras.layers.core.dropout.Dropout at 0x7f9b38113810>,
#  <keras.layers.merge.Add at 0x7f9b38113ed0>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b38113a50>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b3818d590>,
#  <keras.layers.core.activation.Activation at 0x7f9b3816dd90>,
#  <keras.layers.convolutional.DepthwiseConv2D at 0x7f9b381561d0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b38113d90>,
#  <keras.layers.core.activation.Activation at 0x7f9b381bf690>,
#  <keras.layers.pooling.GlobalAveragePooling2D at 0x7f9b3819a290>,
#  <keras.layers.core.reshape.Reshape at 0x7f9b38206910>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b381df190>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b38113a90>,
#  <keras.layers.merge.Multiply at 0x7f9b3811d1d0>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b38220350>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b3823ac10>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b3812e490>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b38121ed0>,
#  <keras.layers.core.activation.Activation at 0x7f9b381393d0>,
#  <keras.layers.convolutional.DepthwiseConv2D at 0x7f9b3813b250>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b3813b410>,
#  <keras.layers.core.activation.Activation at 0x7f9b3813bf50>,
#  <keras.layers.pooling.GlobalAveragePooling2D at 0x7f9b38139590>,
#  <keras.layers.core.reshape.Reshape at 0x7f9b381ab0d0>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b3814e2d0>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b3812e8d0>,
#  <keras.layers.merge.Multiply at 0x7f9b380e2950>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b380e2310>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b380d3290>,
#  <keras.layers.core.dropout.Dropout at 0x7f9b380f8090>,
#  <keras.layers.merge.Add at 0x7f9b380fc290>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b380fc4d0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b380e89d0>,
#  <keras.layers.core.activation.Activation at 0x7f9b380942d0>,
#  <keras.layers.convolutional.DepthwiseConv2D at 0x7f9b38094610>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b38094910>,
#  <keras.layers.core.activation.Activation at 0x7f9b38094790>,
#  <keras.layers.pooling.GlobalAveragePooling2D at 0x7f9b3809f1d0>,
#  <keras.layers.core.reshape.Reshape at 0x7f9b380a3490>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b380a84d0>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b3814ed90>,
#  <keras.layers.merge.Multiply at 0x7f9b380b9690>,
#  <keras.layers.convolutional.Conv2D at 0x7f9b380bfd90>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b380b27d0>,
#  <keras.layers.core.dropout.Dropout at 0x7f9b380cd110>,
#  <keras.layers.merge.Add at 0x7f9b380cd290>,
#  <keras.layers.convolutional.Conv2D at 0x7f9bb5b87b50>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f9b380bfad0>,
#  <keras.layers.core.activation.Activation at 0x7f9b38105cd0>]

# %%
len(model.layers)
# Out:
# 576

# %%
#Set pre-trained model layers to not trainable
for layer in model.layers:
    layer.trainable = False

# %%
#Check if layers frozen
model.summary()
# Out:
# Model: "efficientnetb5"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 500, 500, 3  0           []
#                                 )]
#
#  rescaling (Rescaling)          (None, 500, 500, 3)  0           ['input_1[0][0]']
#
#  normalization (Normalization)  (None, 500, 500, 3)  7           ['rescaling[0][0]']
#
#  stem_conv_pad (ZeroPadding2D)  (None, 501, 501, 3)  0           ['normalization[0][0]']
#
#  stem_conv (Conv2D)             (None, 250, 250, 48  1296        ['stem_conv_pad[0][0]']
#                                 )
#
#  stem_bn (BatchNormalization)   (None, 250, 250, 48  192         ['stem_conv[0][0]']
#                                 )
#
#  stem_activation (Activation)   (None, 250, 250, 48  0           ['stem_bn[0][0]']
#                                 )
#
#  block1a_dwconv (DepthwiseConv2  (None, 250, 250, 48  432        ['stem_activation[0][0]']
#  D)                             )
#
#  block1a_bn (BatchNormalization  (None, 250, 250, 48  192        ['block1a_dwconv[0][0]']
#  )                              )
#
#  block1a_activation (Activation  (None, 250, 250, 48  0          ['block1a_bn[0][0]']
#  )                              )
#
#  block1a_se_squeeze (GlobalAver  (None, 48)          0           ['block1a_activation[0][0]']
#  agePooling2D)
#
#  block1a_se_reshape (Reshape)   (None, 1, 1, 48)     0           ['block1a_se_squeeze[0][0]']
#
#  block1a_se_reduce (Conv2D)     (None, 1, 1, 12)     588         ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)     (None, 1, 1, 48)     624         ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multiply)   (None, 250, 250, 48  0           ['block1a_activation[0][0]',
#                                 )                                 'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv2D)  (None, 250, 250, 24  1152        ['block1a_se_excite[0][0]']
#                                 )
#
#  block1a_project_bn (BatchNorma  (None, 250, 250, 24  96         ['block1a_project_conv[0][0]']
#  lization)                      )
#
#  block1b_dwconv (DepthwiseConv2  (None, 250, 250, 24  216        ['block1a_project_bn[0][0]']
#  D)                             )
#
#  block1b_bn (BatchNormalization  (None, 250, 250, 24  96         ['block1b_dwconv[0][0]']
#  )                              )
#
#  block1b_activation (Activation  (None, 250, 250, 24  0          ['block1b_bn[0][0]']
#  )                              )
#
#  block1b_se_squeeze (GlobalAver  (None, 24)          0           ['block1b_activation[0][0]']
#  agePooling2D)
#
#  block1b_se_reshape (Reshape)   (None, 1, 1, 24)     0           ['block1b_se_squeeze[0][0]']
#
#  block1b_se_reduce (Conv2D)     (None, 1, 1, 6)      150         ['block1b_se_reshape[0][0]']
#
#  block1b_se_expand (Conv2D)     (None, 1, 1, 24)     168         ['block1b_se_reduce[0][0]']
#
#  block1b_se_excite (Multiply)   (None, 250, 250, 24  0           ['block1b_activation[0][0]',
#                                 )                                 'block1b_se_expand[0][0]']
#
#  block1b_project_conv (Conv2D)  (None, 250, 250, 24  576         ['block1b_se_excite[0][0]']
#                                 )
#
#  block1b_project_bn (BatchNorma  (None, 250, 250, 24  96         ['block1b_project_conv[0][0]']
#  lization)                      )
#
#  block1b_drop (Dropout)         (None, 250, 250, 24  0           ['block1b_project_bn[0][0]']
#                                 )
#
#  block1b_add (Add)              (None, 250, 250, 24  0           ['block1b_drop[0][0]',
#                                 )                                 'block1a_project_bn[0][0]']
#
#  block1c_dwconv (DepthwiseConv2  (None, 250, 250, 24  216        ['block1b_add[0][0]']
#  D)                             )
#
#  block1c_bn (BatchNormalization  (None, 250, 250, 24  96         ['block1c_dwconv[0][0]']
#  )                              )
#
#  block1c_activation (Activation  (None, 250, 250, 24  0          ['block1c_bn[0][0]']
#  )                              )
#
#  block1c_se_squeeze (GlobalAver  (None, 24)          0           ['block1c_activation[0][0]']
#  agePooling2D)
#
#  block1c_se_reshape (Reshape)   (None, 1, 1, 24)     0           ['block1c_se_squeeze[0][0]']
#
#  block1c_se_reduce (Conv2D)     (None, 1, 1, 6)      150         ['block1c_se_reshape[0][0]']
#
#  block1c_se_expand (Conv2D)     (None, 1, 1, 24)     168         ['block1c_se_reduce[0][0]']
#
#  block1c_se_excite (Multiply)   (None, 250, 250, 24  0           ['block1c_activation[0][0]',
#                                 )                                 'block1c_se_expand[0][0]']
#
#  block1c_project_conv (Conv2D)  (None, 250, 250, 24  576         ['block1c_se_excite[0][0]']
#                                 )
#
#  block1c_project_bn (BatchNorma  (None, 250, 250, 24  96         ['block1c_project_conv[0][0]']
#  lization)                      )
#
#  block1c_drop (Dropout)         (None, 250, 250, 24  0           ['block1c_project_bn[0][0]']
#                                 )
#
#  block1c_add (Add)              (None, 250, 250, 24  0           ['block1c_drop[0][0]',
#                                 )                                 'block1b_add[0][0]']
#
#  block2a_expand_conv (Conv2D)   (None, 250, 250, 14  3456        ['block1c_add[0][0]']
#                                 4)
#
#  block2a_expand_bn (BatchNormal  (None, 250, 250, 14  576        ['block2a_expand_conv[0][0]']
#  ization)                       4)
#
#  block2a_expand_activation (Act  (None, 250, 250, 14  0          ['block2a_expand_bn[0][0]']
#  ivation)                       4)
#
#  block2a_dwconv_pad (ZeroPaddin  (None, 251, 251, 14  0          ['block2a_expand_activation[0][0]
#  g2D)                           4)                               ']
#
#  block2a_dwconv (DepthwiseConv2  (None, 125, 125, 14  1296       ['block2a_dwconv_pad[0][0]']
#  D)                             4)
#
#  block2a_bn (BatchNormalization  (None, 125, 125, 14  576        ['block2a_dwconv[0][0]']
#  )                              4)
#
#  block2a_activation (Activation  (None, 125, 125, 14  0          ['block2a_bn[0][0]']
#  )                              4)
#
#  block2a_se_squeeze (GlobalAver  (None, 144)         0           ['block2a_activation[0][0]']
#  agePooling2D)
#
#  block2a_se_reshape (Reshape)   (None, 1, 1, 144)    0           ['block2a_se_squeeze[0][0]']
#
#  block2a_se_reduce (Conv2D)     (None, 1, 1, 6)      870         ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)     (None, 1, 1, 144)    1008        ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multiply)   (None, 125, 125, 14  0           ['block2a_activation[0][0]',
#                                 4)                                'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv2D)  (None, 125, 125, 40  5760        ['block2a_se_excite[0][0]']
#                                 )
#
#  block2a_project_bn (BatchNorma  (None, 125, 125, 40  160        ['block2a_project_conv[0][0]']
#  lization)                      )
#
#  block2b_expand_conv (Conv2D)   (None, 125, 125, 24  9600        ['block2a_project_bn[0][0]']
#                                 0)
#
#  block2b_expand_bn (BatchNormal  (None, 125, 125, 24  960        ['block2b_expand_conv[0][0]']
#  ization)                       0)
#
#  block2b_expand_activation (Act  (None, 125, 125, 24  0          ['block2b_expand_bn[0][0]']
#  ivation)                       0)
#
#  block2b_dwconv (DepthwiseConv2  (None, 125, 125, 24  2160       ['block2b_expand_activation[0][0]
#  D)                             0)                               ']
#
#  block2b_bn (BatchNormalization  (None, 125, 125, 24  960        ['block2b_dwconv[0][0]']
#  )                              0)
#
#  block2b_activation (Activation  (None, 125, 125, 24  0          ['block2b_bn[0][0]']
#  )                              0)
#
#  block2b_se_squeeze (GlobalAver  (None, 240)         0           ['block2b_activation[0][0]']
#  agePooling2D)
#
#  block2b_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block2b_se_squeeze[0][0]']
#
#  block2b_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multiply)   (None, 125, 125, 24  0           ['block2b_activation[0][0]',
#                                 0)                                'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv2D)  (None, 125, 125, 40  9600        ['block2b_se_excite[0][0]']
#                                 )
#
#  block2b_project_bn (BatchNorma  (None, 125, 125, 40  160        ['block2b_project_conv[0][0]']
#  lization)                      )
#
#  block2b_drop (Dropout)         (None, 125, 125, 40  0           ['block2b_project_bn[0][0]']
#                                 )
#
#  block2b_add (Add)              (None, 125, 125, 40  0           ['block2b_drop[0][0]',
#                                 )                                 'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2D)   (None, 125, 125, 24  9600        ['block2b_add[0][0]']
#                                 0)
#
#  block2c_expand_bn (BatchNormal  (None, 125, 125, 24  960        ['block2c_expand_conv[0][0]']
#  ization)                       0)
#
#  block2c_expand_activation (Act  (None, 125, 125, 24  0          ['block2c_expand_bn[0][0]']
#  ivation)                       0)
#
#  block2c_dwconv (DepthwiseConv2  (None, 125, 125, 24  2160       ['block2c_expand_activation[0][0]
#  D)                             0)                               ']
#
#  block2c_bn (BatchNormalization  (None, 125, 125, 24  960        ['block2c_dwconv[0][0]']
#  )                              0)
#
#  block2c_activation (Activation  (None, 125, 125, 24  0          ['block2c_bn[0][0]']
#  )                              0)
#
#  block2c_se_squeeze (GlobalAver  (None, 240)         0           ['block2c_activation[0][0]']
#  agePooling2D)
#
#  block2c_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block2c_se_squeeze[0][0]']
#
#  block2c_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block2c_se_reshape[0][0]']
#
#  block2c_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block2c_se_reduce[0][0]']
#
#  block2c_se_excite (Multiply)   (None, 125, 125, 24  0           ['block2c_activation[0][0]',
#                                 0)                                'block2c_se_expand[0][0]']
#
#  block2c_project_conv (Conv2D)  (None, 125, 125, 40  9600        ['block2c_se_excite[0][0]']
#                                 )
#
#  block2c_project_bn (BatchNorma  (None, 125, 125, 40  160        ['block2c_project_conv[0][0]']
#  lization)                      )
#
#  block2c_drop (Dropout)         (None, 125, 125, 40  0           ['block2c_project_bn[0][0]']
#                                 )
#
#  block2c_add (Add)              (None, 125, 125, 40  0           ['block2c_drop[0][0]',
#                                 )                                 'block2b_add[0][0]']
#
#  block2d_expand_conv (Conv2D)   (None, 125, 125, 24  9600        ['block2c_add[0][0]']
#                                 0)
#
#  block2d_expand_bn (BatchNormal  (None, 125, 125, 24  960        ['block2d_expand_conv[0][0]']
#  ization)                       0)
#
#  block2d_expand_activation (Act  (None, 125, 125, 24  0          ['block2d_expand_bn[0][0]']
#  ivation)                       0)
#
#  block2d_dwconv (DepthwiseConv2  (None, 125, 125, 24  2160       ['block2d_expand_activation[0][0]
#  D)                             0)                               ']
#
#  block2d_bn (BatchNormalization  (None, 125, 125, 24  960        ['block2d_dwconv[0][0]']
#  )                              0)
#
#  block2d_activation (Activation  (None, 125, 125, 24  0          ['block2d_bn[0][0]']
#  )                              0)
#
#  block2d_se_squeeze (GlobalAver  (None, 240)         0           ['block2d_activation[0][0]']
#  agePooling2D)
#
#  block2d_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block2d_se_squeeze[0][0]']
#
#  block2d_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block2d_se_reshape[0][0]']
#
#  block2d_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block2d_se_reduce[0][0]']
#
#  block2d_se_excite (Multiply)   (None, 125, 125, 24  0           ['block2d_activation[0][0]',
#                                 0)                                'block2d_se_expand[0][0]']
#
#  block2d_project_conv (Conv2D)  (None, 125, 125, 40  9600        ['block2d_se_excite[0][0]']
#                                 )
#
#  block2d_project_bn (BatchNorma  (None, 125, 125, 40  160        ['block2d_project_conv[0][0]']
#  lization)                      )
#
#  block2d_drop (Dropout)         (None, 125, 125, 40  0           ['block2d_project_bn[0][0]']
#                                 )
#
#  block2d_add (Add)              (None, 125, 125, 40  0           ['block2d_drop[0][0]',
#                                 )                                 'block2c_add[0][0]']
#
#  block2e_expand_conv (Conv2D)   (None, 125, 125, 24  9600        ['block2d_add[0][0]']
#                                 0)
#
#  block2e_expand_bn (BatchNormal  (None, 125, 125, 24  960        ['block2e_expand_conv[0][0]']
#  ization)                       0)
#
#  block2e_expand_activation (Act  (None, 125, 125, 24  0          ['block2e_expand_bn[0][0]']
#  ivation)                       0)
#
#  block2e_dwconv (DepthwiseConv2  (None, 125, 125, 24  2160       ['block2e_expand_activation[0][0]
#  D)                             0)                               ']
#
#  block2e_bn (BatchNormalization  (None, 125, 125, 24  960        ['block2e_dwconv[0][0]']
#  )                              0)
#
#  block2e_activation (Activation  (None, 125, 125, 24  0          ['block2e_bn[0][0]']
#  )                              0)
#
#  block2e_se_squeeze (GlobalAver  (None, 240)         0           ['block2e_activation[0][0]']
#  agePooling2D)
#
#  block2e_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block2e_se_squeeze[0][0]']
#
#  block2e_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block2e_se_reshape[0][0]']
#
#  block2e_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block2e_se_reduce[0][0]']
#
#  block2e_se_excite (Multiply)   (None, 125, 125, 24  0           ['block2e_activation[0][0]',
#                                 0)                                'block2e_se_expand[0][0]']
#
#  block2e_project_conv (Conv2D)  (None, 125, 125, 40  9600        ['block2e_se_excite[0][0]']
#                                 )
#
#  block2e_project_bn (BatchNorma  (None, 125, 125, 40  160        ['block2e_project_conv[0][0]']
#  lization)                      )
#
#  block2e_drop (Dropout)         (None, 125, 125, 40  0           ['block2e_project_bn[0][0]']
#                                 )
#
#  block2e_add (Add)              (None, 125, 125, 40  0           ['block2e_drop[0][0]',
#                                 )                                 'block2d_add[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, 125, 125, 24  9600        ['block2e_add[0][0]']
#                                 0)
#
#  block3a_expand_bn (BatchNormal  (None, 125, 125, 24  960        ['block3a_expand_conv[0][0]']
#  ization)                       0)
#
#  block3a_expand_activation (Act  (None, 125, 125, 24  0          ['block3a_expand_bn[0][0]']
#  ivation)                       0)
#
#  block3a_dwconv_pad (ZeroPaddin  (None, 129, 129, 24  0          ['block3a_expand_activation[0][0]
#  g2D)                           0)                               ']
#
#  block3a_dwconv (DepthwiseConv2  (None, 63, 63, 240)  6000       ['block3a_dwconv_pad[0][0]']
#  D)
#
#  block3a_bn (BatchNormalization  (None, 63, 63, 240)  960        ['block3a_dwconv[0][0]']
#  )
#
#  block3a_activation (Activation  (None, 63, 63, 240)  0          ['block3a_bn[0][0]']
#  )
#
#  block3a_se_squeeze (GlobalAver  (None, 240)         0           ['block3a_activation[0][0]']
#  agePooling2D)
#
#  block3a_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block3a_se_squeeze[0][0]']
#
#  block3a_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multiply)   (None, 63, 63, 240)  0           ['block3a_activation[0][0]',
#                                                                   'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv2D)  (None, 63, 63, 64)   15360       ['block3a_se_excite[0][0]']
#
#  block3a_project_bn (BatchNorma  (None, 63, 63, 64)  256         ['block3a_project_conv[0][0]']
#  lization)
#
#  block3b_expand_conv (Conv2D)   (None, 63, 63, 384)  24576       ['block3a_project_bn[0][0]']
#
#  block3b_expand_bn (BatchNormal  (None, 63, 63, 384)  1536       ['block3b_expand_conv[0][0]']
#  ization)
#
#  block3b_expand_activation (Act  (None, 63, 63, 384)  0          ['block3b_expand_bn[0][0]']
#  ivation)
#
#  block3b_dwconv (DepthwiseConv2  (None, 63, 63, 384)  9600       ['block3b_expand_activation[0][0]
#  D)                                                              ']
#
#  block3b_bn (BatchNormalization  (None, 63, 63, 384)  1536       ['block3b_dwconv[0][0]']
#  )
#
#  block3b_activation (Activation  (None, 63, 63, 384)  0          ['block3b_bn[0][0]']
#  )
#
#  block3b_se_squeeze (GlobalAver  (None, 384)         0           ['block3b_activation[0][0]']
#  agePooling2D)
#
#  block3b_se_reshape (Reshape)   (None, 1, 1, 384)    0           ['block3b_se_squeeze[0][0]']
#
#  block3b_se_reduce (Conv2D)     (None, 1, 1, 16)     6160        ['block3b_se_reshape[0][0]']
#
#  block3b_se_expand (Conv2D)     (None, 1, 1, 384)    6528        ['block3b_se_reduce[0][0]']
#
#  block3b_se_excite (Multiply)   (None, 63, 63, 384)  0           ['block3b_activation[0][0]',
#                                                                   'block3b_se_expand[0][0]']
#
#  block3b_project_conv (Conv2D)  (None, 63, 63, 64)   24576       ['block3b_se_excite[0][0]']
#
#  block3b_project_bn (BatchNorma  (None, 63, 63, 64)  256         ['block3b_project_conv[0][0]']
#  lization)
#
#  block3b_drop (Dropout)         (None, 63, 63, 64)   0           ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)              (None, 63, 63, 64)   0           ['block3b_drop[0][0]',
#                                                                   'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2D)   (None, 63, 63, 384)  24576       ['block3b_add[0][0]']
#
#  block3c_expand_bn (BatchNormal  (None, 63, 63, 384)  1536       ['block3c_expand_conv[0][0]']
#  ization)
#
#  block3c_expand_activation (Act  (None, 63, 63, 384)  0          ['block3c_expand_bn[0][0]']
#  ivation)
#
#  block3c_dwconv (DepthwiseConv2  (None, 63, 63, 384)  9600       ['block3c_expand_activation[0][0]
#  D)                                                              ']
#
#  block3c_bn (BatchNormalization  (None, 63, 63, 384)  1536       ['block3c_dwconv[0][0]']
#  )
#
#  block3c_activation (Activation  (None, 63, 63, 384)  0          ['block3c_bn[0][0]']
#  )
#
#  block3c_se_squeeze (GlobalAver  (None, 384)         0           ['block3c_activation[0][0]']
#  agePooling2D)
#
#  block3c_se_reshape (Reshape)   (None, 1, 1, 384)    0           ['block3c_se_squeeze[0][0]']
#
#  block3c_se_reduce (Conv2D)     (None, 1, 1, 16)     6160        ['block3c_se_reshape[0][0]']
#
#  block3c_se_expand (Conv2D)     (None, 1, 1, 384)    6528        ['block3c_se_reduce[0][0]']
#
#  block3c_se_excite (Multiply)   (None, 63, 63, 384)  0           ['block3c_activation[0][0]',
#                                                                   'block3c_se_expand[0][0]']
#
#  block3c_project_conv (Conv2D)  (None, 63, 63, 64)   24576       ['block3c_se_excite[0][0]']
#
#  block3c_project_bn (BatchNorma  (None, 63, 63, 64)  256         ['block3c_project_conv[0][0]']
#  lization)
#
#  block3c_drop (Dropout)         (None, 63, 63, 64)   0           ['block3c_project_bn[0][0]']
#
#  block3c_add (Add)              (None, 63, 63, 64)   0           ['block3c_drop[0][0]',
#                                                                   'block3b_add[0][0]']
#
#  block3d_expand_conv (Conv2D)   (None, 63, 63, 384)  24576       ['block3c_add[0][0]']
#
#  block3d_expand_bn (BatchNormal  (None, 63, 63, 384)  1536       ['block3d_expand_conv[0][0]']
#  ization)
#
#  block3d_expand_activation (Act  (None, 63, 63, 384)  0          ['block3d_expand_bn[0][0]']
#  ivation)
#
#  block3d_dwconv (DepthwiseConv2  (None, 63, 63, 384)  9600       ['block3d_expand_activation[0][0]
#  D)                                                              ']
#
#  block3d_bn (BatchNormalization  (None, 63, 63, 384)  1536       ['block3d_dwconv[0][0]']
#  )
#
#  block3d_activation (Activation  (None, 63, 63, 384)  0          ['block3d_bn[0][0]']
#  )
#
#  block3d_se_squeeze (GlobalAver  (None, 384)         0           ['block3d_activation[0][0]']
#  agePooling2D)
#
#  block3d_se_reshape (Reshape)   (None, 1, 1, 384)    0           ['block3d_se_squeeze[0][0]']
#
#  block3d_se_reduce (Conv2D)     (None, 1, 1, 16)     6160        ['block3d_se_reshape[0][0]']
#
#  block3d_se_expand (Conv2D)     (None, 1, 1, 384)    6528        ['block3d_se_reduce[0][0]']
#
#  block3d_se_excite (Multiply)   (None, 63, 63, 384)  0           ['block3d_activation[0][0]',
#                                                                   'block3d_se_expand[0][0]']
#
#  block3d_project_conv (Conv2D)  (None, 63, 63, 64)   24576       ['block3d_se_excite[0][0]']
#
#  block3d_project_bn (BatchNorma  (None, 63, 63, 64)  256         ['block3d_project_conv[0][0]']
#  lization)
#
#  block3d_drop (Dropout)         (None, 63, 63, 64)   0           ['block3d_project_bn[0][0]']
#
#  block3d_add (Add)              (None, 63, 63, 64)   0           ['block3d_drop[0][0]',
#                                                                   'block3c_add[0][0]']
#
#  block3e_expand_conv (Conv2D)   (None, 63, 63, 384)  24576       ['block3d_add[0][0]']
#
#  block3e_expand_bn (BatchNormal  (None, 63, 63, 384)  1536       ['block3e_expand_conv[0][0]']
#  ization)
#
#  block3e_expand_activation (Act  (None, 63, 63, 384)  0          ['block3e_expand_bn[0][0]']
#  ivation)
#
# ...
#  block6i_expand_activation (Act  (None, 16, 16, 1824  0          ['block6i_expand_bn[0][0]']
#  ivation)                       )
#
#  block6i_dwconv (DepthwiseConv2  (None, 16, 16, 1824  45600      ['block6i_expand_activation[0][0]
#  D)                             )                                ']
#
#  block6i_bn (BatchNormalization  (None, 16, 16, 1824  7296       ['block6i_dwconv[0][0]']
#  )                              )
#
#  block6i_activation (Activation  (None, 16, 16, 1824  0          ['block6i_bn[0][0]']
#  )                              )
#
#  block6i_se_squeeze (GlobalAver  (None, 1824)        0           ['block6i_activation[0][0]']
#  agePooling2D)
#
#  block6i_se_reshape (Reshape)   (None, 1, 1, 1824)   0           ['block6i_se_squeeze[0][0]']
#
#  block6i_se_reduce (Conv2D)     (None, 1, 1, 76)     138700      ['block6i_se_reshape[0][0]']
#
#  block6i_se_expand (Conv2D)     (None, 1, 1, 1824)   140448      ['block6i_se_reduce[0][0]']
#
#  block6i_se_excite (Multiply)   (None, 16, 16, 1824  0           ['block6i_activation[0][0]',
#                                 )                                 'block6i_se_expand[0][0]']
#
#  block6i_project_conv (Conv2D)  (None, 16, 16, 304)  554496      ['block6i_se_excite[0][0]']
#
#  block6i_project_bn (BatchNorma  (None, 16, 16, 304)  1216       ['block6i_project_conv[0][0]']
#  lization)
#
#  block6i_drop (Dropout)         (None, 16, 16, 304)  0           ['block6i_project_bn[0][0]']
#
#  block6i_add (Add)              (None, 16, 16, 304)  0           ['block6i_drop[0][0]',
#                                                                   'block6h_add[0][0]']
#
#  block7a_expand_conv (Conv2D)   (None, 16, 16, 1824  554496      ['block6i_add[0][0]']
#                                 )
#
#  block7a_expand_bn (BatchNormal  (None, 16, 16, 1824  7296       ['block7a_expand_conv[0][0]']
#  ization)                       )
#
#  block7a_expand_activation (Act  (None, 16, 16, 1824  0          ['block7a_expand_bn[0][0]']
#  ivation)                       )
#
#  block7a_dwconv (DepthwiseConv2  (None, 16, 16, 1824  16416      ['block7a_expand_activation[0][0]
#  D)                             )                                ']
#
#  block7a_bn (BatchNormalization  (None, 16, 16, 1824  7296       ['block7a_dwconv[0][0]']
#  )                              )
#
#  block7a_activation (Activation  (None, 16, 16, 1824  0          ['block7a_bn[0][0]']
#  )                              )
#
#  block7a_se_squeeze (GlobalAver  (None, 1824)        0           ['block7a_activation[0][0]']
#  agePooling2D)
#
#  block7a_se_reshape (Reshape)   (None, 1, 1, 1824)   0           ['block7a_se_squeeze[0][0]']
#
#  block7a_se_reduce (Conv2D)     (None, 1, 1, 76)     138700      ['block7a_se_reshape[0][0]']
#
#  block7a_se_expand (Conv2D)     (None, 1, 1, 1824)   140448      ['block7a_se_reduce[0][0]']
#
#  block7a_se_excite (Multiply)   (None, 16, 16, 1824  0           ['block7a_activation[0][0]',
#                                 )                                 'block7a_se_expand[0][0]']
#
#  block7a_project_conv (Conv2D)  (None, 16, 16, 512)  933888      ['block7a_se_excite[0][0]']
#
#  block7a_project_bn (BatchNorma  (None, 16, 16, 512)  2048       ['block7a_project_conv[0][0]']
#  lization)
#
#  block7b_expand_conv (Conv2D)   (None, 16, 16, 3072  1572864     ['block7a_project_bn[0][0]']
#                                 )
#
#  block7b_expand_bn (BatchNormal  (None, 16, 16, 3072  12288      ['block7b_expand_conv[0][0]']
#  ization)                       )
#
#  block7b_expand_activation (Act  (None, 16, 16, 3072  0          ['block7b_expand_bn[0][0]']
#  ivation)                       )
#
#  block7b_dwconv (DepthwiseConv2  (None, 16, 16, 3072  27648      ['block7b_expand_activation[0][0]
#  D)                             )                                ']
#
#  block7b_bn (BatchNormalization  (None, 16, 16, 3072  12288      ['block7b_dwconv[0][0]']
#  )                              )
#
#  block7b_activation (Activation  (None, 16, 16, 3072  0          ['block7b_bn[0][0]']
#  )                              )
#
#  block7b_se_squeeze (GlobalAver  (None, 3072)        0           ['block7b_activation[0][0]']
#  agePooling2D)
#
#  block7b_se_reshape (Reshape)   (None, 1, 1, 3072)   0           ['block7b_se_squeeze[0][0]']
#
#  block7b_se_reduce (Conv2D)     (None, 1, 1, 128)    393344      ['block7b_se_reshape[0][0]']
#
#  block7b_se_expand (Conv2D)     (None, 1, 1, 3072)   396288      ['block7b_se_reduce[0][0]']
#
#  block7b_se_excite (Multiply)   (None, 16, 16, 3072  0           ['block7b_activation[0][0]',
#                                 )                                 'block7b_se_expand[0][0]']
#
#  block7b_project_conv (Conv2D)  (None, 16, 16, 512)  1572864     ['block7b_se_excite[0][0]']
#
#  block7b_project_bn (BatchNorma  (None, 16, 16, 512)  2048       ['block7b_project_conv[0][0]']
#  lization)
#
#  block7b_drop (Dropout)         (None, 16, 16, 512)  0           ['block7b_project_bn[0][0]']
#
#  block7b_add (Add)              (None, 16, 16, 512)  0           ['block7b_drop[0][0]',
#                                                                   'block7a_project_bn[0][0]']
#
#  block7c_expand_conv (Conv2D)   (None, 16, 16, 3072  1572864     ['block7b_add[0][0]']
#                                 )
#
#  block7c_expand_bn (BatchNormal  (None, 16, 16, 3072  12288      ['block7c_expand_conv[0][0]']
#  ization)                       )
#
#  block7c_expand_activation (Act  (None, 16, 16, 3072  0          ['block7c_expand_bn[0][0]']
#  ivation)                       )
#
#  block7c_dwconv (DepthwiseConv2  (None, 16, 16, 3072  27648      ['block7c_expand_activation[0][0]
#  D)                             )                                ']
#
#  block7c_bn (BatchNormalization  (None, 16, 16, 3072  12288      ['block7c_dwconv[0][0]']
#  )                              )
#
#  block7c_activation (Activation  (None, 16, 16, 3072  0          ['block7c_bn[0][0]']
#  )                              )
#
#  block7c_se_squeeze (GlobalAver  (None, 3072)        0           ['block7c_activation[0][0]']
#  agePooling2D)
#
#  block7c_se_reshape (Reshape)   (None, 1, 1, 3072)   0           ['block7c_se_squeeze[0][0]']
#
#  block7c_se_reduce (Conv2D)     (None, 1, 1, 128)    393344      ['block7c_se_reshape[0][0]']
#
#  block7c_se_expand (Conv2D)     (None, 1, 1, 3072)   396288      ['block7c_se_reduce[0][0]']
#
#  block7c_se_excite (Multiply)   (None, 16, 16, 3072  0           ['block7c_activation[0][0]',
#                                 )                                 'block7c_se_expand[0][0]']
#
#  block7c_project_conv (Conv2D)  (None, 16, 16, 512)  1572864     ['block7c_se_excite[0][0]']
#
#  block7c_project_bn (BatchNorma  (None, 16, 16, 512)  2048       ['block7c_project_conv[0][0]']
#  lization)
#
#  block7c_drop (Dropout)         (None, 16, 16, 512)  0           ['block7c_project_bn[0][0]']
#
#  block7c_add (Add)              (None, 16, 16, 512)  0           ['block7c_drop[0][0]',
#                                                                   'block7b_add[0][0]']
#
#  top_conv (Conv2D)              (None, 16, 16, 2048  1048576     ['block7c_add[0][0]']
#                                 )
#
#  top_bn (BatchNormalization)    (None, 16, 16, 2048  8192        ['top_conv[0][0]']
#                                 )
#
#  top_activation (Activation)    (None, 16, 16, 2048  0           ['top_bn[0][0]']
#                                 )
#
# ==================================================================================================
# Total params: 28,513,527
# Trainable params: 0
# Non-trainable params: 28,513,527
# __________________________________________________________________________________________________

# %%
7*7*2048
# Out:
# 100352

# %% [markdown]
# ### Add FC layer for new classes

# %%
model.output
# Out:
# <KerasTensor: shape=(None, 16, 16, 2048) dtype=float32 (created by layer 'top_activation')>

# %%
#get Output layer of Pre0trained model
x1 = model.output

#Global average pool to reduce number of features and Flatten the output
x2 = tf.keras.layers.GlobalAveragePooling2D()(x1)

# %%
#Output shape of Global Average Pooling
x2
# Out:
# <KerasTensor: shape=(None, 2048) dtype=float32 (created by layer 'global_average_pooling2d')>

# %%
#Add output layer
x3 = tf.keras.layers.Dense(2048, activation='relu', kernel_initializer='he_normal')(x2)
x4 = tf.keras.layers.Dropout(0.35)(x3)
prediction = tf.keras.layers.Dense(len(class_names),activation='softmax')(x4)

# %%
prediction
# Out:
# <KerasTensor: shape=(None, 196) dtype=float32 (created by layer 'dense_1')>

# %% [markdown]
# ### Building final model for Classification

# %%
#Using Keras Model class
final_model = tf.keras.models.Model(inputs=model.input, #Pre-trained model input as input layer
                                    outputs=prediction) #Output layer added

# %%
#Compile the model
final_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
#How does our overall model looks
final_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 500, 500, 3  0           []
#                                 )]
#
#  rescaling (Rescaling)          (None, 500, 500, 3)  0           ['input_1[0][0]']
#
#  normalization (Normalization)  (None, 500, 500, 3)  7           ['rescaling[0][0]']
#
#  stem_conv_pad (ZeroPadding2D)  (None, 501, 501, 3)  0           ['normalization[0][0]']
#
#  stem_conv (Conv2D)             (None, 250, 250, 48  1296        ['stem_conv_pad[0][0]']
#                                 )
#
#  stem_bn (BatchNormalization)   (None, 250, 250, 48  192         ['stem_conv[0][0]']
#                                 )
#
#  stem_activation (Activation)   (None, 250, 250, 48  0           ['stem_bn[0][0]']
#                                 )
#
#  block1a_dwconv (DepthwiseConv2  (None, 250, 250, 48  432        ['stem_activation[0][0]']
#  D)                             )
#
#  block1a_bn (BatchNormalization  (None, 250, 250, 48  192        ['block1a_dwconv[0][0]']
#  )                              )
#
#  block1a_activation (Activation  (None, 250, 250, 48  0          ['block1a_bn[0][0]']
#  )                              )
#
#  block1a_se_squeeze (GlobalAver  (None, 48)          0           ['block1a_activation[0][0]']
#  agePooling2D)
#
#  block1a_se_reshape (Reshape)   (None, 1, 1, 48)     0           ['block1a_se_squeeze[0][0]']
#
#  block1a_se_reduce (Conv2D)     (None, 1, 1, 12)     588         ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)     (None, 1, 1, 48)     624         ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multiply)   (None, 250, 250, 48  0           ['block1a_activation[0][0]',
#                                 )                                 'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv2D)  (None, 250, 250, 24  1152        ['block1a_se_excite[0][0]']
#                                 )
#
#  block1a_project_bn (BatchNorma  (None, 250, 250, 24  96         ['block1a_project_conv[0][0]']
#  lization)                      )
#
#  block1b_dwconv (DepthwiseConv2  (None, 250, 250, 24  216        ['block1a_project_bn[0][0]']
#  D)                             )
#
#  block1b_bn (BatchNormalization  (None, 250, 250, 24  96         ['block1b_dwconv[0][0]']
#  )                              )
#
#  block1b_activation (Activation  (None, 250, 250, 24  0          ['block1b_bn[0][0]']
#  )                              )
#
#  block1b_se_squeeze (GlobalAver  (None, 24)          0           ['block1b_activation[0][0]']
#  agePooling2D)
#
#  block1b_se_reshape (Reshape)   (None, 1, 1, 24)     0           ['block1b_se_squeeze[0][0]']
#
#  block1b_se_reduce (Conv2D)     (None, 1, 1, 6)      150         ['block1b_se_reshape[0][0]']
#
#  block1b_se_expand (Conv2D)     (None, 1, 1, 24)     168         ['block1b_se_reduce[0][0]']
#
#  block1b_se_excite (Multiply)   (None, 250, 250, 24  0           ['block1b_activation[0][0]',
#                                 )                                 'block1b_se_expand[0][0]']
#
#  block1b_project_conv (Conv2D)  (None, 250, 250, 24  576         ['block1b_se_excite[0][0]']
#                                 )
#
#  block1b_project_bn (BatchNorma  (None, 250, 250, 24  96         ['block1b_project_conv[0][0]']
#  lization)                      )
#
#  block1b_drop (Dropout)         (None, 250, 250, 24  0           ['block1b_project_bn[0][0]']
#                                 )
#
#  block1b_add (Add)              (None, 250, 250, 24  0           ['block1b_drop[0][0]',
#                                 )                                 'block1a_project_bn[0][0]']
#
#  block1c_dwconv (DepthwiseConv2  (None, 250, 250, 24  216        ['block1b_add[0][0]']
#  D)                             )
#
#  block1c_bn (BatchNormalization  (None, 250, 250, 24  96         ['block1c_dwconv[0][0]']
#  )                              )
#
#  block1c_activation (Activation  (None, 250, 250, 24  0          ['block1c_bn[0][0]']
#  )                              )
#
#  block1c_se_squeeze (GlobalAver  (None, 24)          0           ['block1c_activation[0][0]']
#  agePooling2D)
#
#  block1c_se_reshape (Reshape)   (None, 1, 1, 24)     0           ['block1c_se_squeeze[0][0]']
#
#  block1c_se_reduce (Conv2D)     (None, 1, 1, 6)      150         ['block1c_se_reshape[0][0]']
#
#  block1c_se_expand (Conv2D)     (None, 1, 1, 24)     168         ['block1c_se_reduce[0][0]']
#
#  block1c_se_excite (Multiply)   (None, 250, 250, 24  0           ['block1c_activation[0][0]',
#                                 )                                 'block1c_se_expand[0][0]']
#
#  block1c_project_conv (Conv2D)  (None, 250, 250, 24  576         ['block1c_se_excite[0][0]']
#                                 )
#
#  block1c_project_bn (BatchNorma  (None, 250, 250, 24  96         ['block1c_project_conv[0][0]']
#  lization)                      )
#
#  block1c_drop (Dropout)         (None, 250, 250, 24  0           ['block1c_project_bn[0][0]']
#                                 )
#
#  block1c_add (Add)              (None, 250, 250, 24  0           ['block1c_drop[0][0]',
#                                 )                                 'block1b_add[0][0]']
#
#  block2a_expand_conv (Conv2D)   (None, 250, 250, 14  3456        ['block1c_add[0][0]']
#                                 4)
#
#  block2a_expand_bn (BatchNormal  (None, 250, 250, 14  576        ['block2a_expand_conv[0][0]']
#  ization)                       4)
#
#  block2a_expand_activation (Act  (None, 250, 250, 14  0          ['block2a_expand_bn[0][0]']
#  ivation)                       4)
#
#  block2a_dwconv_pad (ZeroPaddin  (None, 251, 251, 14  0          ['block2a_expand_activation[0][0]
#  g2D)                           4)                               ']
#
#  block2a_dwconv (DepthwiseConv2  (None, 125, 125, 14  1296       ['block2a_dwconv_pad[0][0]']
#  D)                             4)
#
#  block2a_bn (BatchNormalization  (None, 125, 125, 14  576        ['block2a_dwconv[0][0]']
#  )                              4)
#
#  block2a_activation (Activation  (None, 125, 125, 14  0          ['block2a_bn[0][0]']
#  )                              4)
#
#  block2a_se_squeeze (GlobalAver  (None, 144)         0           ['block2a_activation[0][0]']
#  agePooling2D)
#
#  block2a_se_reshape (Reshape)   (None, 1, 1, 144)    0           ['block2a_se_squeeze[0][0]']
#
#  block2a_se_reduce (Conv2D)     (None, 1, 1, 6)      870         ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)     (None, 1, 1, 144)    1008        ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multiply)   (None, 125, 125, 14  0           ['block2a_activation[0][0]',
#                                 4)                                'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv2D)  (None, 125, 125, 40  5760        ['block2a_se_excite[0][0]']
#                                 )
#
#  block2a_project_bn (BatchNorma  (None, 125, 125, 40  160        ['block2a_project_conv[0][0]']
#  lization)                      )
#
#  block2b_expand_conv (Conv2D)   (None, 125, 125, 24  9600        ['block2a_project_bn[0][0]']
#                                 0)
#
#  block2b_expand_bn (BatchNormal  (None, 125, 125, 24  960        ['block2b_expand_conv[0][0]']
#  ization)                       0)
#
#  block2b_expand_activation (Act  (None, 125, 125, 24  0          ['block2b_expand_bn[0][0]']
#  ivation)                       0)
#
#  block2b_dwconv (DepthwiseConv2  (None, 125, 125, 24  2160       ['block2b_expand_activation[0][0]
#  D)                             0)                               ']
#
#  block2b_bn (BatchNormalization  (None, 125, 125, 24  960        ['block2b_dwconv[0][0]']
#  )                              0)
#
#  block2b_activation (Activation  (None, 125, 125, 24  0          ['block2b_bn[0][0]']
#  )                              0)
#
#  block2b_se_squeeze (GlobalAver  (None, 240)         0           ['block2b_activation[0][0]']
#  agePooling2D)
#
#  block2b_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block2b_se_squeeze[0][0]']
#
#  block2b_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multiply)   (None, 125, 125, 24  0           ['block2b_activation[0][0]',
#                                 0)                                'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv2D)  (None, 125, 125, 40  9600        ['block2b_se_excite[0][0]']
#                                 )
#
#  block2b_project_bn (BatchNorma  (None, 125, 125, 40  160        ['block2b_project_conv[0][0]']
#  lization)                      )
#
#  block2b_drop (Dropout)         (None, 125, 125, 40  0           ['block2b_project_bn[0][0]']
#                                 )
#
#  block2b_add (Add)              (None, 125, 125, 40  0           ['block2b_drop[0][0]',
#                                 )                                 'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2D)   (None, 125, 125, 24  9600        ['block2b_add[0][0]']
#                                 0)
#
#  block2c_expand_bn (BatchNormal  (None, 125, 125, 24  960        ['block2c_expand_conv[0][0]']
#  ization)                       0)
#
#  block2c_expand_activation (Act  (None, 125, 125, 24  0          ['block2c_expand_bn[0][0]']
#  ivation)                       0)
#
#  block2c_dwconv (DepthwiseConv2  (None, 125, 125, 24  2160       ['block2c_expand_activation[0][0]
#  D)                             0)                               ']
#
#  block2c_bn (BatchNormalization  (None, 125, 125, 24  960        ['block2c_dwconv[0][0]']
#  )                              0)
#
#  block2c_activation (Activation  (None, 125, 125, 24  0          ['block2c_bn[0][0]']
#  )                              0)
#
#  block2c_se_squeeze (GlobalAver  (None, 240)         0           ['block2c_activation[0][0]']
#  agePooling2D)
#
#  block2c_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block2c_se_squeeze[0][0]']
#
#  block2c_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block2c_se_reshape[0][0]']
#
#  block2c_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block2c_se_reduce[0][0]']
#
#  block2c_se_excite (Multiply)   (None, 125, 125, 24  0           ['block2c_activation[0][0]',
#                                 0)                                'block2c_se_expand[0][0]']
#
#  block2c_project_conv (Conv2D)  (None, 125, 125, 40  9600        ['block2c_se_excite[0][0]']
#                                 )
#
#  block2c_project_bn (BatchNorma  (None, 125, 125, 40  160        ['block2c_project_conv[0][0]']
#  lization)                      )
#
#  block2c_drop (Dropout)         (None, 125, 125, 40  0           ['block2c_project_bn[0][0]']
#                                 )
#
#  block2c_add (Add)              (None, 125, 125, 40  0           ['block2c_drop[0][0]',
#                                 )                                 'block2b_add[0][0]']
#
#  block2d_expand_conv (Conv2D)   (None, 125, 125, 24  9600        ['block2c_add[0][0]']
#                                 0)
#
#  block2d_expand_bn (BatchNormal  (None, 125, 125, 24  960        ['block2d_expand_conv[0][0]']
#  ization)                       0)
#
#  block2d_expand_activation (Act  (None, 125, 125, 24  0          ['block2d_expand_bn[0][0]']
#  ivation)                       0)
#
#  block2d_dwconv (DepthwiseConv2  (None, 125, 125, 24  2160       ['block2d_expand_activation[0][0]
#  D)                             0)                               ']
#
#  block2d_bn (BatchNormalization  (None, 125, 125, 24  960        ['block2d_dwconv[0][0]']
#  )                              0)
#
#  block2d_activation (Activation  (None, 125, 125, 24  0          ['block2d_bn[0][0]']
#  )                              0)
#
#  block2d_se_squeeze (GlobalAver  (None, 240)         0           ['block2d_activation[0][0]']
#  agePooling2D)
#
#  block2d_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block2d_se_squeeze[0][0]']
#
#  block2d_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block2d_se_reshape[0][0]']
#
#  block2d_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block2d_se_reduce[0][0]']
#
#  block2d_se_excite (Multiply)   (None, 125, 125, 24  0           ['block2d_activation[0][0]',
#                                 0)                                'block2d_se_expand[0][0]']
#
#  block2d_project_conv (Conv2D)  (None, 125, 125, 40  9600        ['block2d_se_excite[0][0]']
#                                 )
#
#  block2d_project_bn (BatchNorma  (None, 125, 125, 40  160        ['block2d_project_conv[0][0]']
#  lization)                      )
#
#  block2d_drop (Dropout)         (None, 125, 125, 40  0           ['block2d_project_bn[0][0]']
#                                 )
#
#  block2d_add (Add)              (None, 125, 125, 40  0           ['block2d_drop[0][0]',
#                                 )                                 'block2c_add[0][0]']
#
#  block2e_expand_conv (Conv2D)   (None, 125, 125, 24  9600        ['block2d_add[0][0]']
#                                 0)
#
#  block2e_expand_bn (BatchNormal  (None, 125, 125, 24  960        ['block2e_expand_conv[0][0]']
#  ization)                       0)
#
#  block2e_expand_activation (Act  (None, 125, 125, 24  0          ['block2e_expand_bn[0][0]']
#  ivation)                       0)
#
#  block2e_dwconv (DepthwiseConv2  (None, 125, 125, 24  2160       ['block2e_expand_activation[0][0]
#  D)                             0)                               ']
#
#  block2e_bn (BatchNormalization  (None, 125, 125, 24  960        ['block2e_dwconv[0][0]']
#  )                              0)
#
#  block2e_activation (Activation  (None, 125, 125, 24  0          ['block2e_bn[0][0]']
#  )                              0)
#
#  block2e_se_squeeze (GlobalAver  (None, 240)         0           ['block2e_activation[0][0]']
#  agePooling2D)
#
#  block2e_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block2e_se_squeeze[0][0]']
#
#  block2e_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block2e_se_reshape[0][0]']
#
#  block2e_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block2e_se_reduce[0][0]']
#
#  block2e_se_excite (Multiply)   (None, 125, 125, 24  0           ['block2e_activation[0][0]',
#                                 0)                                'block2e_se_expand[0][0]']
#
#  block2e_project_conv (Conv2D)  (None, 125, 125, 40  9600        ['block2e_se_excite[0][0]']
#                                 )
#
#  block2e_project_bn (BatchNorma  (None, 125, 125, 40  160        ['block2e_project_conv[0][0]']
#  lization)                      )
#
#  block2e_drop (Dropout)         (None, 125, 125, 40  0           ['block2e_project_bn[0][0]']
#                                 )
#
#  block2e_add (Add)              (None, 125, 125, 40  0           ['block2e_drop[0][0]',
#                                 )                                 'block2d_add[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, 125, 125, 24  9600        ['block2e_add[0][0]']
#                                 0)
#
#  block3a_expand_bn (BatchNormal  (None, 125, 125, 24  960        ['block3a_expand_conv[0][0]']
#  ization)                       0)
#
#  block3a_expand_activation (Act  (None, 125, 125, 24  0          ['block3a_expand_bn[0][0]']
#  ivation)                       0)
#
#  block3a_dwconv_pad (ZeroPaddin  (None, 129, 129, 24  0          ['block3a_expand_activation[0][0]
#  g2D)                           0)                               ']
#
#  block3a_dwconv (DepthwiseConv2  (None, 63, 63, 240)  6000       ['block3a_dwconv_pad[0][0]']
#  D)
#
#  block3a_bn (BatchNormalization  (None, 63, 63, 240)  960        ['block3a_dwconv[0][0]']
#  )
#
#  block3a_activation (Activation  (None, 63, 63, 240)  0          ['block3a_bn[0][0]']
#  )
#
#  block3a_se_squeeze (GlobalAver  (None, 240)         0           ['block3a_activation[0][0]']
#  agePooling2D)
#
#  block3a_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block3a_se_squeeze[0][0]']
#
#  block3a_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multiply)   (None, 63, 63, 240)  0           ['block3a_activation[0][0]',
#                                                                   'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv2D)  (None, 63, 63, 64)   15360       ['block3a_se_excite[0][0]']
#
#  block3a_project_bn (BatchNorma  (None, 63, 63, 64)  256         ['block3a_project_conv[0][0]']
#  lization)
#
#  block3b_expand_conv (Conv2D)   (None, 63, 63, 384)  24576       ['block3a_project_bn[0][0]']
#
#  block3b_expand_bn (BatchNormal  (None, 63, 63, 384)  1536       ['block3b_expand_conv[0][0]']
#  ization)
#
#  block3b_expand_activation (Act  (None, 63, 63, 384)  0          ['block3b_expand_bn[0][0]']
#  ivation)
#
#  block3b_dwconv (DepthwiseConv2  (None, 63, 63, 384)  9600       ['block3b_expand_activation[0][0]
#  D)                                                              ']
#
#  block3b_bn (BatchNormalization  (None, 63, 63, 384)  1536       ['block3b_dwconv[0][0]']
#  )
#
#  block3b_activation (Activation  (None, 63, 63, 384)  0          ['block3b_bn[0][0]']
#  )
#
#  block3b_se_squeeze (GlobalAver  (None, 384)         0           ['block3b_activation[0][0]']
#  agePooling2D)
#
#  block3b_se_reshape (Reshape)   (None, 1, 1, 384)    0           ['block3b_se_squeeze[0][0]']
#
#  block3b_se_reduce (Conv2D)     (None, 1, 1, 16)     6160        ['block3b_se_reshape[0][0]']
#
#  block3b_se_expand (Conv2D)     (None, 1, 1, 384)    6528        ['block3b_se_reduce[0][0]']
#
#  block3b_se_excite (Multiply)   (None, 63, 63, 384)  0           ['block3b_activation[0][0]',
#                                                                   'block3b_se_expand[0][0]']
#
#  block3b_project_conv (Conv2D)  (None, 63, 63, 64)   24576       ['block3b_se_excite[0][0]']
#
#  block3b_project_bn (BatchNorma  (None, 63, 63, 64)  256         ['block3b_project_conv[0][0]']
#  lization)
#
#  block3b_drop (Dropout)         (None, 63, 63, 64)   0           ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)              (None, 63, 63, 64)   0           ['block3b_drop[0][0]',
#                                                                   'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2D)   (None, 63, 63, 384)  24576       ['block3b_add[0][0]']
#
#  block3c_expand_bn (BatchNormal  (None, 63, 63, 384)  1536       ['block3c_expand_conv[0][0]']
#  ization)
#
#  block3c_expand_activation (Act  (None, 63, 63, 384)  0          ['block3c_expand_bn[0][0]']
#  ivation)
#
#  block3c_dwconv (DepthwiseConv2  (None, 63, 63, 384)  9600       ['block3c_expand_activation[0][0]
#  D)                                                              ']
#
#  block3c_bn (BatchNormalization  (None, 63, 63, 384)  1536       ['block3c_dwconv[0][0]']
#  )
#
#  block3c_activation (Activation  (None, 63, 63, 384)  0          ['block3c_bn[0][0]']
#  )
#
#  block3c_se_squeeze (GlobalAver  (None, 384)         0           ['block3c_activation[0][0]']
#  agePooling2D)
#
#  block3c_se_reshape (Reshape)   (None, 1, 1, 384)    0           ['block3c_se_squeeze[0][0]']
#
#  block3c_se_reduce (Conv2D)     (None, 1, 1, 16)     6160        ['block3c_se_reshape[0][0]']
#
#  block3c_se_expand (Conv2D)     (None, 1, 1, 384)    6528        ['block3c_se_reduce[0][0]']
#
#  block3c_se_excite (Multiply)   (None, 63, 63, 384)  0           ['block3c_activation[0][0]',
#                                                                   'block3c_se_expand[0][0]']
#
#  block3c_project_conv (Conv2D)  (None, 63, 63, 64)   24576       ['block3c_se_excite[0][0]']
#
#  block3c_project_bn (BatchNorma  (None, 63, 63, 64)  256         ['block3c_project_conv[0][0]']
#  lization)
#
#  block3c_drop (Dropout)         (None, 63, 63, 64)   0           ['block3c_project_bn[0][0]']
#
#  block3c_add (Add)              (None, 63, 63, 64)   0           ['block3c_drop[0][0]',
#                                                                   'block3b_add[0][0]']
#
#  block3d_expand_conv (Conv2D)   (None, 63, 63, 384)  24576       ['block3c_add[0][0]']
#
#  block3d_expand_bn (BatchNormal  (None, 63, 63, 384)  1536       ['block3d_expand_conv[0][0]']
#  ization)
#
#  block3d_expand_activation (Act  (None, 63, 63, 384)  0          ['block3d_expand_bn[0][0]']
#  ivation)
#
#  block3d_dwconv (DepthwiseConv2  (None, 63, 63, 384)  9600       ['block3d_expand_activation[0][0]
#  D)                                                              ']
#
#  block3d_bn (BatchNormalization  (None, 63, 63, 384)  1536       ['block3d_dwconv[0][0]']
#  )
#
#  block3d_activation (Activation  (None, 63, 63, 384)  0          ['block3d_bn[0][0]']
#  )
#
#  block3d_se_squeeze (GlobalAver  (None, 384)         0           ['block3d_activation[0][0]']
#  agePooling2D)
#
#  block3d_se_reshape (Reshape)   (None, 1, 1, 384)    0           ['block3d_se_squeeze[0][0]']
#
#  block3d_se_reduce (Conv2D)     (None, 1, 1, 16)     6160        ['block3d_se_reshape[0][0]']
#
#  block3d_se_expand (Conv2D)     (None, 1, 1, 384)    6528        ['block3d_se_reduce[0][0]']
#
#  block3d_se_excite (Multiply)   (None, 63, 63, 384)  0           ['block3d_activation[0][0]',
#                                                                   'block3d_se_expand[0][0]']
#
#  block3d_project_conv (Conv2D)  (None, 63, 63, 64)   24576       ['block3d_se_excite[0][0]']
#
#  block3d_project_bn (BatchNorma  (None, 63, 63, 64)  256         ['block3d_project_conv[0][0]']
#  lization)
#
#  block3d_drop (Dropout)         (None, 63, 63, 64)   0           ['block3d_project_bn[0][0]']
#
#  block3d_add (Add)              (None, 63, 63, 64)   0           ['block3d_drop[0][0]',
#                                                                   'block3c_add[0][0]']
#
#  block3e_expand_conv (Conv2D)   (None, 63, 63, 384)  24576       ['block3d_add[0][0]']
#
#  block3e_expand_bn (BatchNormal  (None, 63, 63, 384)  1536       ['block3e_expand_conv[0][0]']
#  ization)
#
#  block3e_expand_activation (Act  (None, 63, 63, 384)  0          ['block3e_expand_bn[0][0]']
#  ivation)
#
# ...
#  )                              )
#
#  block6i_se_squeeze (GlobalAver  (None, 1824)        0           ['block6i_activation[0][0]']
#  agePooling2D)
#
#  block6i_se_reshape (Reshape)   (None, 1, 1, 1824)   0           ['block6i_se_squeeze[0][0]']
#
#  block6i_se_reduce (Conv2D)     (None, 1, 1, 76)     138700      ['block6i_se_reshape[0][0]']
#
#  block6i_se_expand (Conv2D)     (None, 1, 1, 1824)   140448      ['block6i_se_reduce[0][0]']
#
#  block6i_se_excite (Multiply)   (None, 16, 16, 1824  0           ['block6i_activation[0][0]',
#                                 )                                 'block6i_se_expand[0][0]']
#
#  block6i_project_conv (Conv2D)  (None, 16, 16, 304)  554496      ['block6i_se_excite[0][0]']
#
#  block6i_project_bn (BatchNorma  (None, 16, 16, 304)  1216       ['block6i_project_conv[0][0]']
#  lization)
#
#  block6i_drop (Dropout)         (None, 16, 16, 304)  0           ['block6i_project_bn[0][0]']
#
#  block6i_add (Add)              (None, 16, 16, 304)  0           ['block6i_drop[0][0]',
#                                                                   'block6h_add[0][0]']
#
#  block7a_expand_conv (Conv2D)   (None, 16, 16, 1824  554496      ['block6i_add[0][0]']
#                                 )
#
#  block7a_expand_bn (BatchNormal  (None, 16, 16, 1824  7296       ['block7a_expand_conv[0][0]']
#  ization)                       )
#
#  block7a_expand_activation (Act  (None, 16, 16, 1824  0          ['block7a_expand_bn[0][0]']
#  ivation)                       )
#
#  block7a_dwconv (DepthwiseConv2  (None, 16, 16, 1824  16416      ['block7a_expand_activation[0][0]
#  D)                             )                                ']
#
#  block7a_bn (BatchNormalization  (None, 16, 16, 1824  7296       ['block7a_dwconv[0][0]']
#  )                              )
#
#  block7a_activation (Activation  (None, 16, 16, 1824  0          ['block7a_bn[0][0]']
#  )                              )
#
#  block7a_se_squeeze (GlobalAver  (None, 1824)        0           ['block7a_activation[0][0]']
#  agePooling2D)
#
#  block7a_se_reshape (Reshape)   (None, 1, 1, 1824)   0           ['block7a_se_squeeze[0][0]']
#
#  block7a_se_reduce (Conv2D)     (None, 1, 1, 76)     138700      ['block7a_se_reshape[0][0]']
#
#  block7a_se_expand (Conv2D)     (None, 1, 1, 1824)   140448      ['block7a_se_reduce[0][0]']
#
#  block7a_se_excite (Multiply)   (None, 16, 16, 1824  0           ['block7a_activation[0][0]',
#                                 )                                 'block7a_se_expand[0][0]']
#
#  block7a_project_conv (Conv2D)  (None, 16, 16, 512)  933888      ['block7a_se_excite[0][0]']
#
#  block7a_project_bn (BatchNorma  (None, 16, 16, 512)  2048       ['block7a_project_conv[0][0]']
#  lization)
#
#  block7b_expand_conv (Conv2D)   (None, 16, 16, 3072  1572864     ['block7a_project_bn[0][0]']
#                                 )
#
#  block7b_expand_bn (BatchNormal  (None, 16, 16, 3072  12288      ['block7b_expand_conv[0][0]']
#  ization)                       )
#
#  block7b_expand_activation (Act  (None, 16, 16, 3072  0          ['block7b_expand_bn[0][0]']
#  ivation)                       )
#
#  block7b_dwconv (DepthwiseConv2  (None, 16, 16, 3072  27648      ['block7b_expand_activation[0][0]
#  D)                             )                                ']
#
#  block7b_bn (BatchNormalization  (None, 16, 16, 3072  12288      ['block7b_dwconv[0][0]']
#  )                              )
#
#  block7b_activation (Activation  (None, 16, 16, 3072  0          ['block7b_bn[0][0]']
#  )                              )
#
#  block7b_se_squeeze (GlobalAver  (None, 3072)        0           ['block7b_activation[0][0]']
#  agePooling2D)
#
#  block7b_se_reshape (Reshape)   (None, 1, 1, 3072)   0           ['block7b_se_squeeze[0][0]']
#
#  block7b_se_reduce (Conv2D)     (None, 1, 1, 128)    393344      ['block7b_se_reshape[0][0]']
#
#  block7b_se_expand (Conv2D)     (None, 1, 1, 3072)   396288      ['block7b_se_reduce[0][0]']
#
#  block7b_se_excite (Multiply)   (None, 16, 16, 3072  0           ['block7b_activation[0][0]',
#                                 )                                 'block7b_se_expand[0][0]']
#
#  block7b_project_conv (Conv2D)  (None, 16, 16, 512)  1572864     ['block7b_se_excite[0][0]']
#
#  block7b_project_bn (BatchNorma  (None, 16, 16, 512)  2048       ['block7b_project_conv[0][0]']
#  lization)
#
#  block7b_drop (Dropout)         (None, 16, 16, 512)  0           ['block7b_project_bn[0][0]']
#
#  block7b_add (Add)              (None, 16, 16, 512)  0           ['block7b_drop[0][0]',
#                                                                   'block7a_project_bn[0][0]']
#
#  block7c_expand_conv (Conv2D)   (None, 16, 16, 3072  1572864     ['block7b_add[0][0]']
#                                 )
#
#  block7c_expand_bn (BatchNormal  (None, 16, 16, 3072  12288      ['block7c_expand_conv[0][0]']
#  ization)                       )
#
#  block7c_expand_activation (Act  (None, 16, 16, 3072  0          ['block7c_expand_bn[0][0]']
#  ivation)                       )
#
#  block7c_dwconv (DepthwiseConv2  (None, 16, 16, 3072  27648      ['block7c_expand_activation[0][0]
#  D)                             )                                ']
#
#  block7c_bn (BatchNormalization  (None, 16, 16, 3072  12288      ['block7c_dwconv[0][0]']
#  )                              )
#
#  block7c_activation (Activation  (None, 16, 16, 3072  0          ['block7c_bn[0][0]']
#  )                              )
#
#  block7c_se_squeeze (GlobalAver  (None, 3072)        0           ['block7c_activation[0][0]']
#  agePooling2D)
#
#  block7c_se_reshape (Reshape)   (None, 1, 1, 3072)   0           ['block7c_se_squeeze[0][0]']
#
#  block7c_se_reduce (Conv2D)     (None, 1, 1, 128)    393344      ['block7c_se_reshape[0][0]']
#
#  block7c_se_expand (Conv2D)     (None, 1, 1, 3072)   396288      ['block7c_se_reduce[0][0]']
#
#  block7c_se_excite (Multiply)   (None, 16, 16, 3072  0           ['block7c_activation[0][0]',
#                                 )                                 'block7c_se_expand[0][0]']
#
#  block7c_project_conv (Conv2D)  (None, 16, 16, 512)  1572864     ['block7c_se_excite[0][0]']
#
#  block7c_project_bn (BatchNorma  (None, 16, 16, 512)  2048       ['block7c_project_conv[0][0]']
#  lization)
#
#  block7c_drop (Dropout)         (None, 16, 16, 512)  0           ['block7c_project_bn[0][0]']
#
#  block7c_add (Add)              (None, 16, 16, 512)  0           ['block7c_drop[0][0]',
#                                                                   'block7b_add[0][0]']
#
#  top_conv (Conv2D)              (None, 16, 16, 2048  1048576     ['block7c_add[0][0]']
#                                 )
#
#  top_bn (BatchNormalization)    (None, 16, 16, 2048  8192        ['top_conv[0][0]']
#                                 )
#
#  top_activation (Activation)    (None, 16, 16, 2048  0           ['top_bn[0][0]']
#                                 )
#
#  global_average_pooling2d (Glob  (None, 2048)        0           ['top_activation[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 2048)         4196352     ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dropout (Dropout)              (None, 2048)         0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 196)          401604      ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 33,111,483
# Trainable params: 4,597,956
# Non-trainable params: 28,513,527
# __________________________________________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
#Saving the best model using model checkpoint callback
model_checkpoint=tf.keras.callbacks.ModelCheckpoint('cars_EfficientNetB5.h5', 
                                                    save_best_only=True, 
                                                    monitor='val_accuracy', 
                                                    mode='max', 
                                                    verbose=1)

# %%
final_model.fit(train_generator,
                epochs=50,
                steps_per_epoch= 6515//64,
                validation_data=test_generator,
                validation_steps = 1629//64, 
                callbacks=[model_checkpoint])
# Out:
# Epoch 1/50
# 101/101 [==============================] - ETA: 0s - loss: 4.4561 - accuracy: 0.0760
# Epoch 00001: val_accuracy improved from -inf to 0.15563, saving model to cars_EfficientNetB5.h5
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# 101/101 [==============================] - 2768s 27s/step - loss: 4.4561 - accuracy: 0.0760 - val_loss: 3.6587 - val_accuracy: 0.1556
# Epoch 2/50
# 101/101 [==============================] - ETA: 0s - loss: 3.3488 - accuracy: 0.2147
# Epoch 00002: val_accuracy improved from 0.15563 to 0.21750, saving model to cars_EfficientNetB5.h5
# 101/101 [==============================] - 140s 1s/step - loss: 3.3488 - accuracy: 0.2147 - val_loss: 3.2497 - val_accuracy: 0.2175
# Epoch 3/50
# 101/101 [==============================] - ETA: 0s - loss: 2.8327 - accuracy: 0.3012
# Epoch 00003: val_accuracy improved from 0.21750 to 0.26500, saving model to cars_EfficientNetB5.h5
# 101/101 [==============================] - 140s 1s/step - loss: 2.8327 - accuracy: 0.3012 - val_loss: 2.9933 - val_accuracy: 0.2650
# Epoch 4/50
# 101/101 [==============================] - ETA: 0s - loss: 2.4488 - accuracy: 0.3838
# Epoch 00004: val_accuracy improved from 0.26500 to 0.32063, saving model to cars_EfficientNetB5.h5
# 101/101 [==============================] - 139s 1s/step - loss: 2.4488 - accuracy: 0.3838 - val_loss: 2.7214 - val_accuracy: 0.3206
# Epoch 5/50
# 101/101 [==============================] - ETA: 0s - loss: 2.1501 - accuracy: 0.4432
# Epoch 00005: val_accuracy improved from 0.32063 to 0.34312, saving model to cars_EfficientNetB5.h5
# 101/101 [==============================] - 139s 1s/step - loss: 2.1501 - accuracy: 0.4432 - val_loss: 2.6388 - val_accuracy: 0.3431
# Epoch 6/50
# 101/101 [==============================] - ETA: 0s - loss: 1.8988 - accuracy: 0.4978
# Epoch 00006: val_accuracy improved from 0.34312 to 0.35313, saving model to cars_EfficientNetB5.h5
# 101/101 [==============================] - 139s 1s/step - loss: 1.8988 - accuracy: 0.4978 - val_loss: 2.5438 - val_accuracy: 0.3531
# Epoch 7/50
# 101/101 [==============================] - ETA: 0s - loss: 1.6999 - accuracy: 0.5337
# Epoch 00007: val_accuracy improved from 0.35313 to 0.36625, saving model to cars_EfficientNetB5.h5
# 101/101 [==============================] - 140s 1s/step - loss: 1.6999 - accuracy: 0.5337 - val_loss: 2.5230 - val_accuracy: 0.3663
# Epoch 8/50
# 101/101 [==============================] - ETA: 0s - loss: 1.5094 - accuracy: 0.5996
# Epoch 00008: val_accuracy improved from 0.36625 to 0.38500, saving model to cars_EfficientNetB5.h5
# 101/101 [==============================] - 140s 1s/step - loss: 1.5094 - accuracy: 0.5996 - val_loss: 2.4513 - val_accuracy: 0.3850
# Epoch 9/50
# 101/101 [==============================] - ETA: 0s - loss: 1.4053 - accuracy: 0.6070
# Epoch 00009: val_accuracy improved from 0.38500 to 0.39125, saving model to cars_EfficientNetB5.h5
# 101/101 [==============================] - 140s 1s/step - loss: 1.4053 - accuracy: 0.6070 - val_loss: 2.4286 - val_accuracy: 0.3913
# Epoch 10/50
# 101/101 [==============================] - ETA: 0s - loss: 1.2877 - accuracy: 0.6394
# Epoch 00010: val_accuracy improved from 0.39125 to 0.39625, saving model to cars_EfficientNetB5.h5
# 101/101 [==============================] - 139s 1s/step - loss: 1.2877 - accuracy: 0.6394 - val_loss: 2.4536 - val_accuracy: 0.3963
# Epoch 11/50
# 101/101 [==============================] - ETA: 0s - loss: 1.1747 - accuracy: 0.6728
# Epoch 00011: val_accuracy improved from 0.39625 to 0.40938, saving model to cars_EfficientNetB5.h5
# 101/101 [==============================] - 140s 1s/step - loss: 1.1747 - accuracy: 0.6728 - val_loss: 2.4556 - val_accuracy: 0.4094
# Epoch 12/50
# 101/101 [==============================] - ETA: 0s - loss: 1.0902 - accuracy: 0.6906
# Epoch 00012: val_accuracy improved from 0.40938 to 0.41688, saving model to cars_EfficientNetB5.h5
# 101/101 [==============================] - 139s 1s/step - loss: 1.0902 - accuracy: 0.6906 - val_loss: 2.3930 - val_accuracy: 0.4169
# Epoch 13/50
# 101/101 [==============================] - ETA: 0s - loss: 1.0113 - accuracy: 0.7134
# Epoch 00013: val_accuracy improved from 0.41688 to 0.42063, saving model to cars_EfficientNetB5.h5
# 101/101 [==============================] - 139s 1s/step - loss: 1.0113 - accuracy: 0.7134 - val_loss: 2.4116 - val_accuracy: 0.4206
# Epoch 14/50
# 101/101 [==============================] - ETA: 0s - loss: 0.9543 - accuracy: 0.7216
# Epoch 00014: val_accuracy did not improve from 0.42063
# 101/101 [==============================] - 138s 1s/step - loss: 0.9543 - accuracy: 0.7216 - val_loss: 2.4003 - val_accuracy: 0.4169
# Epoch 15/50
# 101/101 [==============================] - ETA: 0s - loss: 0.8800 - accuracy: 0.7478
# Epoch 00015: val_accuracy did not improve from 0.42063
# 101/101 [==============================] - 139s 1s/step - loss: 0.8800 - accuracy: 0.7478 - val_loss: 2.4095 - val_accuracy: 0.4187
# Epoch 16/50
# 101/101 [==============================] - ETA: 0s - loss: 0.7951 - accuracy: 0.7726
# Epoch 00016: val_accuracy did not improve from 0.42063
# 101/101 [==============================] - 138s 1s/step - loss: 0.7951 - accuracy: 0.7726 - val_loss: 2.4381 - val_accuracy: 0.4194
# Epoch 17/50
# 101/101 [==============================] - ETA: 0s - loss: 0.7706 - accuracy: 0.7758
# Epoch 00017: val_accuracy improved from 0.42063 to 0.42125, saving model to cars_EfficientNetB5.h5
# 101/101 [==============================] - 140s 1s/step - loss: 0.7706 - accuracy: 0.7758 - val_loss: 2.4097 - val_accuracy: 0.4212
# Epoch 18/50
# 101/101 [==============================] - ETA: 0s - loss: 0.7262 - accuracy: 0.7906
# Epoch 00018: val_accuracy did not improve from 0.42125
# 101/101 [==============================] - 138s 1s/step - loss: 0.7262 - accuracy: 0.7906 - val_loss: 2.4803 - val_accuracy: 0.4169
# Epoch 19/50
# 101/101 [==============================] - ETA: 0s - loss: 0.6921 - accuracy: 0.7973
# Epoch 00019: val_accuracy improved from 0.42125 to 0.44000, saving model to cars_EfficientNetB5.h5
# 101/101 [==============================] - 139s 1s/step - loss: 0.6921 - accuracy: 0.7973 - val_loss: 2.3786 - val_accuracy: 0.4400
# Epoch 20/50
# 101/101 [==============================] - ETA: 0s - loss: 0.6495 - accuracy: 0.8104
# Epoch 00020: val_accuracy did not improve from 0.44000
# 101/101 [==============================] - 138s 1s/step - loss: 0.6495 - accuracy: 0.8104 - val_loss: 2.5162 - val_accuracy: 0.4187
# Epoch 21/50
# 101/101 [==============================] - ETA: 0s - loss: 0.6103 - accuracy: 0.8262
# Epoch 00021: val_accuracy did not improve from 0.44000
# 101/101 [==============================] - 139s 1s/step - loss: 0.6103 - accuracy: 0.8262 - val_loss: 2.4257 - val_accuracy: 0.4375
# Epoch 22/50
# 101/101 [==============================] - ETA: 0s - loss: 0.5964 - accuracy: 0.8219
# Epoch 00022: val_accuracy did not improve from 0.44000
# 101/101 [==============================] - 139s 1s/step - loss: 0.5964 - accuracy: 0.8219 - val_loss: 2.5069 - val_accuracy: 0.4281
# Epoch 23/50
# 101/101 [==============================] - ETA: 0s - loss: 0.5793 - accuracy: 0.8295
# Epoch 00023: val_accuracy did not improve from 0.44000
# 101/101 [==============================] - 138s 1s/step - loss: 0.5793 - accuracy: 0.8295 - val_loss: 2.4991 - val_accuracy: 0.4269
# Epoch 24/50
# 101/101 [==============================] - ETA: 0s - loss: 0.5415 - accuracy: 0.8427
# Epoch 00024: val_accuracy did not improve from 0.44000
# 101/101 [==============================] - 138s 1s/step - loss: 0.5415 - accuracy: 0.8427 - val_loss: 2.5437 - val_accuracy: 0.4369
# Epoch 25/50
# 101/101 [==============================] - ETA: 0s - loss: 0.5109 - accuracy: 0.8489
# Epoch 00025: val_accuracy did not improve from 0.44000
# 101/101 [==============================] - 138s 1s/step - loss: 0.5109 - accuracy: 0.8489 - val_loss: 2.5644 - val_accuracy: 0.4363
# Epoch 26/50
# 101/101 [==============================] - ETA: 0s - loss: 0.5111 - accuracy: 0.8482
# Epoch 00026: val_accuracy did not improve from 0.44000
# 101/101 [==============================] - 139s 1s/step - loss: 0.5111 - accuracy: 0.8482 - val_loss: 2.5085 - val_accuracy: 0.4369
# Epoch 27/50
# 101/101 [==============================] - ETA: 0s - loss: 0.4816 - accuracy: 0.8541
# Epoch 00027: val_accuracy improved from 0.44000 to 0.44188, saving model to cars_EfficientNetB5.h5
# 101/101 [==============================] - 139s 1s/step - loss: 0.4816 - accuracy: 0.8541 - val_loss: 2.4973 - val_accuracy: 0.4419
# Epoch 28/50
# 101/101 [==============================] - ETA: 0s - loss: 0.4739 - accuracy: 0.8555
# Epoch 00028: val_accuracy did not improve from 0.44188
# 101/101 [==============================] - 138s 1s/step - loss: 0.4739 - accuracy: 0.8555 - val_loss: 2.5310 - val_accuracy: 0.4331
# Epoch 29/50
# 101/101 [==============================] - ETA: 0s - loss: 0.4376 - accuracy: 0.8706
# Epoch 00029: val_accuracy improved from 0.44188 to 0.44688, saving model to cars_EfficientNetB5.h5
# 101/101 [==============================] - 139s 1s/step - loss: 0.4376 - accuracy: 0.8706 - val_loss: 2.5729 - val_accuracy: 0.4469
# Epoch 30/50
# 101/101 [==============================] - ETA: 0s - loss: 0.4405 - accuracy: 0.8716
# Epoch 00030: val_accuracy did not improve from 0.44688
# 101/101 [==============================] - 140s 1s/step - loss: 0.4405 - accuracy: 0.8716 - val_loss: 2.5564 - val_accuracy: 0.4381
# Epoch 31/50
# 101/101 [==============================] - ETA: 0s - loss: 0.4005 - accuracy: 0.8808
# Epoch 00031: val_accuracy improved from 0.44688 to 0.44875, saving model to cars_EfficientNetB5.h5
# 101/101 [==============================] - 145s 1s/step - loss: 0.4005 - accuracy: 0.8808 - val_loss: 2.4911 - val_accuracy: 0.4487
# Epoch 32/50
# 101/101 [==============================] - ETA: 0s - loss: 0.4155 - accuracy: 0.8763
# Epoch 00032: val_accuracy improved from 0.44875 to 0.45875, saving model to cars_EfficientNetB5.h5
# 101/101 [==============================] - 144s 1s/step - loss: 0.4155 - accuracy: 0.8763 - val_loss: 2.6188 - val_accuracy: 0.4588
# Epoch 33/50
# 101/101 [==============================] - ETA: 0s - loss: 0.4095 - accuracy: 0.8769
# Epoch 00033: val_accuracy did not improve from 0.45875
# 101/101 [==============================] - 143s 1s/step - loss: 0.4095 - accuracy: 0.8769 - val_loss: 2.7040 - val_accuracy: 0.4462
# Epoch 34/50
# 101/101 [==============================] - ETA: 0s - loss: 0.4207 - accuracy: 0.8805
# Epoch 00034: val_accuracy did not improve from 0.45875
# 101/101 [==============================] - 142s 1s/step - loss: 0.4207 - accuracy: 0.8805 - val_loss: 2.6140 - val_accuracy: 0.4450
# Epoch 35/50
# 101/101 [==============================] - ETA: 0s - loss: 0.4012 - accuracy: 0.8799
# Epoch 00035: val_accuracy did not improve from 0.45875
# 101/101 [==============================] - 143s 1s/step - loss: 0.4012 - accuracy: 0.8799 - val_loss: 2.5583 - val_accuracy: 0.4525
# Epoch 36/50
# 101/101 [==============================] - ETA: 0s - loss: 0.3715 - accuracy: 0.8882
# Epoch 00036: val_accuracy did not improve from 0.45875
# 101/101 [==============================] - 144s 1s/step - loss: 0.3715 - accuracy: 0.8882 - val_loss: 2.7574 - val_accuracy: 0.4350
# Epoch 37/50
# 101/101 [==============================] - ETA: 0s - loss: 0.3607 - accuracy: 0.8924
# Epoch 00037: val_accuracy did not improve from 0.45875
# 101/101 [==============================] - 140s 1s/step - loss: 0.3607 - accuracy: 0.8924 - val_loss: 2.7259 - val_accuracy: 0.4475
# Epoch 38/50
# 101/101 [==============================] - ETA: 0s - loss: 0.3584 - accuracy: 0.8918
# Epoch 00038: val_accuracy did not improve from 0.45875
# 101/101 [==============================] - 141s 1s/step - loss: 0.3584 - accuracy: 0.8918 - val_loss: 2.7873 - val_accuracy: 0.4381
# Epoch 39/50
# 101/101 [==============================] - ETA: 0s - loss: 0.3378 - accuracy: 0.9031
# Epoch 00039: val_accuracy did not improve from 0.45875
# 101/101 [==============================] - 142s 1s/step - loss: 0.3378 - accuracy: 0.9031 - val_loss: 2.7052 - val_accuracy: 0.4556
# Epoch 40/50
# 101/101 [==============================] - ETA: 0s - loss: 0.3211 - accuracy: 0.8983
# Epoch 00040: val_accuracy did not improve from 0.45875
# 101/101 [==============================] - 142s 1s/step - loss: 0.3211 - accuracy: 0.8983 - val_loss: 2.7147 - val_accuracy: 0.4481
# Epoch 41/50
# 101/101 [==============================] - ETA: 0s - loss: 0.3397 - accuracy: 0.9005
# Epoch 00041: val_accuracy did not improve from 0.45875
# 101/101 [==============================] - 140s 1s/step - loss: 0.3397 - accuracy: 0.9005 - val_loss: 2.6538 - val_accuracy: 0.4525
# Epoch 42/50
# 101/101 [==============================] - ETA: 0s - loss: 0.3255 - accuracy: 0.9019
# Epoch 00042: val_accuracy did not improve from 0.45875
# 101/101 [==============================] - 143s 1s/step - loss: 0.3255 - accuracy: 0.9019 - val_loss: 2.7531 - val_accuracy: 0.4475
# Epoch 43/50
# 101/101 [==============================] - ETA: 0s - loss: 0.3249 - accuracy: 0.9031
# Epoch 00043: val_accuracy did not improve from 0.45875
# 101/101 [==============================] - 142s 1s/step - loss: 0.3249 - accuracy: 0.9031 - val_loss: 2.6868 - val_accuracy: 0.4387
# Epoch 44/50
# 101/101 [==============================] - ETA: 0s - loss: 0.2995 - accuracy: 0.9068
# Epoch 00044: val_accuracy did not improve from 0.45875
# 101/101 [==============================] - 144s 1s/step - loss: 0.2995 - accuracy: 0.9068 - val_loss: 2.8685 - val_accuracy: 0.4363
# Epoch 45/50
# 101/101 [==============================] - ETA: 0s - loss: 0.3269 - accuracy: 0.8996
# Epoch 00045: val_accuracy did not improve from 0.45875
# 101/101 [==============================] - 140s 1s/step - loss: 0.3269 - accuracy: 0.8996 - val_loss: 2.8180 - val_accuracy: 0.4456
# Epoch 46/50
# 101/101 [==============================] - ETA: 0s - loss: 0.3181 - accuracy: 0.8994
# Epoch 00046: val_accuracy did not improve from 0.45875
# 101/101 [==============================] - 143s 1s/step - loss: 0.3181 - accuracy: 0.8994 - val_loss: 2.8766 - val_accuracy: 0.4369
# Epoch 47/50
# 101/101 [==============================] - ETA: 0s - loss: 0.3083 - accuracy: 0.9084
# Epoch 00047: val_accuracy did not improve from 0.45875
# 101/101 [==============================] - 142s 1s/step - loss: 0.3083 - accuracy: 0.9084 - val_loss: 2.8081 - val_accuracy: 0.4500
# Epoch 48/50
# 101/101 [==============================] - ETA: 0s - loss: 0.2904 - accuracy: 0.9120
# Epoch 00048: val_accuracy did not improve from 0.45875
# 101/101 [==============================] - 142s 1s/step - loss: 0.2904 - accuracy: 0.9120 - val_loss: 2.8795 - val_accuracy: 0.4244
# Epoch 49/50
# 101/101 [==============================] - ETA: 0s - loss: 0.3015 - accuracy: 0.9085
# Epoch 00049: val_accuracy did not improve from 0.45875
# 101/101 [==============================] - 144s 1s/step - loss: 0.3015 - accuracy: 0.9085 - val_loss: 2.8424 - val_accuracy: 0.4431
# Epoch 50/50
# 101/101 [==============================] - ETA: 0s - loss: 0.2838 - accuracy: 0.9095
# Epoch 00050: val_accuracy did not improve from 0.45875
# 101/101 [==============================] - 141s 1s/step - loss: 0.2838 - accuracy: 0.9095 - val_loss: 2.8965 - val_accuracy: 0.4437

# %% [markdown]
# ### Unfreeze some of Trained Layers in ResNet

# %%
print(len(model.layers))
# Out:
# 576

# %% [markdown]
# Let's unfreeze some layers at the end (which have high end features more specific to ImageNet)

# %%
#Unfreezing all layers after layer#
for layer in model.layers[170:]:
    layer.trainable = True

# %%
model.summary()

# %%
#We will need to recompile the model
final_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
final_model.summary()

# %%
#Lets train for 10 steps
final_model.fit(train_generator, 
                epochs=250,
                initial_epoch=50,
                steps_per_epoch= 6515//64,
                validation_data=test_generator,
                validation_steps = 1629//64, 
                callbacks=[model_checkpoint])
# Out:
# Epoch 51/250
# 101/101 [==============================] - ETA: 0s - loss: 2.3893 - accuracy: 0.4916
# Epoch 00051: val_accuracy did not improve from 0.45875
# 101/101 [==============================] - 178s 2s/step - loss: 2.3893 - accuracy: 0.4916 - val_loss: 2.7848 - val_accuracy: 0.3481
# Epoch 52/250
# 101/101 [==============================] - ETA: 0s - loss: 0.7647 - accuracy: 0.7796
# Epoch 00052: val_accuracy improved from 0.45875 to 0.46625, saving model to cars_EfficientNetB5.h5
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# 101/101 [==============================] - 160s 2s/step - loss: 0.7647 - accuracy: 0.7796 - val_loss: 2.5508 - val_accuracy: 0.4663
# Epoch 53/250
# 101/101 [==============================] - ETA: 0s - loss: 0.5688 - accuracy: 0.8369
# Epoch 00053: val_accuracy improved from 0.46625 to 0.51063, saving model to cars_EfficientNetB5.h5
# 101/101 [==============================] - 161s 2s/step - loss: 0.5688 - accuracy: 0.8369 - val_loss: 2.3197 - val_accuracy: 0.5106
# Epoch 54/250
# 101/101 [==============================] - ETA: 0s - loss: 0.4686 - accuracy: 0.8668
# Epoch 00054: val_accuracy improved from 0.51063 to 0.54688, saving model to cars_EfficientNetB5.h5
# 101/101 [==============================] - 161s 2s/step - loss: 0.4686 - accuracy: 0.8668 - val_loss: 2.1993 - val_accuracy: 0.5469
# Epoch 55/250
# 101/101 [==============================] - ETA: 0s - loss: 0.3850 - accuracy: 0.8859
# Epoch 00055: val_accuracy improved from 0.54688 to 0.57500, saving model to cars_EfficientNetB5.h5
# 101/101 [==============================] - 156s 2s/step - loss: 0.3850 - accuracy: 0.8859 - val_loss: 2.1846 - val_accuracy: 0.5750
# Epoch 56/250
# 101/101 [==============================] - ETA: 0s - loss: 0.3250 - accuracy: 0.9009
# Epoch 00056: val_accuracy improved from 0.57500 to 0.60250, saving model to cars_EfficientNetB5.h5
# 101/101 [==============================] - 159s 2s/step - loss: 0.3250 - accuracy: 0.9009 - val_loss: 2.0521 - val_accuracy: 0.6025
# Epoch 57/250
# 101/101 [==============================] - ETA: 0s - loss: 0.3156 - accuracy: 0.9065
# Epoch 00057: val_accuracy did not improve from 0.60250
# 101/101 [==============================] - 155s 2s/step - loss: 0.3156 - accuracy: 0.9065 - val_loss: 2.1681 - val_accuracy: 0.5987
# Epoch 58/250
# 101/101 [==============================] - ETA: 0s - loss: 0.3132 - accuracy: 0.9011
# Epoch 00058: val_accuracy did not improve from 0.60250
# 101/101 [==============================] - 155s 2s/step - loss: 0.3132 - accuracy: 0.9011 - val_loss: 2.2893 - val_accuracy: 0.5863
# Epoch 59/250
# 101/101 [==============================] - ETA: 0s - loss: 0.2898 - accuracy: 0.9146
# Epoch 00059: val_accuracy improved from 0.60250 to 0.61563, saving model to cars_EfficientNetB5.h5
# 101/101 [==============================] - 157s 2s/step - loss: 0.2898 - accuracy: 0.9146 - val_loss: 2.0360 - val_accuracy: 0.6156
# Epoch 60/250
# 101/101 [==============================] - ETA: 0s - loss: 0.2474 - accuracy: 0.9270
# Epoch 00060: val_accuracy improved from 0.61563 to 0.63875, saving model to cars_EfficientNetB5.h5
# 101/101 [==============================] - 157s 2s/step - loss: 0.2474 - accuracy: 0.9270 - val_loss: 2.1015 - val_accuracy: 0.6388
# Epoch 61/250
# 101/101 [==============================] - ETA: 0s - loss: 0.2155 - accuracy: 0.9349
# Epoch 00061: val_accuracy did not improve from 0.63875
# 101/101 [==============================] - 155s 2s/step - loss: 0.2155 - accuracy: 0.9349 - val_loss: 2.1190 - val_accuracy: 0.6294
# Epoch 62/250
# 101/101 [==============================] - ETA: 0s - loss: 0.2443 - accuracy: 0.9271
# Epoch 00062: val_accuracy improved from 0.63875 to 0.64500, saving model to cars_EfficientNetB5.h5
# 101/101 [==============================] - 157s 2s/step - loss: 0.2443 - accuracy: 0.9271 - val_loss: 1.9206 - val_accuracy: 0.6450
# Epoch 63/250
# 101/101 [==============================] - ETA: 0s - loss: 0.2606 - accuracy: 0.9214
# Epoch 00063: val_accuracy did not improve from 0.64500
# 101/101 [==============================] - 154s 2s/step - loss: 0.2606 - accuracy: 0.9214 - val_loss: 2.3270 - val_accuracy: 0.6144
# Epoch 64/250
# 101/101 [==============================] - ETA: 0s - loss: 0.2183 - accuracy: 0.9363
# Epoch 00064: val_accuracy did not improve from 0.64500
# 101/101 [==============================] - 154s 2s/step - loss: 0.2183 - accuracy: 0.9363 - val_loss: 1.9330 - val_accuracy: 0.6406
# Epoch 65/250
# 101/101 [==============================] - ETA: 0s - loss: 0.2195 - accuracy: 0.9375
# Epoch 00065: val_accuracy did not improve from 0.64500
# 101/101 [==============================] - 157s 2s/step - loss: 0.2195 - accuracy: 0.9375 - val_loss: 1.9873 - val_accuracy: 0.6294
# Epoch 66/250
# 101/101 [==============================] - ETA: 0s - loss: 0.2303 - accuracy: 0.9327
# Epoch 00066: val_accuracy did not improve from 0.64500
# 101/101 [==============================] - 156s 2s/step - loss: 0.2303 - accuracy: 0.9327 - val_loss: 2.0663 - val_accuracy: 0.6112
# Epoch 67/250
# 101/101 [==============================] - ETA: 0s - loss: 0.2533 - accuracy: 0.9278
# Epoch 00067: val_accuracy did not improve from 0.64500
# 101/101 [==============================] - 155s 2s/step - loss: 0.2533 - accuracy: 0.9278 - val_loss: 2.2568 - val_accuracy: 0.6375
# Epoch 68/250
# 101/101 [==============================] - ETA: 0s - loss: 0.2183 - accuracy: 0.9349
# Epoch 00068: val_accuracy improved from 0.64500 to 0.64688, saving model to cars_EfficientNetB5.h5
# 101/101 [==============================] - 161s 2s/step - loss: 0.2183 - accuracy: 0.9349 - val_loss: 2.0491 - val_accuracy: 0.6469
# Epoch 69/250
# 101/101 [==============================] - ETA: 0s - loss: 0.2065 - accuracy: 0.9406
# Epoch 00069: val_accuracy did not improve from 0.64688
# 101/101 [==============================] - 157s 2s/step - loss: 0.2065 - accuracy: 0.9406 - val_loss: 2.1538 - val_accuracy: 0.6388
# Epoch 70/250
# 101/101 [==============================] - ETA: 0s - loss: 0.1788 - accuracy: 0.9479
# Epoch 00070: val_accuracy did not improve from 0.64688
# 101/101 [==============================] - 159s 2s/step - loss: 0.1788 - accuracy: 0.9479 - val_loss: 2.1074 - val_accuracy: 0.6444
# Epoch 71/250
# 101/101 [==============================] - ETA: 0s - loss: 0.1421 - accuracy: 0.9566
# Epoch 00071: val_accuracy improved from 0.64688 to 0.67750, saving model to cars_EfficientNetB5.h5
# 101/101 [==============================] - 161s 2s/step - loss: 0.1421 - accuracy: 0.9566 - val_loss: 1.7450 - val_accuracy: 0.6775
# Epoch 72/250
# 101/101 [==============================] - ETA: 0s - loss: 0.1352 - accuracy: 0.9586
# Epoch 00072: val_accuracy improved from 0.67750 to 0.68000, saving model to cars_EfficientNetB5.h5
# 101/101 [==============================] - 160s 2s/step - loss: 0.1352 - accuracy: 0.9586 - val_loss: 1.9814 - val_accuracy: 0.6800
# Epoch 73/250
# 101/101 [==============================] - ETA: 0s - loss: 0.1797 - accuracy: 0.9445
# Epoch 00073: val_accuracy improved from 0.68000 to 0.68063, saving model to cars_EfficientNetB5.h5
# 101/101 [==============================] - 161s 2s/step - loss: 0.1797 - accuracy: 0.9445 - val_loss: 2.0078 - val_accuracy: 0.6806
# Epoch 74/250
# 101/101 [==============================] - ETA: 0s - loss: 0.2015 - accuracy: 0.9433
# Epoch 00074: val_accuracy did not improve from 0.68063
# 101/101 [==============================] - 156s 2s/step - loss: 0.2015 - accuracy: 0.9433 - val_loss: 2.0656 - val_accuracy: 0.6400
# Epoch 75/250
# 101/101 [==============================] - ETA: 0s - loss: 0.2180 - accuracy: 0.9364
# Epoch 00075: val_accuracy did not improve from 0.68063
# 101/101 [==============================] - 159s 2s/step - loss: 0.2180 - accuracy: 0.9364 - val_loss: 2.4449 - val_accuracy: 0.6075
# Epoch 76/250
# 101/101 [==============================] - ETA: 0s - loss: 0.1820 - accuracy: 0.9471
# Epoch 00076: val_accuracy did not improve from 0.68063
# 101/101 [==============================] - 159s 2s/step - loss: 0.1820 - accuracy: 0.9471 - val_loss: 1.9629 - val_accuracy: 0.6725
# Epoch 77/250
# 101/101 [==============================] - ETA: 0s - loss: 0.1870 - accuracy: 0.9442
# Epoch 00077: val_accuracy did not improve from 0.68063
# 101/101 [==============================] - 161s 2s/step - loss: 0.1870 - accuracy: 0.9442 - val_loss: 2.1272 - val_accuracy: 0.6463
# Epoch 78/250
# 101/101 [==============================] - ETA: 0s - loss: 0.1781 - accuracy: 0.9473
# Epoch 00078: val_accuracy did not improve from 0.68063
# 101/101 [==============================] - 159s 2s/step - loss: 0.1781 - accuracy: 0.9473 - val_loss: 2.2196 - val_accuracy: 0.6488
# Epoch 79/250
# 101/101 [==============================] - ETA: 0s - loss: 0.1530 - accuracy: 0.9561
# Epoch 00079: val_accuracy did not improve from 0.68063
# 101/101 [==============================] - 159s 2s/step - loss: 0.1530 - accuracy: 0.9561 - val_loss: 2.6790 - val_accuracy: 0.6300
# Epoch 80/250
# 101/101 [==============================] - ETA: 0s - loss: 0.1918 - accuracy: 0.9454
# Epoch 00080: val_accuracy did not improve from 0.68063
# 101/101 [==============================] - 155s 2s/step - loss: 0.1918 - accuracy: 0.9454 - val_loss: 1.8749 - val_accuracy: 0.6394
# Epoch 81/250
# 101/101 [==============================] - ETA: 0s - loss: 0.1701 - accuracy: 0.9521
# Epoch 00081: val_accuracy did not improve from 0.68063
# 101/101 [==============================] - 155s 2s/step - loss: 0.1701 - accuracy: 0.9521 - val_loss: 2.4568 - val_accuracy: 0.6281
# Epoch 82/250
# 101/101 [==============================] - ETA: 0s - loss: 0.1499 - accuracy: 0.9583
# Epoch 00082: val_accuracy improved from 0.68063 to 0.68500, saving model to cars_EfficientNetB5.h5
# 101/101 [==============================] - 161s 2s/step - loss: 0.1499 - accuracy: 0.9583 - val_loss: 2.0409 - val_accuracy: 0.6850
# Epoch 83/250
# 101/101 [==============================] - ETA: 0s - loss: 0.1615 - accuracy: 0.9558
# Epoch 00083: val_accuracy did not improve from 0.68500
# 101/101 [==============================] - 159s 2s/step - loss: 0.1615 - accuracy: 0.9558 - val_loss: 1.9193 - val_accuracy: 0.6650
# Epoch 84/250
# 101/101 [==============================] - ETA: 0s - loss: 0.1524 - accuracy: 0.9588
# Epoch 00084: val_accuracy did not improve from 0.68500
# 101/101 [==============================] - 156s 2s/step - loss: 0.1524 - accuracy: 0.9588 - val_loss: 2.2118 - val_accuracy: 0.6444
# Epoch 85/250
# 101/101 [==============================] - ETA: 0s - loss: 0.1737 - accuracy: 0.9523
# Epoch 00085: val_accuracy did not improve from 0.68500
# 101/101 [==============================] - 159s 2s/step - loss: 0.1737 - accuracy: 0.9523 - val_loss: 2.3088 - val_accuracy: 0.6488
# Epoch 86/250
# 101/101 [==============================] - ETA: 0s - loss: 0.1913 - accuracy: 0.9471
# Epoch 00086: val_accuracy did not improve from 0.68500
# 101/101 [==============================] - 157s 2s/step - loss: 0.1913 - accuracy: 0.9471 - val_loss: 2.5860 - val_accuracy: 0.6350
# Epoch 87/250
# 101/101 [==============================] - ETA: 0s - loss: 0.2291 - accuracy: 0.9383
# Epoch 00087: val_accuracy did not improve from 0.68500
# 101/101 [==============================] - 157s 2s/step - loss: 0.2291 - accuracy: 0.9383 - val_loss: 2.5205 - val_accuracy: 0.6375
# Epoch 88/250
# 101/101 [==============================] - ETA: 0s - loss: 0.1368 - accuracy: 0.9597
# Epoch 00088: val_accuracy did not improve from 0.68500
# 101/101 [==============================] - 156s 2s/step - loss: 0.1368 - accuracy: 0.9597 - val_loss: 2.1047 - val_accuracy: 0.6744
# Epoch 89/250
# 101/101 [==============================] - ETA: 0s - loss: 0.1379 - accuracy: 0.9605
# Epoch 00089: val_accuracy did not improve from 0.68500
# 101/101 [==============================] - 155s 2s/step - loss: 0.1379 - accuracy: 0.9605 - val_loss: 2.3059 - val_accuracy: 0.6456
# Epoch 90/250
# 101/101 [==============================] - ETA: 0s - loss: 0.1468 - accuracy: 0.9568
# Epoch 00090: val_accuracy did not improve from 0.68500
# 101/101 [==============================] - 156s 2s/step - loss: 0.1468 - accuracy: 0.9568 - val_loss: 2.3334 - val_accuracy: 0.6575
# Epoch 91/250
# 101/101 [==============================] - ETA: 0s - loss: 0.1543 - accuracy: 0.9569
# Epoch 00091: val_accuracy did not improve from 0.68500
# 101/101 [==============================] - 159s 2s/step - loss: 0.1543 - accuracy: 0.9569 - val_loss: 1.9839 - val_accuracy: 0.6750
# Epoch 92/250
# 101/101 [==============================] - ETA: 0s - loss: 0.1206 - accuracy: 0.9643
# Epoch 00092: val_accuracy did not improve from 0.68500
# 101/101 [==============================] - 154s 2s/step - loss: 0.1206 - accuracy: 0.9643 - val_loss: 2.1874 - val_accuracy: 0.6637
# Epoch 93/250
# 101/101 [==============================] - ETA: 0s - loss: 0.1316 - accuracy: 0.9631
# Epoch 00093: val_accuracy improved from 0.68500 to 0.69000, saving model to cars_EfficientNetB5.h5
# 101/101 [==============================] - 157s 2s/step - loss: 0.1316 - accuracy: 0.9631 - val_loss: 2.0335 - val_accuracy: 0.6900
# Epoch 94/250
# 101/101 [==============================] - ETA: 0s - loss: 0.1167 - accuracy: 0.9678
# Epoch 00094: val_accuracy did not improve from 0.69000
# 101/101 [==============================] - 154s 2s/step - loss: 0.1167 - accuracy: 0.9678 - val_loss: 2.0911 - val_accuracy: 0.6844
# Epoch 95/250
# 101/101 [==============================] - ETA: 0s - loss: 0.1291 - accuracy: 0.9642
# Epoch 00095: val_accuracy did not improve from 0.69000
# 101/101 [==============================] - 154s 2s/step - loss: 0.1291 - accuracy: 0.9642 - val_loss: 2.3736 - val_accuracy: 0.6762
# Epoch 96/250
# 101/101 [==============================] - ETA: 0s - loss: 0.1633 - accuracy: 0.9547
# Epoch 00096: val_accuracy did not improve from 0.69000
# 101/101 [==============================] - 155s 2s/step - loss: 0.1633 - accuracy: 0.9547 - val_loss: 2.4915 - val_accuracy: 0.6844
# Epoch 97/250
# 101/101 [==============================] - ETA: 0s - loss: 0.1329 - accuracy: 0.9609
# Epoch 00097: val_accuracy did not improve from 0.69000
# 101/101 [==============================] - 156s 2s/step - loss: 0.1329 - accuracy: 0.9609 - val_loss: 1.9197 - val_accuracy: 0.6850
# Epoch 98/250
# 101/101 [==============================] - ETA: 0s - loss: 0.1347 - accuracy: 0.9581
# Epoch 00098: val_accuracy did not improve from 0.69000
# 101/101 [==============================] - 155s 2s/step - loss: 0.1347 - accuracy: 0.9581 - val_loss: 2.5872 - val_accuracy: 0.6212
# Epoch 99/250
# 101/101 [==============================] - ETA: 0s - loss: 0.1381 - accuracy: 0.9609
# Epoch 00099: val_accuracy did not improve from 0.69000
# 101/101 [==============================] - 156s 2s/step - loss: 0.1381 - accuracy: 0.9609 - val_loss: 2.4974 - val_accuracy: 0.6394
# Epoch 100/250
# 101/101 [==============================] - ETA: 0s - loss: 0.1531 - accuracy: 0.9555
# Epoch 00100: val_accuracy improved from 0.69000 to 0.69063, saving model to cars_EfficientNetB5.h5
# 101/101 [==============================] - 160s 2s/step - loss: 0.1531 - accuracy: 0.9555 - val_loss: 1.8154 - val_accuracy: 0.6906
# Epoch 101/250
# 101/101 [==============================] - ETA: 0s - loss: 0.1244 - accuracy: 0.9642
# Epoch 00101: val_accuracy did not improve from 0.69063
# 101/101 [==============================] - 157s 2s/step - loss: 0.1244 - accuracy: 0.9642 - val_loss: 1.9568 - val_accuracy: 0.6794
# Epoch 102/250
# 101/101 [==============================] - ETA: 0s - loss: 0.1461 - accuracy: 0.9628
# Epoch 00102: val_accuracy did not improve from 0.69063
# 101/101 [==============================] - 156s 2s/step - loss: 0.1461 - accuracy: 0.9628 - val_loss: 2.3268 - val_accuracy: 0.6656
# Epoch 103/250
# 101/101 [==============================] - ETA: 0s - loss: 0.1189 - accuracy: 0.9630
# Epoch 00103: val_accuracy did not improve from 0.69063
# 101/101 [==============================] - 153s 2s/step - loss: 0.1189 - accuracy: 0.9630 - val_loss: 1.9876 - val_accuracy: 0.6906
# Epoch 104/250
# 101/101 [==============================] - ETA: 0s - loss: 0.1494 - accuracy: 0.9606
# Epoch 00104: val_accuracy did not improve from 0.69063
# 101/101 [==============================] - 153s 2s/step - loss: 0.1494 - accuracy: 0.9606 - val_loss: 1.9794 - val_accuracy: 0.6819
# Epoch 105/250
# 101/101 [==============================] - ETA: 0s - loss: 0.1226 - accuracy: 0.9653
# Epoch 00105: val_accuracy did not improve from 0.69063
# 101/101 [==============================] - 154s 2s/step - loss: 0.1226 - accuracy: 0.9653 - val_loss: 2.3756 - val_accuracy: 0.6837
# Epoch 106/250
# 101/101 [==============================] - ETA: 0s - loss: 0.1465 - accuracy: 0.9589
# Epoch 00106: val_accuracy did not improve from 0.69063
# 101/101 [==============================] - 156s 2s/step - loss: 0.1465 - accuracy: 0.9589 - val_loss: 2.1672 - val_accuracy: 0.6631
# Epoch 107/250
# 101/101 [==============================] - ETA: 0s - loss: 0.1357 - accuracy: 0.9628
# Epoch 00107: val_accuracy did not improve from 0.69063
# 101/101 [==============================] - 154s 2s/step - loss: 0.1357 - accuracy: 0.9628 - val_loss: 1.9102 - val_accuracy: 0.6737
# Epoch 108/250
# 101/101 [==============================] - ETA: 0s - loss: 0.1076 - accuracy: 0.9656
# Epoch 00108: val_accuracy did not improve from 0.69063
# 101/101 [==============================] - 155s 2s/step - loss: 0.1076 - accuracy: 0.9656 - val_loss: 2.3526 - val_accuracy: 0.6794
# Epoch 109/250
# 101/101 [==============================] - ETA: 0s - loss: 0.1030 - accuracy: 0.9709
# Epoch 00109: val_accuracy did not improve from 0.69063
# 101/101 [==============================] - 154s 2s/step - loss: 0.1030 - accuracy: 0.9709 - val_loss: 2.3078 - val_accuracy: 0.6831
# Epoch 110/250
# 101/101 [==============================] - ETA: 0s - loss: 0.1103 - accuracy: 0.9701
# Epoch 00110: val_accuracy did not improve from 0.69063
# 101/101 [==============================] - 154s 2s/step - loss: 0.1103 - accuracy: 0.9701 - val_loss: 2.1628 - val_accuracy: 0.6856
# Epoch 111/250
#  17/101 [====>.........................] - ETA: 1:57 - loss: 0.0944 - accuracy: 0.9715
